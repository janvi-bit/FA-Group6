# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats

from pandas_datareader import data
from scipy.optimize import minimize

# %%
corr = pd.read_csv('Correlation_matrix.csv', index_col='Unnamed: 0')
corr
# Out:
#        AAP   ABT   ACN   ADM   ADP  ADSK   AEE   AEP   AFL   AJG  ...  WRLD  \
# AAP   1.00  0.76  0.82  0.81  0.85  0.70  0.70  0.45  0.68  0.82  ...  0.79
# ABT   0.76  1.00  0.95  0.71  0.90  0.95  0.91  0.66  0.56  0.96  ...  0.71
# ACN   0.82  0.95  1.00  0.83  0.93  0.91  0.84  0.56  0.64  0.99  ...  0.82
# ADM   0.81  0.71  0.83  1.00  0.74  0.70  0.56  0.23  0.64  0.82  ...  0.77
# ADP   0.85  0.90  0.93  0.74  1.00  0.83  0.89  0.70  0.79  0.93  ...  0.84
# ...    ...   ...   ...   ...   ...   ...   ...   ...   ...   ...  ...   ...
# XOMA  0.19  0.59  0.54  0.39  0.49  0.65  0.43  0.30  0.35  0.54  ...  0.32
# XRX  -0.32 -0.52 -0.47 -0.34 -0.26 -0.54 -0.35 -0.01  0.22 -0.47  ... -0.18
# ZD    0.77  0.69  0.81  0.82  0.81  0.70  0.59  0.38  0.74  0.81  ...  0.79
# ZUMZ  0.80  0.89  0.91  0.82  0.89  0.88  0.77  0.53  0.69  0.91  ...  0.75
# ESNT  0.41  0.36  0.41  0.36  0.55  0.33  0.45  0.55  0.76  0.42  ...  0.50
#
# ...

# %%
test = corr[(corr > -.04) & (corr < .04)]
test
# Out:
#       AAP  ABT  ACN  ADM  ADP  ADSK  AEE   AEP  AFL  AJG  ...  WRLD  WTFC  \
# AAP   NaN  NaN  NaN  NaN  NaN   NaN  NaN   NaN  NaN  NaN  ...   NaN   NaN
# ABT   NaN  NaN  NaN  NaN  NaN   NaN  NaN   NaN  NaN  NaN  ...   NaN   NaN
# ACN   NaN  NaN  NaN  NaN  NaN   NaN  NaN   NaN  NaN  NaN  ...   NaN   NaN
# ADM   NaN  NaN  NaN  NaN  NaN   NaN  NaN   NaN  NaN  NaN  ...   NaN   NaN
# ADP   NaN  NaN  NaN  NaN  NaN   NaN  NaN   NaN  NaN  NaN  ...   NaN   NaN
# ...   ...  ...  ...  ...  ...   ...  ...   ...  ...  ...  ...   ...   ...
# XOMA  NaN  NaN  NaN  NaN  NaN   NaN  NaN   NaN  NaN  NaN  ...   NaN   NaN
# XRX   NaN  NaN  NaN  NaN  NaN   NaN  NaN -0.01  NaN  NaN  ...   NaN   NaN
# ZD    NaN  NaN  NaN  NaN  NaN   NaN  NaN   NaN  NaN  NaN  ...   NaN   NaN
# ZUMZ  NaN  NaN  NaN  NaN  NaN   NaN  NaN   NaN  NaN  NaN  ...   NaN   NaN
# ESNT  NaN  NaN  NaN  NaN  NaN   NaN  NaN   NaN  NaN  NaN  ...   NaN   NaN
#
#       WTRH  WW  WWD  XOMA  XRX  ZD  ZUMZ  ESNT
# ...
