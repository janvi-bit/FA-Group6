# %%
# Provides ways to work with large multidimensional arrays
import numpy as np 
# Allows for further data manipulation and analysis
import pandas as pd
from pandas_datareader import data # Reads stock data 
import matplotlib.pyplot as plt # Plotting
import matplotlib.dates as mdates # Styling dates
# %matplotlib inline

import datetime as dt # For defining dates
# import mplfinance as mpf # Matplotlib finance

import time

# Used to get data from a directory
import os
from os import listdir
from os.path import isfile, join

#Statsmodels is a great library we can use to run regressions.
import statsmodels.api as sm
# Seaborn extends the capabilities of Matplotlib
import seaborn as sns
# Used for calculating regressions
from statsmodels.tsa.ar_model import AutoReg, ar_select_order

# %%
#change the tickers here according to what's in the portfolio
tickers = ['LHX','ODFL','GLDD','HSON','ISSC','KRNT','RCII','SAIA','AMD','EPAM','APPS','ASML','AUDC','DSGX',
          'TTD','TSLA','CHDN','CLAR','FIVE','FOXF','HTHT','LULU','IDXX','BDSI','CDMO','EDAP','ICLR','MEDP',
          'OPRX','RGEN','XOMA','SBAC']

start_date = '2017-01-01'
end_date = '2021-12-31'

panel_data = data.DataReader(tickers,'yahoo', start_date, end_date)

# %%
#check that all stocks have the same amount of data otherwise change the date range

adj_close = panel_data['Adj Close']
adj_close.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1259 entries, 2017-01-03 to 2021-12-31
# Data columns (total 31 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   MGIC    1259 non-null   float64
#  1   NSIT    1259 non-null   float64
#  2   ON      1259 non-null   float64
#  3   TTD     1259 non-null   float64
#  4   IDXX    1259 non-null   float64
#  5   BDSI    1259 non-null   float64
#  6   CDMO    1259 non-null   float64
#  7   ICLR    1259 non-null   float64
#  8   MEDP    1259 non-null   float64
#  9   OPRX    1259 non-null   float64
#  10  RGEN    1259 non-null   float64
#  11  TNDM    1259 non-null   float64
#  12  XOMA    1259 non-null   float64
#  13  CBRE    1259 non-null   float64
#  14  SBAC    1259 non-null   float64
#  15  ODFL    1259 non-null   float64
#  16  GLDD    1259 non-null   float64
#  17  HSON    1259 non-null   float64
#  18  KRNT    1259 non-null   float64
#  19  QRHC    1259 non-null   float64
#  20  RCII    1259 non-null   float64
#  21  SAIA    1259 non-null   float64
#  22  SBLK    1259 non-null   float64
#  23  TRNS    1259 non-null   float64
#  24  HLT     1259 non-null   float64
#  25  TSLA    1259 non-null   float64
#  26  CHDN    1259 non-null   float64
#  27  CLAR    1259 non-null   float64
#  28  FIVE    1259 non-null   float64
#  29  FOXF    1259 non-null   float64
#  30  LULU    1259 non-null   float64
# dtypes: float64(31)
# memory usage: 314.8 KB

# %% [markdown]
# ## Function that saves dataframe to CSV

# %%
# def save_dataframe_to_csv(kind, df, ticker):
#     df.to_csv(kind + ticker + '.csv')

# %%
# for ticker in tickers:
#     panel_data = data.DataReader(ticker,'yahoo', start_date, end_date)
# #     close = panel_data['Close']
#     adj_close = panel_data['Adj Close']
#     save_dataframe_to_csv('adj_close', adj_close, ticker)

# %% [markdown]
# ## Function that returns dataframe from a CSV

# %%
def get_df_from_csv(kind, ticker):
    try:
        df = pd.read_csv(kind + ticker + '.csv', index_col='Date', 
                         parse_dates=True)
    except FileNotFoundError:
        pass
        # print("File Doesn't Exist")
    else:
        return df

# %% [markdown]
# ## Add Daily Return to dataframe

# %%
def add_daily_return_to_df(kind, df, ticker):
    df['daily_return'] = (df['Adj Close'] / df['Adj Close'].shift(1)) - 1
    # Save data to a CSV file
    save_dataframe_to_csv(kind, df, ticker)
    return df

# %%
for ticker in tickers:
    df = get_df_from_csv('adj_close', ticker)
    add_daily_return_to_df('adj_close', df, ticker)

# %% [markdown]
# ## Merge multiple stocks in one dataframe by col name

# %%
def merge_df_by_column_name(col_name, sdate, edate, *tickers):
    # Will hold data for all dataframes with the same column name
    mult_df = pd.DataFrame()
    
    for x in tickers:
        df = get_df_from_csv('adj_close', x)
        
        # NEW Check if your dataframe has duplicate indexes
        if not df.index.is_unique:
            # Delete duplicates 
            df = df.loc[~df.index.duplicated(), :]
        
        mask = (df.index >= sdate) & (df.index <= edate)
        mult_df[x] = df.loc[mask][col_name]
        
    return mult_df

# %% [markdown]
# ## Get stock prices on date

# %%
def get_prices_on_date(stocks_df, date):
    return stocks_df.loc[pd.DatetimeIndex([date])]['Adj Close'].item()

# %% [markdown]
# ## Returns the value of portfolio by date

# %%
def get_port_val_by_date(date, shares, tickers):
    port_prices = merge_df_by_column_name('Adj Close',  date, date, *port_list)
    # Convert from dataframe to Python list
    port_prices = port_prices.values.tolist()
    # Trick that converts a list of lists into a single list
    port_prices = sum(port_prices, [])
    
    # Create a list of values by multiplying shares by price
    value_list = []
    for price, share in zip(port_prices, shares):
        value_list.append(price * share)
    
    return sum(value_list)

# %% [markdown]
# ## Find Daily Return for Whole Portfolio

# %%
def get_port_daily_return(sdate, edate, shares, tickers):
    # Merge all daily prices for all stocks into 1 dataframe
    mult_df = merge_df_by_column_name('Adj Close',  sdate, 
                                  edate, *port_list)
    
    # Get the number of stocks in portfolio
    num_cols = len(mult_df.columns)
    
    # Multiply each stock column by the number of shares
    i = 0
    while i < num_cols:
        mult_df[tickers[i]] = mult_df[tickers[i]].apply(lambda x: x * shares[i])
        i += 1
        
    # Create a new column with the sums of all stocks named Total
    mult_df['Total'] = mult_df.iloc[:, 0:num_cols].sum(axis=1)
    
    # Add column for portfolio daily return
    mult_df['daily_return'] = (mult_df['Total'] / mult_df['Total'].shift(1)) - 1
    
    return mult_df

# %%
#change to the list of stocks we using
port_list = ['LHX','ODFL','GLDD','HSON','ISSC','KRNT','RCII','SAIA','AMD','EPAM','APPS','ASML','AUDC','DSGX',
          'TTD','TSLA','CHDN','CLAR','FIVE','FOXF','HTHT','LULU','IDXX','BDSI','CDMO','EDAP','ICLR','MEDP',
          'OPRX','RGEN','XOMA','SBAC']

#add in the weightage of stocks
port_shares = [0.070635,0.058251,0.007926,0.163185,0.048494,0.008194,0.018976,0.017402,0.006024,0.043926,0.047034,
              0.000492,0.009460,0.064368,0.135632,0.078126,0.000670,0.007985,0.008257,0.006478,0.003217,0.000217,
              0.003121,0.041926,0.002017,0.046972,0.011787,0.031827,0.006205,0.012434,0.038754]

# tot_port_df = get_port_daily_return('2020-01-02', '2020-12-31', 
#                                     port_shares, port_list)

#change the dates according to what you put on top
tot_port_df = get_port_daily_return('2017-01-01', '2021-01-01', port_shares, port_list)
tot_port_df
# Out:
#                 MGIC      NSIT        ON        TTD       IDXX      BDSI  \
# Date
# 2017-01-03  0.414692  2.369651  0.100581   0.439457   5.702894  0.014339
# 2017-01-04  0.417696  2.411591  0.103038   0.442231   5.622879  0.014339
# 2017-01-05  0.420702  2.368486  0.101849   0.447943   5.623364  0.015159
# 2017-01-06  0.417696  2.335283  0.103117   0.452022   5.739750  0.015569
# 2017-01-09  0.417696  2.328875  0.105733   0.464098   5.771756  0.015159
# ...              ...       ...       ...        ...        ...       ...
# 2020-12-24  1.041280  4.342612  0.253553  15.205089  24.108308  0.035234
# 2020-12-28  1.033102  4.404358  0.253236  13.587110  23.989982  0.034087
# 2020-12-29  1.061724  4.346690  0.250937  13.385902  23.959431  0.033513
# 2020-12-30  1.071946  4.394456  0.257436  13.348533  24.099578  0.034988
# 2020-12-31  1.066494  4.432318  0.259418  13.071118  24.240696  0.034415
#
#                 CDMO      ICLR      MEDP      OPRX  ...      TRNS       HLT  \
# Date                                                ...
# 
DMO      ICLR      MEDP      OPRX  ...      TRNS       HLT  \
# Date                                                ...
# 2017-01-03  0.030059  1.300103  0.216322  0.106740  ...  0.444416  0.110537
# 2017-01-04  0.031061  1.336822  0.219213  0.105422  ...  0.454897  0.114069
# 2017-01-05  0.030059  1.326206  0.215840  0.106740  ...  0.448608  0.112731
# 2017-01-06  0.030059  1.368667  0.215780  0.106740  ...  0.450704  0.113026
# 2017-01-09  0.030059  1.398599  0.215177  0.104105  ...  0.452801  0.112023
# ...              ...       ...       ...       ...  ...       ...       ...
# 2020-12-24  0.216137  3.350059  0.838179  1.387183  ...  1.384816  0.215597
# 2020-12-28  0.215188  3.330395  0.832577  1.414856  ...  1.423807  0.216585
# 2020-12-29  0.211013  3.367287  0.830529  1.364781  ...  1.430934  0.217735
# 2020-12-30  0.220881  3.370071  0.830469  1.370491  ...  1.409133  0.222233
# 2020-12-31  0.218983  3.393042  0.838541  1.368734  ...  1.453994  0.224411
#
#                  TSLA      CHDN      CLAR      FIVE      FOXF       LULU  \
# Date
# 2017-01-03   2.038491  0.570413  0.175594  0.251178  0.333853   2.590705
# 2017-01-04   2.132435  0.571372  0.180256  0.252481  0.346909   2.689915
# 2017-01-05   2.130180  0.570989  0.178702  0.254095  0.347530   2.663563
# 2017-01-06   2.151411  0.562933  0.184918  0.246463  0.343800   2.645735
# 2017-01-09   2.172737  0.555069  0.186472  0.240878  0.341935   2.642635
# ...               ...       ...       ...       ...       ...        ...
# 2020-12-24  31.084661  2.431371  0.488358  0.985664  1.325340  13.618931
# 2020-12-28  31.174847  2.438539  0.489940  1.027300  1.328697  13.616605
# 2020-12-29  31.282882  2.303052  0.472533  1.053547  1.311165  13.688688
# 2020-12-30  32.635208  2.331724  0.480445  1.071852  1.333546  13.594128
# 2020-12-31  33.146730  2.288951  0.487408  1.085751  1.314398  13.487555
#
#                  Total  daily_return
# Date
# 2017-01-03   39.534262           NaN
# 2017-01-04   39.897552      0.009189
# 2017-01-05   39.591896     -0.007661
# 2017-01-06   39.569306     -0.000571
# 2017-01-09   39.512496     -0.001436
# ...                ...           ...
# 2020-12-24  169.405670      0.007074
# 2020-12-28  167.438339     -0.011613
# 2020-12-29  167.118280     -0.001912
# 2020-12-30  168.434283      0.007875
# 2020-12-31  170.032629      0.009489
#
# [1007 rows x 33 columns]

# %% [markdown]
# ## Forecasting

# %%
tot_port_df = tot_port_df.asfreq('d')
tot_port_df.index
# Out:
# DatetimeIndex(['2017-01-03', '2017-01-04', '2017-01-05', '2017-01-06',
#                '2017-01-07', '2017-01-08', '2017-01-09', '2017-01-10',
#                '2017-01-11', '2017-01-12',
#                ...
#                '2020-12-22', '2020-12-23', '2020-12-24', '2020-12-25',
#                '2020-12-26', '2020-12-27', '2020-12-28', '2020-12-29',
#                '2020-12-30', '2020-12-31'],
#               dtype='datetime64[ns]', name='Date', length=1459, freq='D')

# %%
# Delete NaNs for nontrading days
tot_port_df = tot_port_df.fillna(method='ffill')

# %%
tot_port_df
# Out:
#                 MGIC      NSIT        ON        TTD       IDXX      BDSI  \
# Date
# 2017-01-03  0
          'OPRX','RGEN','XOMA','SBAC', "daily_return"]

for x in del_col:
    tot_port_df = tot_port_df.drop([x], axis=1)

# %%
tot_port_df
# Out:
#                  Total
# Date
# 2017-01-03   39.534262
# 2017-01-04   39.897552
# 2017-01-05   39.591896
# 2017-01-06   39.569306
# 2017-01-07   39.569306
# ...                ...
# 2020-12-27  169.405670
# 2020-12-28  167.438339
# 2020-12-29  167.118280
# 2020-12-30  168.434283
# 2020-12-31  170.032629
#
# [1459 rows x 1 columns]

# %%
# Set style for seaborn plot
sns.set_style('darkgrid')
# Add automatic datetime converters
pd.plotting.register_matplotlib_converters()
# Default figure size
sns.mpl.rc('figure',figsize=(19, 13))

# Set fig and ax
fig, ax = plt.subplots()

# Figure out optimum lags for this data set
lags = ar_select_order(tot_port_df, maxlag=30)
print("Lags :", lags.ar_lags)

# Create our model using whole data set
model = AutoReg(tot_port_df['Total'], lags.ar_lags)
model_fit = model.fit()

# Define training and testing area
print("Observations :", len(tot_port_df)) # 1095 observations

train_df = tot_port_df.iloc[0:1167] # First 80% 
test_df = tot_port_df.iloc[1167:] # Last 20%

# Define training model for 459 days (Play with Number & Test)
# and White's covariance estimator
train_model = AutoReg(tot_port_df['Total'], 459).fit(cov_type="HC0")

# # Define start and end for prediction 
start = len(train_df)
end = len(train_df) + len(test_df) - 1

prediction = train_model.predict(start=start, end=end, dynamic=True)

# Plot testing data with prediction
ax = test_df.plot(ax=ax) # blue
ax = prediction.plot(ax=ax) # orange

# Predict 60 days into the future
forecast = train_model.predict(start=end, end=end+252, dynamic=True)
ax = forecast.plot(ax=ax) # Green
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/ar_model.py:248: FutureWarning: The parameter names will change after 0.12 is released. Set old_names to False to use the new names now. Set old_names to True to use the old names.
#   warnings.warn(
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/ar_model.py:248: FutureWarning: The parameter names will change after 0.12 is released. Set old_names to False to use the new names now. Set old_names to True to use the old names.
#   warnings.warn(
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/ar_model.py:248: FutureWarning: The parameter names will change after 0.12 is released. Set old_names to False to use the new names now. Set old_names to True to use the old names.
#   warnings.warn(
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/ar_model.py:248: FutureWarning: The parameter names will change after 0.12 is released. Set old_names to False to use the new names now. Set old_names to True to use the old names.
#   warnings.warn(
# Lags : [1 2]
# Observations : 1459

# %% [markdown]
# ## Calculate annualized returns for forecasted

# %%
forecast
# Out:
# 2020-12-31    170.531999
# 2021-01-01    162.883878
# 2021-01-02    165.296106
# 2021-01-03    158.281736
# 2021-01-04    161.705387
#                  ...
# 2021-09-05    195.361944
# 2021-09-06    211.443617
# 2021-09-07    212.621078
# 2021-09-08    209.400065
# 2021-09-09    197.878171
# Freq: D, Length: 253, dtype: float64

# %%
forecast_df = pd.DataFrame(forecast)

# %%
forecast_df
# Out:
#                      0
# 2020-12-31  170.531999
# 2021-01-01  162.883878
# 2021-01-02  165.296106
# 2021-01-03  158.281736
# 2021-01-04  161.705387
# ...                ...
# 2021-09-05  195.361944
# 2021-09-06  211.443617
# 2021-09-07  212.621078
# 2021-09-08  209.400065
# 2021-09-09  197.878171
#
# [253 rows x 1 columns]

# %%
return_series = (1 + forecast_df.pct_change()).cumprod() - 1

# %%
return_series
# Out:
#                    0
# 2020-12-31       NaN
# 2021-01-01 -0.044849
# 2021-01-02 -0.030703
# 2021-01-03 -0.071836
# 2021-01-04 -0.051759
# ...              ...
# 2021-09-05  0.145603
# 2021-09-06  0.239906
# 2021-09-07  0.246810
# 2021-09-08  0.227922
# 2021-09-09  0.160358
#
# [253 rows x 1 columns]

# %%
#calculate annualized return
total_return = return_series.tail(1)

annualized_return = ((1 + total_return)**(1))-1

print(annualized_return*100)
# Out:
#                     0
# 2021-09-09  16.035801

# %% [markdown]
# ## Backtesting

# %%
# 2021-12-30  3.08  29.610001  5.30  309.290009  219.080002  61.139999
#
# Symbols           RGEN       XOMA        SBAC
# Date
# 2020-12-30  189.139999  44.540001  271.858246
# 2020-12-31  191.630005  44.130001  279.353760
# 2021-01-04  190.660004  39.820000  272.917694
# 2021-01-05  194.669998  40.070000  269.897705
# 2021-01-06  197.009995  40.119999  262.035828
# ...                ...        ...         ...
# 2021-12-23  264.649994  23.320000  373.462097
# 2021-12-27  267.859985  22.049999  382.522247
# 2021-12-28  253.770004  21.940001  383.889252
# 2021-12-29  257.899994  21.500000  384.108795
# 2021-12-30  260.980011  21.230000  387.710876
#
# [253 rows x 32 columns]

# %% [markdown]
# ## Portfolio Analysis

# %%
return_series2 = panel_data2.pct_change().dropna()
return_series2.head()
# Out:
# Symbols          LHX      ODFL      GLDD      HSON      ISSC      KRNT  \
# Date
# 2020-12-31  0.007301  0.008057  0.008423 -0.023256  0.004623 -0.009667
# 2021-01-04 -0.045392 -0.023004 -0.015945 -0.007619 -0.033742 -0.082576
# 2021-01-05  0.010585  0.005559  0.025463  0.011516  0.039683  0.041947
# 2021-01-06  0.002303  0.008083  0.080512 -0.017078 -0.033588 -0.008451
# 2021-01-07 -0.008317  0.044801  0.018802  0.021236 -0.028436  0.034564
#
# Symbols         RCII      SAIA       AMD      EPAM  ...      IDXX      BDSI  \
# Date                                                ...
# 2020-12-31 -0.002345 -0.008337 -0.006285 -0.000363  ...  0.005856 -0.016393
# 2021-01-04 -0.003917 -0.004812  0.006433 -0.028715  ... -0.016204  0.021429
# 2021-01-05  0.040902  0.005169  0.005092 -0.006780  ...  0.011164  0.034965
# 2021-01-06  0.095214  0.034004 -0.026302 -0.046399  ... -0.027471  0.013514
# 2021-01-07 -0.000690  0.036790  0.053471  0.026755  ...  0.023966  0.082222
#
# Symbols         CDMO      EDAP      ICLR      MEDP      OPRX      RGEN  \
# Date
# 2020-12-31 -0.008591 -0.015238  0.006816  0.009720 -0.001282  0.013165
# 2021-01-04  0.027730 -0.009671 -0.015181 -0.034339  0.070603 -0.005062
# 2021-01-05  0.089376  0.025391  0.019113 -0.003199  0.036870  0.021032
# 2021-01-06  0.027864  0.074286  0.050028  0.043958  0.023706  0.012020
# 2021-01-07 -0.003012  0.003546  0.019321  0.000143  0.059023  0.035937
#
# Symbols         XOMA      SBAC
# Date
# 2020-12-31 -0.009205  0.027571
# 2021-01-04 -0.097666 -0.023039
# 2021-01-05  0.006278 -0.011066
# 2021-01-06  0.001248 -0.029129
# 2021-01-07  0.024427  0.002305
#
# [5 rows x 32 columns]

# %%
portfolio_weights = [0.01437975,0.104636,0.00768775,0.015512,0.002394,0.015673,0.01420825,0.000511,0.00838005,
               0.0105336,0.0328188,0.0201075,0.01645035,0.001197,0.01551375,0.0425894,0.0113876,0.0300132,
               0.0050862,0.010752,0.0056798,0.0344918,0.0246477,0.00422835,0.0131775,0.0009114,0.00846195,
               0.00270795,0.02266425,0.0236607,0.0045423,0.175]

#apply the weights to returns
wt_portfolio = return_series2 * portfolio_weights
wt_portfolio.head()
# Out:
# Symbols          LHX      ODFL      GLDD      HSON      ISSC      KRNT  \
# Date
# 2020-12-31  0.000105  0.000843  0.000065 -0.000361  0.000011 -0.000152
# 2021-01-04 -0.000653 -0.002407 -0.000123 -0.000118 -0.000081 -0.001294
# 2021-01-05  0.000152  0.000582  0.000196  0.000179  0.000095  0.000657
# 2021-01-06  0.000033  0.000846  0.000619 -0.000265 -0.000080 -0.000132
# 2021-01-07 -0.000120  0.004688  0.000145  0.000329 -0.000068  0.000542
#
# Symbols         RCII      SAIA       AMD      EPAM  ...      IDXX      BDSI  \
# Date                                                ...
# 2020-12-31 -0.000033 -0.000004 -0.000053 -0.000004  ...  0.000144 -0.000069
# 2021-01-04 -0.000056 -0.000002  0.000054 -0.000302  ... -0.000399  0.000091
# 2021-01-05  0.000581  0.000003  0.000043 -0.000071  ...  0.000275  0.000148
# 2021-01-06  0.001353  0.000017 -0.000220 -0.000489  ... -0.000677  0.000057
# 2021-01-07 -0.000010  0.000019  0.000448  0.000282  ...  0.000591  0.000348
#
# Symbols         CDMO      EDAP      ICLR          MEDP      OPRX      RGEN  \
# Date
# 2020-12-31 -0.000113 -0.000014  0.000058  2.632122e-05 -0.000029  0.000311
# 2021-01-04  0.000365 -0.000009 -0.000128 -9.298849e-05  0.001600 -0.000120
# 2021-01-05  0.001178  0.000023  0.000162 -8.662392e-06  0.000836  0.000498
# 2021-01-06  0.000367  0.000068  0.000423  1.190374e-04  0.000537  0.000284
# 2021-01-07 -0.000040  0.000003  0.000163  3.869692e-07  0.001338  0.000850
#
# Symbols         XOMA      SBAC
# Date
# 2020-12-31 -0.000042  0.004825
# 2021-01-04 -0.000444 -0.004032
# 2021-01-05  0.000029 -0.001936
# 2021-01-06  0.000006 -0.005098
# 2021-01-07  0.000111  0.000403
#
# [5 rows x 32 columns]

# %%
portfolio_returns1 = wt_portfolio.sum(axis = 1)
portfolio_returns1.head()
# Out:
# Date
# 2020-12-31    0.005318
# 2021-01-04   -0.009737
# 2021-01-05    0.007776
# 2021-01-06   -0.001182
# 2021-01-07    0.017724
# dtype: float64

# %%
import pyfolio as pf
pf.create_simple_tear_sheet(portfolio_returns1)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/pyfolio/pos.py:26: UserWarning: Module "zipline.assets" not found; mutltipliers will not be applied to position notionals.
#   warnings.warn(
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2020-12-31</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2021-12-30</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>12</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>38.4%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>38.4%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>13.7%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>2.44</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>5.50</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.96</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-7.0%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>1.49</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>3.77</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>-0.19</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>0.95</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>1.14</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-1.6%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Extra stuff

# %%
import itertools

# %%
weights = [0.070635,0.058251,0.007926,0.163185,0.048494,0.008194,0.018976,0.017402,0.006024,0.043926,0.047034,
              0.000492,0.009460,0.064368,0.135632,0.078126,0.000670,0.007985,0.008257,0.006478,0.003217,0.000217,
              0.003121,0.041926,0.002017,0.046972,0.011787,0.031827,0.006205,0.012434,0.038754]

# %%
panel_data2 = panel_data2 * weights

# %%
num_cols = len(panel_data2.columns)
    
# Create a new column with the sums of all stocks named Total
panel_data2['Total'] = panel_data2.iloc[:, 0:num_cols].sum(axis=1)

# %%
#forecasted portfolio value
panel_data2
# Out:
# Symbols         MGIC      NSIT        ON        TTD       IDXX      BDSI  \
# Date
# 
#  187.01811566308828,
#  192.40328266411188,
#  198.51868722844182,
#  212.64377377737208,
#  213.95220494949567,
#  203.9922504519935,
#  202.54831170356326,
#  204.33818069023764,
#  213.0611281837609,
#  212.00379263748823,
#  210.3596592492213,
#  203.60525404236026,
#  206.9236800571226,
#  210.36037509150646,
#  213.33375861918253,
#  214.52928432247558,
#  213.26178845875324,
#  213.05539808677136,
#  202.25105191807052,
#  211.05273132547055,
#  213.23502138540485,
#  218.63420364249396,
#  208.4652076861681,
#  208.5164617538904,
#  194.15273786322962,
#  194.3744152176625,
#  205.56515007290523,
#  214.91581396863185,
#  210.25037283040749,
#  201.61155240546267,
#  200.02174076795544,
#  206.8683677638386,
#  222.52686056500346,
#  223.41268791395544,
#  219.10058970408696,
#  207.390244839859,
#  210.50959033009437,
#  204.60802995954194,
#  221.63470569427085,
#  220.58906040220737,
#  219.07639299357461,
#  211.09743844200497,
#  211.52449433657299,
#  218.6129258159041,
#  224.84265827836916,
#  236.798999303047,
#  229.94561034032034,
#  227.07112920619292,
#  220.1556683967897,
#  222.3887516330131,
#  221.47074090881392,
#  231.65454089405512,
#  227.6541518842721,
#  216.55864511916647,
#  208.33379194109298,
#  215.90328110257443,
#  221.07694622095897,
#  221.65674772199682,
#  224.22456287848672,
#  216.45625411412067,
#  215.9655089310849,
#  228.13417695817512,
#  224.15116861926012,
#  221.57072317520922,
#  214.39816757435054,
#  200.10880231964177,
#  191.01740925061253,
#  194.11126067036486,
#  203.88206811318292,
#  190.92435602490562,
#  191.22765980601622,
#  186.49493460682586,
#  188.180995182516,
#  195.36194369990474,
#  211.44361717575586,
#  212.62107834435767,
#  209.40006534260405,
#  197.87817057315993]

# %% [markdown]
# ## Calculate MAPE of forecasted period

# %%
# Define the dataset as python lists
# actual = [136, 120, 138, 155, 149]
# forecast = [134, 124, 132, 141, 149]

# Consider a list APE to store the
# APE value for each of the records in dataset
APE = []

# Iterate over the list values
for day in range(253):

	# Calculate percentage error
	per_err = (actual_portfolio_value[day] - forecasted_portfolio_value[day]) / actual_portfolio_value[day]

	# Take absolute value of
	# the percentage error (APE)
	per_err = abs(per_err)

	# Append it to the APE list
	APE.append(per_err)

# Calculate the MAPE
MAPE = sum(APE)/len(APE)

# Print the MAPE value and percentage
print(f'''
MAPE : { round(MAPE, 2) }
MAPE % : { round(MAPE*100, 2) } %
''')
# Out:
# MAPE : 0.09
# MAPE % : 8.89 %

# %% [markdown]
# ## Mean Squared Error

# %%
from sklearn.metrics import mean_squared_error
print(mean_squared_error(actual_portfolio_value, forecasted_portfolio_value))
# Out:
# 476.4983431578214

# %% [markdown]
# ## Forecast for future

# %%
#change to the list of stocks we using
port_list = ["MGIC", "NSIT", "ON", "TTD", "IDXX", "BDSI", "CDMO", "ICLR", "MEDP", "OPRX", "RGEN", "TNDM", "XOMA",
          "CBRE", "SBAC", "ODFL", "GLDD", "HSON", "KRNT", "QRHC", "RCII", "SAIA", "SBLK", "TRNS", "HLT", "TSLA",
          "CHDN", "CLAR", "FIVE", "FOXF", "LULU"]

#add in the weightage of stocks
port_shares = [0.070635,0.058251,0.007926,0.163185,0.048494,0.008194,0.018976,0.017402,0.006024,0.043926,0.047034,
              0.000492,0.009460,0.064368,0.135632,0.078126,0.000670,0.007985,0.008257,0.006478,0.003217,0.000217,
              0.003121,0.041926,0.002017,0.046972,0.011787,0.031827,0.006205,0.012434,0.038754]

# tot_port_df = get_port_daily_return('2020-01-02', '2020-12-31', 
#                                     port_shares, port_list)

#change the dates according to what you put on top
tot_port_df = get_port_daily_return('2017-01-01', '2021-12-31', port_shares, port_list)
tot_port_df
# Out:
#                 MGIC      NSIT        ON        TTD       IDXX      BDSI  \
# Date
# 2017-01-03  0
["MGIC", "NSIT", "ON", "TTD", "IDXX", "BDSI", "CDMO", "ICLR", "MEDP", "OPRX", "RGEN", "TNDM", "XOMA",
          "CBRE", "SBAC", "ODFL", "GLDD", "HSON", "KRNT", "QRHC", "RCII", "SAIA", "SBLK", "TRNS", "HLT", "TSLA",
          "CHDN", "CLAR", "FIVE", "FOXF", "LULU", "daily_return"]

for x in del_col:
    tot_port_df = tot_port_df.drop([x], axis=1)

# %%
tot_port_df
# Out:
#                  Total
# Date
# 2017-01-03   39.534262
# 2017-01-04   39.897552
# 2017-01-05   39.591896
# 2017-01-06   39.569306
# 2017-01-07   39.569306
# ...                ...
# 2021-12-27  245.394348
# 2021-12-28  243.697569
# 2021-12-29  244.319351
# 2021-12-30  244.384989
# 2021-12-31  243.391820
#
# [1824 rows x 1 columns]

# %%
# Set style for seaborn plot
sns.set_style('darkgrid')
# Add automatic datetime converters
pd.plotting.register_matplotlib_converters()
# Default figure size
sns.mpl.rc('figure',figsize=(19, 13))

# Set fig and ax
fig, ax = plt.subplots()

# Figure out optimum lags for this data set
lags = ar_select_order(tot_port_df, maxlag=30)
print("Lags :", lags.ar_lags)

# Create our model using whole data set
model = AutoReg(tot_port_df['Total'], lags.ar_lags)
model_fit = model.fit()

# Define training and testing area
print("Observations :", len(tot_port_df)) # 1095 observations

train_df = tot_port_df.iloc[0:1459] # First 80% 
test_df = tot_port_df.iloc[1459:] # Last 20%

# Define training model for 459 days (Play with Number & Test)
# and White's covariance estimator
train_model = AutoReg(tot_port_df['Total'], 459).fit(cov_type="HC0")

# # Define start and end for prediction 
start = len(train_df)
end = len(train_df) + len(test_df) - 1

prediction = train_model.predict(start=start, end=end, dynamic=True)

# Plot testing data with prediction
ax = test_df.plot(ax=ax) # blue
ax = prediction.plot(ax=ax) # orange

# Predict 60 days into the future
forecast = train_model.predict(start=end, end=end+252, dynamic=True)
ax = forecast.plot(ax=ax) # Green
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/ar_model.py:248: FutureWarning: The parameter names will change after 0.12 is released. Set old_names to False to use the new names now. Set old_names to True to use the old names.
#   warnings.warn(
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/ar_model.py:248: FutureWarning: The parameter names will change after 0.12 is released. Set old_names to False to use the new names now. Set old_names to True to use the old names.
#   warnings.warn(
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/ar_model.py:248: FutureWarning: The parameter names will change after 0.12 is released. Set old_names to False to use the new names now. Set old_names to True to use the old names.
#   warnings.warn(
# /opt/anaconda3/lib/python3.8/site-packages/statsmodels/tsa/ar_model.py:248: FutureWarning: The parameter names will change after 0.12 is released. Set old_names to False to use the new names now. Set old_names to True to use the old names.
#   warnings.warn(
# Lags : [1]
# Observations : 1824

# %%
## Calculate annualized returns for forecasted

# %%
forecast
# Out:
# 2021-12-31    243.101373
# 2022-01-01    240.824711
# 2022-01-02    238.626986
# 2022-01-03    240.144328
# 2022-01-04    243.098429
#                  ...
# 2022-09-05    353.519671
# 2022-09-06    352.494686
# 2022-09-07    352.901521
# 2022-09-08    347.913188
# 2022-09-09    344.610348
# Freq: D, Length: 253, dtype: float64

# %%
forecast_df = pd.DataFrame(forecast)

# %%
forecast_df
# Out:
#                      0
# 2021-12-31  243.101373
# 2022-01-01  240.824711
# 2022-01-02  238.626986
# 2022-01-03  240.144328
# 2022-01-04  243.098429
# ...                ...
# 2022-09-05  353.519671
# 2022-09-06  352.494686
# 2022-09-07  352.901521
# 2022-09-08  347.913188
# 2022-09-09  344.610348
#
# [253 rows x 1 columns]

# %%
return_series = (1 + forecast_df.pct_change()).cumprod() - 1

# %%
return_series
# Out:
#                    0
# 2021-12-31       NaN
# 2022-01-01 -0.009365
# 2022-01-02 -0.018405
# 2022-01-03 -0.012164
# 2022-01-04 -0.000012
# ...              ...
# 2022-09-05  0.454207
# 2022-09-06  0.449991
# 2022-09-07  0.451664
# 2022-09-08  0.431144
# 2022-09-09  0.417558
#
# [253 rows x 1 columns]

# %%
#calculate annualized return
total_return = return_series.tail(1)

annualized_return = ((1 + total_return)**(1))-1

print(annualized_return*100)
# Out:
#                     0
# 2022-09-09  41.755822
