# %%
import pandas as pd
import numpy as np
from datetime import date
import matplotlib.pyplot as plt
import seaborn as sns
from tabulate import tabulate
from pandas_datareader import data
import matplotlib.pyplot as plt
from scipy.stats import norm
import pyfolio as pf
# %matplotlib inline
# Out:
# C:\Users\LAVANYA MARAN\anaconda3\lib\site-packages\pyfolio\pos.py:26: UserWarning: Module "zipline.assets" not found; mutltipliers will not be applied to position notionals.
#   warnings.warn(

# %%
import csv
df = pd.read_csv('Final_stock_data_V2.csv')
df
# Out:
#     ticker                             name                  sector  \
# 0      AAP          Advance Auto Parts Inc.       Consumer Cyclical
# 1      ABT              Abbott Laboratories              Healthcare
# 2      ACN                    Accenture plc              Technology
# 3      ADM   Archer-Daniels-Midland Company      Consumer Defensive
# 4      ADP  Automatic Data Processing, Inc.             Industrials
# ..     ...                              ...                     ...
# 933    XRX       Xerox Holdings Corporation              Technology
# 934     ZD                 Ziff Davis, Inc.  Communication Services
# 935   ZUMZ                      Zumiez Inc.       Consumer Cyclical
# 936   ESNT                Essent Group Ltd.      Financial Services
# 937   SAFE                    Safehold Inc.             Real Estate
#
#     Earnings_expectation        irv_status  capm_status       esg_status  \
# 0               Increase  Above Fair Price  UnderValued      Sustainable
# 1               Increase  Above Fair Price   OverValued          Average
# 2               Increase  Above Fair Price   OverValued      Sustainable
# 3               Increase  Above Fair Price   OverValued  Not Sustainable
# 4               Increase  Above Fair Price   OverValued      Sustainable
# ..                   ...               ...          ...              ...
# 933             Increase  Above Fair Price  UnderValued          No Data
# 934             Increase  Above Fair Price   OverValued          No Data
# 935             Decrease  Above Fair Price  UnderValued          No Data
# 936             Increase  Above Fair Price  UnderValued          No Data
# 937             Increase  Below Fair Price   OverValued          No Data
#
#      current_price  annu_return_10y    market_cap  ...  beta  eps_ttm  \
# 0         214.1500         0.103398  1.308405e+10  ...  1.25    9.550
# 1         118.2900         0.181179  2.091710e+11  ...  0.74    3.940
# 2         323.9050         0.208836  2.047083e+11  ...  1.21    9.613
# 3          76.9850         0.122815  4.327843e+10  ...  0.81    4.790
# 4         201.0100         0.182708  8.443324e+10  ...  0.83    6.460
# ..             ...              ...           ...  ...   ...      ...
# 933        20.6059         0.029031  3.678401e+09  ...  1.75    1.459
# 934       102.4800         0.145864  4.941668e+09  ...  1.01    4.120
# 935        42.6600         0.035214  9.777245e+08  ...  1.68    4.870
# 936        44.4800         0.082041  4.912015e+09  ...  1.33    5.569
# 937        60.4700         0.133037  3.420177e+09  ... -0.29    1.261
#
#      growth_estimate_5y  pe_forward  pe_trailing  irv_FairValue  ESG_risk  \
# 0                0.1525   13.932986    22.424082     109.188247     12.97
# 1                0.1318   22.924420    30.022842      51.234756     25.96
# 2                0.1135   31.025385    33.694477     121.148794      9.45
# 3                0.0660   14.804809    16.072025      19.449588     36.42
# 4                0.1371   26.483530    31.116098      90.801919     14.18
# ..                  ...         ...          ...            ...       ...
# 933             -0.1600   10.302950    14.123303       0.609810    999.00
# 934              0.1140   14.193907    24.873789      38.485339    999.00
# 935              0.1500    9.233767     8.759754      21.330001    999.00
# 936              0.1555    7.339934     7.987071      23.215807    999.00
# 937              0.3690   34.752872    47.954006     145.164511    999.00
#
#      capm_expected_return    AHV_5y  annu_return_5y
# 0                0.171149  0.355467        0.049267
# 1                0.109154  0.249769        0.247649
# 2                0.166287  0.254874        0.245322
# 3                0.117663  0.252289        0.150693
# 4                0.120094  0.272415        0.178939
# ..                    ...       ...             ...
# 933              0.231929  0.405374       -0.032851
# 934              0.141975  0.308007        0.055993
# 935              0.223419  0.513665        0.157523
# 936              0.180874  0.502764        0.045034
# 937             -0.016052       NaN             NaN
#
# [938 rows x 21 columns]

# %%
df['sector'].hist(xrot=90)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Filter based on 2/3 criteria

# %%
def check_criteria(each):
    check = []
    if each["capm_status"] == "UnderValued":
        check.append(True)
    if each["Earnings_expectation"] == "Increase":
        check.append(True)
    if each["irv_status"] == "Below Fair Price":
        check.append(True)
    return check

# %%
def check_number(criteria):
    if len(criteria) >= 2:
        return True
    else:
        return False

# %%
rows = []
for i in range(938):
    each = df.iloc[i]
    criteria = check_criteria(each)
    result = check_number(criteria)
    if result:
        rows.append(i)

# %%
len(rows)
# Out:
# 476

# %%
df = df.iloc[rows]
df
# Out:
#     ticker                          name              sector  \
# 0      AAP       Advance Auto Parts Inc.   Consumer Cyclical
# 5     ADSK                Autodesk, Inc.          Technology
# 11     ALK        Alaska Air Group, Inc.         Industrials
# 12    ALLE                  Allegion plc         Industrials
# 14     AMD  Advanced Micro Devices, Inc.          Technology
# ..     ...                           ...                 ...
# 931   XOMA              XOMA Corporation          Healthcare
# 932     XP                       XP Inc.  Financial Services
# 933    XRX    Xerox Holdings Corporation          Technology
# 936   ESNT             Essent Group Ltd.  Financial Services
# 937   SAFE                 Safehold Inc.         Real Estate
#
#     Earnings_expectation        irv_status  capm_status   esg_status  \
# 0               Increase  Above Fair Price  UnderValued  Sustainable
# 5               Increase  Below Fair Price  UnderValued  Sustainable
# 11              Increase  Above Fair Price  UnderValued      No Data
# 12              Increase  Above Fair Price  UnderValued      Average
# 14              Increase  Below Fair Price   OverValued      No Data
# ..                   ...               ...          ...          ...
# 931             Increase  Above Fair Price  UnderValued      No Data
# 932             Increase  Above Fair Price  UnderValued      No Data
# 933             Increase  Above Fair Price  UnderValued      No Data
# 936             Increase  Above Fair Price  UnderValued      No Data
# 937             Increase  Below Fair Price   OverValued      No Data
#
#      current_price  annu_return_10y    market_cap  ...  beta  eps_ttm  \
# 0         214.1500         0.103398  1.308405e+10  ...  1.25    9.550
# 5         217.3800         0.190997  4.781773e+10  ...  1.43    5.928
# 11         58.9750         0.141697  7.425660e+09  ...  1.55    3.770
# 12        114.1447         0.097180  1.023831e+10  ...  1.14    5.086
# 14        117.1100         0.319034  1.414232e+11  ...  1.95    3.242
# ..             ...              ...           ...  ...   ...      ...
# 931        20.7600        -0.034853  2.348205e+08  ...  0.81    0.082
# 932        34.1100        -0.001020  1.908622e+10  ...  1.91    0.986
# 933        20.6059         0.029031  3.678401e+09  ...  1.75    1.459
# 936        44.4800         0.082041  4.912015e+09  ...  1.33    5.569
# 937        60.4700         0.133037  3.420177e+09  ... -0.29    1.261
#
#      growth_estimate_5y  pe_forward  pe_trailing  irv_FairValue  ESG_risk  \
# 0                0.1525   13.932986    22.424082     109.188247     12.97
# 5                0.2883   31.967648    36.670040     302.038344     15.45
# 11              -0.2340    9.073076    15.643236       0.761055    999.00
# 12               0.0777   19.955368    22.442923      31.814578     23.59
# 14               0.3532   35.062874    36.122765     253.245268    999.00
# ..                  ...         ...          ...            ...       ...
# 931              0.1900  -90.260870   253.170730      14.120154    999.00
# 932              0.0478   27.508064    34.594322       7.380346    999.00
# 933             -0.1600   10.302950    14.123303       0.609810    999.00
# 936              0.1555    7.339934     7.987071      23.215807    999.00
# 937              0.3690   34.752872    47.954006     145.164511    999.00
#
#      capm_expected_return    AHV_5y  annu_return_5y
# 0                0.171149  0.355467        0.049267
# 5                0.193030  0.384894        0.209161
# 11               0.207617  0.454054       -0.086043
# 12               0.157777  0.279213        0.118004
# 14               0.256240  0.564107        0.569607
# ..                    ...       ...             ...
# 931              0.117663  0.689078        0.371572
# 932              0.251378       NaN             NaN
# 933              0.231929  0.405374       -0.032851
# 936              0.180874  0.502764        0.045034
# 937             -0.016052       NaN             NaN
#
# [476 rows x 21 columns]

# %%
#total number of stocks for each sector 

df["sector"].value_counts()
# Out:
# Industrials               93
# Technology                89
# Consumer Cyclical         79
# Financial Services        68
# Healthcare                52
# Communication Services    29
# Basic Materials           20
# Consumer Defensive        19
# Energy                    15
# Real Estate               11
# Utilities                  1
# Name: sector, dtype: int64

# %%
#df for each sector

df_basic_materials = df.loc[df['sector'] == 'Basic Materials']
df_communication = df.loc[df['sector'] == 'Communication Services']
df_consumer_c = df.loc[df['sector'] == 'Consumer Cyclical']
df_consumer_d = df.loc[df['sector'] == 'Consumer Defensive']
df_energy = df.loc[df['sector'] == 'Energy']
df_financial = df.loc[df['sector'] == 'Financial Services']
df_healthcare = df.loc[df['sector'] == 'Healthcare']
df_industrials = df.loc[df['sector'] == 'Industrials']
df_real_estate = df.loc[df['sector'] == 'Real Estate']
df_tech = df.loc[df['sector'] == 'Technology']
df_utilites = df.loc[df['sector'] == 'Utilities']

# %% [markdown]
# ## Selection of Sector based on Returns

# %%
#calculating the average returns

basic_returns = df_basic_materials['annu_return_5y'].mean()
comm_returns = df_communication['annu_return_5y'].mean()
consumer_c_returns = df_consumer_c['annu_return_5y'].mean()
consumer_d_returns = df_consumer_d['annu_return_5y'].mean()
energy_returns = df_energy['annu_return_5y'].mean()
financial_returns = df_financial['annu_return_5y'].mean()
healthcare_returns = df_healthcare['annu_return_5y'].mean()
industrials_returns = df_industrials['annu_return_5y'].mean()
real_estate_returns = df_real_estate['annu_return_5y'].mean()
tech_returns = df_tech['annu_return_5y'].mean()
utilities_returns = df_utilites['annu_return_5y'].mean()

print(tabulate([['Basic Materials', basic_returns],['Communication Services', comm_returns],['Consumer Cyclical', consumer_c_returns],['Consumer Defensive', consumer_d_returns], ['Energy', energy_returns], ['Financial Services', financial_returns], ['Healthcare', healthcare_returns], ['Industrials', industrials_returns], ['Real Estate', real_estate_returns], ['Technology', tech_returns], ['Utilities', utilities_returns]],
               headers=['Sector','Annual Returns']))
# Out:
# Sector                    Annual Returns
# ----------------------  ----------------
# Basic Materials                0.0631966
# Communication Services         0.0340231
# Consumer Cyclical              0.0942812
# Consumer Defensive             0.049066
# Energy                         0.0551988
# Financial Services             0.03874
# Healthcare                     0.101074
# Industrials                    0.0855473
# Real Estate                    0.106064
# Technology                     0.123625
# Utilities                      0.118782

# %% [markdown]
# From above, the top 3 sectors that give the highest returns is Technology (0.123625), Utilities (0.118782), Real Estate (0.106064). These will be the chosen sectors for the aggressive model.

# %%
#combining the top 3 sectors into 1 dataframe

df2 = pd.concat([df_tech, df_utilites, df_real_estate])
df2
# Out:
#     ticker                             name       sector Earnings_expectation  \
# 5     ADSK                   Autodesk, Inc.   Technology             Increase
# 14     AMD     Advanced Micro Devices, Inc.   Technology             Increase
# 17    ANSS                      ANSYS, Inc.   Technology             Increase
# 57    CTSH  Cognizant Technology Solutions    Technology             Increase
# 73    EPAM               EPAM Systems, Inc.   Technology             Increase
# ..     ...                              ...          ...                  ...
# 485   GOOD  Gladstone Commercial Corporatio  Real Estate             Increase
# 581   LAMR        Lamar Advertising Company  Real Estate             Increase
# 614   LSEA        Landsea Homes Corporation  Real Estate             Increase
# 906   UNIT                 Uniti Group Inc.  Real Estate             Increase
# 937   SAFE                    Safehold Inc.  Real Estate             Increase
#
#            irv_status  capm_status   esg_status  current_price  \
# 5    Below Fair Price  UnderValued  Sustainable       217.3800
# 14   Below Fair Price   OverValued      No Data       117.1100
# 17   Above Fair Price  UnderValued  Sustainable       305.4575
# 57   Above Fair Price  UnderValued  Sustainable        85.7600
# 73   Below Fair Price   OverValued      No Data       428.8350
# ..                ...          ...          ...            ...
# 485  Above Fair Price  UnderValued      No Data        21.0900
# 581  Above Fair Price  UnderValued  Sustainable       109.8500
# 614  Below Fair Price  UnderValued      No Data         6.5600
# 906  Below Fair Price  UnderValued      No Data        11.0850
# 937  Below Fair Price   OverValued      No Data        60.4700
#
#      annu_return_10y    market_cap  ...  beta  eps_ttm  growth_estimate_5y  \
# 5           0.190997  4.781773e+10  ...  1.43    5.928              0.2883
# 14          0.319034  1.414232e+11  ...  1.95    3.242              0.3532
# 17          0.163292  2.665208e+10  ...  1.24    5.318              0.1118
# 57          0.098598  4.556764e+10  ...  1.13    3.545              0.1398
# 73          0.408649  2.432335e+10  ...  1.43    7.211              0.2850
# ..               ...           ...  ...   ...      ...                 ...
# 485         0.095257  7.859906e+08  ...  1.00    0.029              0.0600
# 581         0.167806  1.112110e+10  ...  1.44    3.689              0.0300
# 614        -0.037662  3.036040e+08  ...  0.14    0.531              0.4860
# 906        -0.039440  2.616847e+09  ...  1.05    0.171              0.3400
# 937         0.133037  3.420177e+09  ... -0.29    1.261              0.3690
#
#       pe_forward  pe_trailing  irv_FairValue  ESG_risk  capm_expected_return  \
# 5      31.967648    36.670040     302.038344     15.45              0.193030
# 14     35.062874    36.122765     253.245268    999.00              0.256240
# 17     38.470715    57.438416     112.688671     13.16              0.169933
# 57     18.973452    24.191820      39.576018     17.47              0.156562
# 73     38.391674    59.469560     582.247739    999.00              0.193030
# ..           ...          ...            ...       ...                   ...
# 485 -2109.000000   727.241400       5.064293    999.00              0.140759
# 581    23.422174    29.777718      20.371571     16.28              0.194245
# 614     4.315790    12.354049      32.942956    999.00              0.036218
# 906    17.879032    64.824560      21.946654    999.00              0.146837
# 937    34.752872    47.954006     145.164511    999.00             -0.016052
#
#        AHV_5y  annu_return_5y
# 5    0.384894        0.209161
# 14   0.564107        0.569607
# 17   0.316793        0.271663
# 57   0.290279        0.115536
# 73   0.376405        0.422642
# ..        ...             ...
# 485  0.386789        0.084844
# 581  0.413550        0.128521
# 614       NaN             NaN
# 906  0.546158       -0.087307
# 937       NaN             NaN
#
# [101 rows x 21 columns]

# %% [markdown]
# ## Filtering Stocks based on Sharpe Ratio

# %%
def get_closeprice(ticker):    
    start_date = str(date.today().year - 5) +'-0'+ str(date.today().month) +'-'+ str(date.today().day)
    end_date = str(date.today())
    
    panel_data = data.DataReader([ticker],'yahoo', start_date, end_date)
    closes = panel_data[["Close", "Adj Close"]]
    
    return closes

# %%
def get_sharpe_ratio(ticker):
    
    closes = get_closeprice(ticker)
    adj_close = closes["Adj Close"]
    
    risk_free_ann_ret_rate = 0.0195  #assuming this rate based on the latest data
     
    #Rp
    returns_ts = adj_close.pct_change().dropna()
    
    #Average Rp
    avg_daily_ret = returns_ts.mean()

    #Average risk-free rate for the year (Annual rate / number of trading days to spread it out)
    returns_ts['RiskFree_Rate'] = risk_free_ann_ret_rate/252

    #Average Rf
    avg_rf_ret = returns_ts['RiskFree_Rate'].mean()

    #calculate sharpe ratio

    #Add the excess return columns for each ETF: Rp - Rf
    returns_ts['Excess_ret'] = returns_ts[ticker] - returns_ts['RiskFree_Rate']
    
    sharpe = ((avg_daily_ret[ticker] - avg_rf_ret) /returns_ts['Excess_ret'].std())*np.sqrt(252)

    return sharpe.round(3)

# %%
sharpe_list = []
for i in range(len(df2)):
    each = df2.iloc[i]
    ticker = each["ticker"]
    sharpe = get_sharpe_ratio(ticker)
    sharpe_list.append(sharpe)

# %%
sharpe_list
# Out:
# [0.611,
#  0.98,
#  0.776,
#  0.426,
#  0.814,
#  0.385,
#  0.178,
#  0.423,
#  0.615,
#  0.547,
#  0.513,
#  0.731,
#  0.477,
#  0.07,
#  0.206,
#  0.51,
#  0.662,
#  1.395,
#  1.065,
#  0.084,
#  0.48,
#  0.841,
#  0.147,
#  0.367,
#  0.163,
#  0.457,
#  0.303,
#  -0.317,
#  0.301,
#  0.479,
#  0.553,
#  0.362,
#  0.271,
#  0.392,
#  -0.241,
#  0.4,
#  0.808,
#  0.912,
#  0.17,
#  -0.068,
#  0.494,
#  0.369,
#  0.001,
#  0.074,
#  0.406,
#  0.495,
#  0.473,
#  0.085,
#  0.563,
#  0.694,
#  0.115,
#  0.666,
#  0.694,
#  0.579,
#  0.558,
#  0.559,
#  0.361,
#  0.316,
#  0.644,
#  0.018,
#  0.024,
#  0.141,
#  0.106,
#  0.482,
#  0.766,
#  0.205,
#  0.31,
#  -0.054,
#  0.381,
#  0.359,
#  0.701,
#  0.436,
#  0.572,
#  0.89,
#  0.603,
#  0.17,
#  0.114,
#  0.725,
#  1.807,
#  0.43,
#  0.505,
#  0.501,
#  1.128,
#  0.612,
#  -0.081,
#  0.046,
#  0.684,
#  0.037,
#  0.06,
#  0.495,
#  0.159,
#  0.654,
#  0.605,
#  0.846,
#  0.35,
#  0.82,
#  0.397,
#  0.441,
#  -0.053,
#  0.163,
#  0.785]

# %%
df2["sharpe"] = sharpe_list
df2
# Out:
#     ticker                             name       sector Earnings_expectation  \
# 5     ADSK                   Autodesk, Inc.   Technology             Increase
# 14     AMD     Advanced Micro Devices, Inc.   Technology             Increase
# 17    ANSS                      ANSYS, Inc.   Technology             Increase
# 57    CTSH  Cognizant Technology Solutions    Technology             Increase
# 73    EPAM               EPAM Systems, Inc.   Technology             Increase
# ..     ...                              ...          ...                  ...
# 485   GOOD  Gladstone Commercial Corporatio  Real Estate             Increase
# 581   LAMR        Lamar Advertising Company  Real Estate             Increase
# 614   LSEA        Landsea Homes Corporation  Real Estate             Increase
# 906   UNIT                 Uniti Group Inc.  Real Estate             Increase
# 937   SAFE                    Safehold Inc.  Real Estate             Increase
#
#            irv_status  capm_status   esg_status  current_price  \
# 5    Below Fair Price  UnderValued  Sustainable       217.3800
# 14   Below Fair Price   OverValued      No Data       117.1100
# 17   Above Fair Price  UnderValued  Sustainable       305.4575
# 57   Above Fair Price  UnderValued  Sustainable        85.7600
# 73   Below Fair Price   OverValued      No Data       428.8350
# ..                ...          ...          ...            ...
# 485  Above Fair Price  UnderValued      No Data        21.0900
# 581  Above Fair Price  UnderValued  Sustainable       109.8500
# 614  Below Fair Price  UnderValued      No Data         6.5600
# 906  Below Fair Price  UnderValued      No Data        11.0850
# 937  Below Fair Price   OverValued      No Data        60.4700
#
#      annu_return_10y    market_cap  ... eps_ttm  growth_estimate_5y  \
# 5           0.190997  4.781773e+10  ...   5.928              0.2883
# 14          0.319034  1.414232e+11  ...   3.242              0.3532
# 17          0.163292  2.665208e+10  ...   5.318              0.1118
# 57          0.098598  4.556764e+10  ...   3.545              0.1398
# 73          0.408649  2.432335e+10  ...   7.211              0.2850
# ..               ...           ...  ...     ...                 ...
# 485         0.095257  7.859906e+08  ...   0.029              0.0600
# 581         0.167806  1.112110e+10  ...   3.689              0.0300
# 614        -0.037662  3.036040e+08  ...   0.531              0.4860
# 906        -0.039440  2.616847e+09  ...   0.171              0.3400
# 937         0.133037  3.420177e+09  ...   1.261              0.3690
#
#       pe_forward  pe_trailing  irv_FairValue  ESG_risk  capm_expected_return  \
# 5      31.967648    36.670040     302.038344     15.45              0.193030
# 14     35.062874    36.122765     253.245268    999.00              0.256240
# 17     38.470715    57.438416     112.688671     13.16              0.169933
# 57     18.973452    24.191820      39.576018     17.47              0.156562
# 73     38.391674    59.469560     582.247739    999.00              0.193030
# ..           ...          ...            ...       ...                   ...
# 485 -2109.000000   727.241400       5.064293    999.00              0.140759
# 581    23.422174    29.777718      20.371571     16.28              0.194245
# 614     4.315790    12.354049      32.942956    999.00              0.036218
# 906    17.879032    64.824560      21.946654    999.00              0.146837
# 937    34.752872    47.954006     145.164511    999.00             -0.016052
#
#        AHV_5y  annu_return_5y  sharpe
# 5    0.384894        0.209161   0.611
# 14   0.564107        0.569607   0.980
# 17   0.316793        0.271663   0.776
# 57   0.290279        0.115536   0.426
# 73   0.376405        0.422642   0.814
# ..        ...             ...     ...
# 485  0.386789        0.084844   0.397
# 581  0.413550        0.128521   0.441
# 614       NaN             NaN  -0.053
# 906  0.546158       -0.087307   0.163
# 937       NaN             NaN   0.785
#
# [101 rows x 22 columns]

# %%
#only choosing stocks which has a sharpe ratio of more than 0.6 

df3 = df2[df2["sharpe"] > 0.6]
df3
# Out:
#     ticker                             name       sector Earnings_expectation  \
# 5     ADSK                   Autodesk, Inc.   Technology             Increase
# 14     AMD     Advanced Micro Devices, Inc.   Technology             Increase
# 17    ANSS                      ANSYS, Inc.   Technology             Increase
# 73    EPAM               EPAM Systems, Inc.   Technology             Increase
# 155   NTAP                     NetApp, Inc.   Technology             Increase
# 176   QCOM            QUALCOMM Incorporated   Technology             Increase
# 243   AOSL  Alpha and Omega Semiconductor L   Technology             Increase
# 244   APPS            Digital Turbine, Inc.   Technology             Increase
# 249   ASML  ASML Holding N.V. - New York Re   Technology             Increase
# 258   AUDC                  AudioCodes Ltd.   Technology             Increase
# 381   DIOD              Diodes Incorporated   Technology             Increase
# 386   DSGX  The Descartes Systems Group Inc   Technology             Increase
# 555   INOD                    Innodata Inc.   Technology             Increase
# 621   MANT  ManTech International Corporati   Technology             Increase
# 639   MGIC  Magic Software Enterprises Ltd.   Technology             Increase
# 686   NSIT        Insight Enterprises, Inc.   Technology             Increase
# 708     ON     ON Semiconductor Corporation   Technology             Increase
# 751   POWI         Power Integrations, Inc.   Technology             Increase
# 781   RIOT             Riot Blockchain, Inc   Technology             Increase
# 783   RMBS                     Rambus, Inc.   Technology             Increase
# 818    SGH      SMART Global Holdings, Inc.   Technology             Increase
# 825   SITM               SiTime Corporation   Technology             Increase
# 890    TTD             The Trade Desk, Inc.   Technology             Increase
# 901   UCTT       Ultra Clean Holdings, Inc.   Technology             Increase
# 923   WDAY                    Workday, Inc.   Technology             Increase
# 39    CBRE                   CBRE Group Inc  Real Estate             Increase
# 74    EQIX                    Equinix, Inc.  Real Estate             Increase
# 184   SBAC   SBA Communications Corporation  Real Estate             Increase
# 416   EXPI         eXp World Holdings, Inc.  Real Estate             Increase
# 937   SAFE                    Safehold Inc.  Real Estate             Increase
#
#            irv_status  capm_status   esg_status  current_price  \
# 5    Below Fair Price  UnderValued  Sustainable       217.3800
# 14   Below Fair Price   OverValued      No Data       117.1100
# 17   Above Fair Price  UnderValued  Sustainable       305.4575
# 73   Below Fair Price   OverValued      No Data       428.8350
# 155  Above Fair Price  UnderValued  Sustainable        88.2150
# 176  Below Fair Price  UnderValued  Sustainable       165.6500
# 243  Above Fair Price  UnderValued      No Data        49.2600
# 244  Below Fair Price  UnderValued      No Data        43.8000
# 249  Below Fair Price   OverValued      No Data       634.7900
# 258  Below Fair Price   OverValued      No Data        27.6750
# 381  Above Fair Price  UnderValued      No Data        87.1300
# 386  Below Fair Price   OverValued      No Data        69.6200
# 555  Above Fair Price  UnderValued      No Data         5.0600
# 621  Above Fair Price  UnderValued      No Data        78.5700
# 639  Above Fair Price  UnderValued      No Data        18.3000
# 686  Above Fair Price  UnderValued      No Data        99.4000
# 708  Below Fair Price  UnderValued      Average        58.4400
# 751  Below Fair Price   OverValued      No Data        87.7500
# 781  Above Fair Price  UnderValued      No Data        15.9500
# 783  Above Fair Price  UnderValued      No Data        26.2900
# 818  Below Fair Price   OverValued      No Data        28.9900
# 825  Below Fair Price   OverValued      No Data       188.8200
# 890  Below Fair Price   OverValued      No Data        73.6800
# 901  Above Fair Price  UnderValued      No Data        45.8500
# 923  Above Fair Price  UnderValued  Sustainable       216.5600
# 39   Above Fair Price  UnderValued  Sustainable        99.5300
# 74   Below Fair Price   OverValued  Sustainable       681.0200
# 184  Below Fair Price   OverValued  Sustainable       297.1600
# 416  Above Fair Price  UnderValued      No Data        25.1500
# 937  Below Fair Price   OverValued      No Data        60.4700
#
#      annu_return_10y    market_cap  ... eps_ttm  growth_estimate_5y  \
# 5           0.190997  4.781773e+10  ...   5.928              0.2883
# 14          0.319034  1.414232e+11  ...   3.242              0.3532
# 17          0.163292  2.665208e+10  ...   5.318              0.1118
# 73          0.408649  2.432335e+10  ...   7.211              0.2850
# 155         0.095312  1.960825e+10  ...   4.113              0.0880
# 176         0.130769  1.855280e+11  ...   7.870              0.2562
# 243         0.165397  1.299356e+09  ...   2.612              0.1700
# 244         0.278657  4.232205e+09  ...   0.530              0.5000
# 249         0.341963  2.580256e+11  ...  15.017              0.2980
# 258         0.234188  9.141052e+08  ...   1.028              0.2500
# 381         0.131229  3.922401e+09  ...   4.123              0.1500
# 386         0.240316  5.893862e+09  ...   0.980              0.2600
# 555        -0.007579  1.373967e+08  ...   0.017              0.2000
# 621         0.109370  3.200871e+09  ...   3.401              0.0538
# 639         0.134997  9.082454e+08  ...   0.570              0.1000
# 686         0.162830  3.467649e+09  ...   5.767              0.0744
# 708         0.204125  2.517794e+10  ...   1.532              0.5545
# 751         0.172236  5.294107e+09  ...   2.458              0.2529
# 781         0.208131  1.859499e+09  ...   0.188              0.2000
# 783         0.131836  2.875206e+09  ...   0.002              0.0998
# 818         0.155233  7.154384e+08  ...   0.830              0.3606
# 825         0.302106  3.881006e+09  ...   0.727              1.2498
# 890         0.376786  3.793717e+10  ...   0.561              0.2800
# 901         0.183616  2.058665e+09  ...   2.230              0.2000
# 923         0.160951  5.414000e+10  ...   0.117              0.1579
# 39          0.182808  3.330930e+10  ...   4.290              0.1100
# 74          0.198920  6.131986e+10  ...   4.743              0.3700
# 184         0.204253  3.232536e+10  ...   2.606              1.8932
# 416         0.156613  3.710555e+09  ...   0.467              0.1000
# 937         0.133037  3.420177e+09  ...   1.261              0.3690
#
#      pe_forward   pe_trailing  irv_FairValue  ESG_risk  capm_expected_return  \
# 5     31.967648     36.670040     302.038344     15.45              0.193030
# 14    35.062874     36.122765     253.245268    999.00              0.256240
# 17    38.470715     57.438416     112.688671     13.16              0.169933
# 73    38.391674     59.469560     582.247739    999.00              0.193030
# 155   16.009981     21.447847      26.785016     16.58              0.166287
# 176   14.231099     21.048285     183.404501     18.00              0.173580
# 243   11.617925     18.859112      28.764485    999.00              0.330391
# 244   20.372091     82.641510     239.323247    999.00              0.285415
# 249   32.420326     42.271423     943.608234    999.00              0.134681
# 258   16.875000     26.921206      29.306718    999.00              0.084842
# 381   14.919519     21.132670      43.564999    999.00              0.148053
# 386   66.942314     71.040820      79.206056    999.00              0.144406
# 555 -101.200000    297.647030       3.710831    999.00              0.268396
# 621   22.512894     23.102028      17.896575    999.00              0.115232
# 639   17.428572     32.105263       6.133024    999.00              0.188167
# 686   12.925878     17.235998      26.950686    999.00              0.234360
# 708   17.926380     38.146214     440.267051     26.16              0.230713
# 751   26.753050     35.699757      94.882094    999.00              0.138328
# 781    8.763736     84.840430      11.697185    999.00              0.539473
# 783   18.006850  13145.000000       8.796370    999.00              0.139544
# 818    4.288461     34.927710      65.843339    999.00              0.148053
# 825   55.049564    259.724900   39630.782889    999.00              0.143190
# 890   80.967030    131.336900      96.589249    999.00              0.302433
# 901    9.713984     20.560537      33.624820    999.00              0.261103
# 923   60.831463   1850.940200     115.161464     13.09              0.183305
# 39    17.647163     23.200466      36.186806      6.99              0.189383
# 74    88.100910    143.584230    1645.638404     14.71              0.062961
# 184   74.663315    114.029170  599909.754404     14.52              0.056883
# 416   36.985294     53.854390       8.428719    999.00              0.397249
# 937   34.752872     47.954006     145.164511    999.00             -0.016052
#
#        AHV_5y  annu_return_5y  sharpe
# 5    0.384894        0.209161   0.611
# 14   0.564107        0.569607   0.980
# 17   0.316793        0.271663   0.776
# 73   0.376405        0.422642   0.814
# 155  0.373202        0.185306   0.615
# 176  0.375961        0.297623   0.731
# 243  0.570794        0.201750   0.662
# 244  0.719036        1.325025   1.395
# 249  0.360669        0.411064   1.065
# 258  0.446357        0.362672   0.841
# 381  0.401822        0.286506   0.808
# 386  0.291432        0.265617   0.912
# 555  0.669394        0.192740   0.694
# 621  0.344249        0.170329   0.666
# 639  0.334100        0.227677   0.694
# 686  0.366896        0.221251   0.644
# 708  0.507655        0.343777   0.766
# 751  0.396886        0.226355   0.701
# 781  1.229896        0.422364   0.890
# 783  0.349622        0.160927   0.603
# 818       NaN             NaN   0.725
# 825       NaN             NaN   1.807
# 890  0.683392        0.956083   1.128
# 901  0.610451        0.290763   0.612
# 923  0.383779        0.213788   0.684
# 39   0.351216        0.244065   0.654
# 74   0.272286        0.148163   0.605
# 184  0.267604        0.237268   0.846
# 416       NaN             NaN   0.820
# 937       NaN             NaN   0.785
#
# [30 rows x 22 columns]

# %% [markdown]
# ## Correlation between Stocks

# %%
def get_return_series(ticker):
    closes = get_closeprice(ticker)
    return_series_close = (closes['Close'].pct_change()+ 1).cumprod() - 1
    return return_series_close

# %%
returns_list = []
for i in range(len(df3)):
    each = df3.iloc[i]
    ticker = each["ticker"]
    returns = get_return_series(ticker)
    if (len(returns) == 1260):
        returns_list.append(returns)

# %%
returns_list
# Out:
# [Symbols           TTD
#  Date
#  2017-03-20        NaN
#  2017-03-21  -0.014436
#  2017-03-22   0.014173
#  2017-03-23  -0.028346
#  2017-03-24  -0.054593
#  ...               ...
#  2022-03-14  12.774278
#  2022-03-15  13.139108
#  2022-03-16  14.829397
#  2022-03-17  16.167980
#  2022-03-18  17.060367
#
#  [1260 rows x 1 columns],
#  Symbols         UCTT
#  Date
#  2017-03-20       NaN
#  2017-03-21 -0.054293
#  2017-03-22 -0.049242
#  2017-03-23 -0.029040
#  2017-03-24 -0.011364
#  ...              ...
#  2022-03-14  1.392677
#  2022-03-15  1.471591
#  2022-03-16  1.702652
#  2022-03-17  1.788510
#  2022-03-18  1.826389
#
#  [1260 rows x 1 columns],
#  Symbols         WDAY
#  Date
#  2017-03-20       NaN
#  2017-03-21 -0.043041
#  2017-03-22 -0.047368
#  2017-03-23 -0.047134
#  2017-03-24 -0.029825
#  ...              ...
#  2022-03-14  1.583743
#  2022-03-15  1.589708
#  2022-03-16  1.660468
#  2022-03-17  1.752047
#  2022-03-18  1.849123
#
#  [1260 rows x 1 columns],
#  Symbols         CBRE
#  Date
#  2017-03-20       NaN
#  2017-03-21 -0.010970
#  2017-03-22 -0.018847
#  2017-03-23 -0.016878
#  2017-03-24 -0.032911
#  ...              ...
#  2022-03-14  1.458509
#  2022-03-15  1.463291
#  2022-03-16  1.558931
#  2022-03-17  1.561182
#  2022-03-18  1.562307
#
#  [1260 rows x 1 columns],
#  Symbols         EQIX
#  Date
#  2017-03-20       NaN
#  2017-03-21 -0.000417
#  2017-03-22  0.010168
#  2017-03-23  0.011680
#  2017-03-24  0.011784
#  ...              ...
#  2022-03-14  0.782204
#  2022-03-15  0.829236
#  2022-03-16  0.835545
#  2022-03-17  0.876737
#  2022-03-18  0.909065
#
#  [1260 rows x 1 columns],
#  Symbols         SBAC
#  Date
#  2017-03-20       NaN
#  2017-03-21  0.000171
#  2017-03-22 -0.001538
#  2017-03-23  0.009141
#  2017-03-24  0.010507
#  ...              ...
#  2022-03-14  1.739621
#  2022-03-15  1.752776
#  2022-03-16  1.783701
#  2022-03-17  1.819665
#  2022-03-18  1.824449
#
#  [1260 rows x 1 columns]]

# %%
return_series_close = pd.concat(returns_list, axis=1)
return_series_close
# Out:
# Symbols           TTD      UCTT      WDAY      CBRE      EQIX      SBAC
# Date
# 2017-03-20        NaN       NaN       NaN       NaN       NaN       NaN
# 2017-03-21  -0.014436 -0.054293 -0.043041 -0.010970 -0.000417  0.000171
# 2017-03-22   0.014173 -0.049242 -0.047368 -0.018847  0.010168 -0.001538
# 2017-03-23  -0.028346 -0.029040 -0.047134 -0.016878  0.011680  0.009141
# 2017-03-24  -0.054593 -0.011364 -0.029825 -0.032911  0.011784  0.010507
# ...               ...       ...       ...       ...       ...       ...
# 2022-03-14  12.774278  1.392677  1.583743  1.458509  0.782204  1.739621
# 2022-03-15  13.139108  1.471591  1.589708  1.463291  0.829236  1.752776
# 2022-03-16  14.829397  1.702652  1.660468  1.558931  0.835545  1.783701
# 2022-03-17  16.167980  1.788510  1.752047  1.561182  0.876737  1.819665
# 2022-03-18  17.060367  1.826389  1.849123  1.562307  0.909065  1.824449
#
# [1260 rows x 6 columns]

# %%
return_series_close.plot(figsize=(16,9))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
highest = return_series_close[return_series_close.tail(1) > 5]

# %%
highest.dropna(axis=1, how="all")
# Out:
# Symbols           TTD
# Date
# 2017-03-20        NaN
# 2017-03-21        NaN
# 2017-03-22        NaN
# 2017-03-23        NaN
# 2017-03-24        NaN
# ...               ...
# 2022-03-14        NaN
# 2022-03-15        NaN
# 2022-03-16        NaN
# 2022-03-17        NaN
# 2022-03-18  17.060367
#
# [1260 rows x 1 columns]

# %%
correlation = return_series_close.corr()
# correlation
fig, ax = plt.subplots(figsize=(16,10))
sns.heatmap(correlation, annot = True, ax = ax, cmap="YlGnBu")
# Out:
# <AxesSubplot:xlabel='Symbols', ylabel='Symbols'>

# %%
#only choosing stocks with correlation less than 1 for diversification

correlation = correlation[correlation < 0.1]
correlation
# Out:
# Symbols  TTD  UCTT  WDAY  CBRE  EQIX  SBAC
# Symbols
# TTD      NaN   NaN   NaN   NaN   NaN   NaN
# UCTT     NaN   NaN   NaN   NaN   NaN   NaN
# WDAY     NaN   NaN   NaN   NaN   NaN   NaN
# CBRE     NaN   NaN   NaN   NaN   NaN   NaN
# EQIX     NaN   NaN   NaN   NaN   NaN   NaN
# SBAC     NaN   NaN   NaN   NaN   NaN   NaN

# %% [markdown]
# ## Final DF

# %%
all_stocks = []
for each in correlation:
    all_stocks.append(each)

# %%
indexes = []
for i in range(len(df3)):
    each = df3.iloc[i]
    ticker = each["ticker"]
    if ticker in all_stocks:
        indexes.append(i)

# %%
chosen_df = df3.iloc[indexes]
chosen_df
# Out:
#     ticker                             name       sector Earnings_expectation  \
# 14     AMD     Advanced Micro Devices, Inc.   Technology             Increase
# 17    ANSS                      ANSYS, Inc.   Technology             Increase
# 73    EPAM               EPAM Systems, Inc.   Technology             Increase
# 176   QCOM            QUALCOMM Incorporated   Technology             Increase
# 243   AOSL  Alpha and Omega Semiconductor L   Technology             Increase
# 244   APPS            Digital Turbine, Inc.   Technology             Increase
# 249   ASML  ASML Holding N.V. - New York Re   Technology             Increase
# 258   AUDC                  AudioCodes Ltd.   Technology             Increase
# 381   DIOD              Diodes Incorporated   Technology             Increase
# 386   DSGX  The Descartes Systems Group Inc   Technology             Increase
# 555   INOD                    Innodata Inc.   Technology             Increase
# 621   MANT  ManTech International Corporati   Technology             Increase
# 639   MGIC  Magic Software Enterprises Ltd.   Technology             Increase
# 686   NSIT        Insight Enterprises, Inc.   Technology             Increase
# 708     ON     ON Semiconductor Corporation   Technology             Increase
# 751   POWI         Power Integrations, Inc.   Technology             Increase
# 781   RIOT             Riot Blockchain, Inc   Technology             Increase
# 890    TTD             The Trade Desk, Inc.   Technology             Increase
# 901   UCTT       Ultra Clean Holdings, Inc.   Technology             Increase
# 923   WDAY                    Workday, Inc.   Technology             Increase
# 39    CBRE                   CBRE Group Inc  Real Estate             Increase
# 74    EQIX                    Equinix, Inc.  Real Estate             Increase
# 184   SBAC   SBA Communications Corporation  Real Estate             Increase
#
#            irv_status  capm_status   esg_status  current_price  \
# 14   Below Fair Price   OverValued      No Data       117.1100
# 17   Above Fair Price  UnderValued  Sustainable       305.4575
# 73   Below Fair Price   OverValued      No Data       428.8350
# 176  Below Fair Price  UnderValued  Sustainable       165.6500
# 243  Above Fair Price  UnderValued      No Data        49.2600
# 244  Below Fair Price  UnderValued      No Data        43.8000
# 249  Below Fair Price   OverValued      No Data       634.7900
# 258  Below Fair Price   OverValued      No Data        27.6750
# 381  Above Fair Price  UnderValued      No Data        87.1300
# 386  Below Fair Price   OverValued      No Data        69.6200
# 555  Above Fair Price  UnderValued      No Data         5.0600
# 621  Above Fair Price  UnderValued      No Data        78.5700
# 639  Above Fair Price  UnderValued      No Data        18.3000
# 686  Above Fair Price  UnderValued      No Data        99.4000
# 708  Below Fair Price  UnderValued      Average        58.4400
# 751  Below Fair Price   OverValued      No Data        87.7500
# 781  Above Fair Price  UnderValued      No Data        15.9500
# 890  Below Fair Price   OverValued      No Data        73.6800
# 901  Above Fair Price  UnderValued      No Data        45.8500
# 923  Above Fair Price  UnderValued  Sustainable       216.5600
# 39   Above Fair Price  UnderValued  Sustainable        99.5300
# 74   Below Fair Price   OverValued  Sustainable       681.0200
# 184  Below Fair Price   OverValued  Sustainable       297.1600
#
#      annu_return_10y    market_cap  ... eps_ttm  growth_estimate_5y  \
# 14          0.319034  1.414232e+11  ...   3.242              0.3532
# 17          0.163292  2.665208e+10  ...   5.318              0.1118
# 73          0.408649  2.432335e+10  ...   7.211              0.2850
# 176         0.130769  1.855280e+11  ...   7.870              0.2562
# 243         0.165397  1.299356e+09  ...   2.612              0.1700
# 244         0.278657  4.232205e+09  ...   0.530              0.5000
# 249         0.341963  2.580256e+11  ...  15.017              0.2980
# 258         0.234188  9.141052e+08  ...   1.028              0.2500
# 381         0.131229  3.922401e+09  ...   4.123              0.1500
# 386         0.240316  5.893862e+09  ...   0.980              0.2600
# 555        -0.007579  1.373967e+08  ...   0.017              0.2000
# 621         0.109370  3.200871e+09  ...   3.401              0.0538
# 639         0.134997  9.082454e+08  ...   0.570              0.1000
# 686         0.162830  3.467649e+09  ...   5.767              0.0744
# 708         0.204125  2.517794e+10  ...   1.532              0.5545
# 751         0.172236  5.294107e+09  ...   2.458              0.2529
# 781         0.208131  1.859499e+09  ...   0.188              0.2000
# 890         0.376786  3.793717e+10  ...   0.561              0.2800
# 901         0.183616  2.058665e+09  ...   2.230              0.2000
# 923         0.160951  5.414000e+10  ...   0.117              0.1579
# 39          0.182808  3.330930e+10  ...   4.290              0.1100
# 74          0.198920  6.131986e+10  ...   4.743              0.3700
# 184         0.204253  3.232536e+10  ...   2.606              1.8932
#
#      pe_forward  pe_trailing  irv_FairValue  ESG_risk  capm_expected_return  \
# 14    35.062874    36.122765     253.245268    999.00              0.256240
# 17    38.470715    57.438416     112.688671     13.16              0.169933
# 73    38.391674    59.469560     582.247739    999.00              0.193030
# 176   14.231099    21.048285     183.404501     18.00              0.173580
# 243   11.617925    18.859112      28.764485    999.00              0.330391
# 244   20.372091    82.641510     239.323247    999.00              0.285415
# 249   32.420326    42.271423     943.608234    999.00              0.134681
# 258   16.875000    26.921206      29.306718    999.00              0.084842
# 381   14.919519    21.132670      43.564999    999.00              0.148053
# 386   66.942314    71.040820      79.206056    999.00              0.144406
# 555 -101.200000   297.647030       3.710831    999.00              0.268396
# 621   22.512894    23.102028      17.896575    999.00              0.115232
# 639   17.428572    32.105263       6.133024    999.00              0.188167
# 686   12.925878    17.235998      26.950686    999.00              0.234360
# 708   17.926380    38.146214     440.267051     26.16              0.230713
# 751   26.753050    35.699757      94.882094    999.00              0.138328
# 781    8.763736    84.840430      11.697185    999.00              0.539473
# 890   80.967030   131.336900      96.589249    999.00              0.302433
# 901    9.713984    20.560537      33.624820    999.00              0.261103
# 923   60.831463  1850.940200     115.161464     13.09              0.183305
# 39    17.647163    23.200466      36.186806      6.99              0.189383
# 74    88.100910   143.584230    1645.638404     14.71              0.062961
# 184   74.663315   114.029170  599909.754404     14.52              0.056883
#
#        AHV_5y  annu_return_5y  sharpe
# 14   0.564107        0.569607   0.993
# 17   0.316793        0.271663   0.757
# 73   0.376405        0.422642   0.784
# 176  0.375961        0.297623   0.722
# 243  0.570794        0.201750   0.637
# 244  0.719036        1.325025   1.365
# 249  0.360669        0.411064   1.045
# 258  0.446357        0.362672   0.833
# 381  0.401822        0.286506   0.784
# 386  0.291432        0.265617   0.876
# 555  0.669394        0.192740   0.661
# 621  0.344249        0.170329   0.689
# 639  0.334100        0.227677   0.678
# 686  0.366896        0.221251   0.628
# 708  0.507655        0.343777   0.756
# 751  0.396886        0.226355   0.674
# 781  1.229896        0.422364   0.873
# 890  0.683392        0.956083   1.100
# 901  0.610451        0.290763   0.613
# 923  0.383779        0.213788   0.659
# 39   0.351216        0.244065   0.646
# 74   0.272286        0.148163   0.603
# 184  0.267604        0.237268   0.855
#
# [23 rows x 22 columns]

# %%
chosen_df.to_csv("selected_stocks_aggressive.csv")

# %% [markdown]
# ## Bonds

# %%
pip install Nasdaq-Data-Link
# Out:
# Requirement already satisfied: Nasdaq-Data-Link in c:\users\lavanya maran\anaconda3\lib\site-packages (1.0.1)
# Requirement already satisfied: numpy>=1.8 in c:\users\lavanya maran\anaconda3\lib\site-packages (from Nasdaq-Data-Link) (1.20.3)
# Requirement already satisfied: pandas>=0.14 in c:\users\lavanya maran\anaconda3\lib\site-packages (from Nasdaq-Data-Link) (1.3.5)
# Requirement already satisfied: inflection>=0.3.1 in c:\users\lavanya maran\anaconda3\lib\site-packages (from Nasdaq-Data-Link) (0.5.1)
# Requirement already satisfied: six in c:\users\lavanya maran\anaconda3\lib\site-packages (from Nasdaq-Data-Link) (1.16.0)
# Requirement already satisfied: requests>=2.7.0 in c:\users\lavanya maran\anaconda3\lib\site-packages (from Nasdaq-Data-Link) (2.26.0)
# Requirement already satisfied: python-dateutil in c:\users\lavanya maran\anaconda3\lib\site-packages (from Nasdaq-Data-Link) (2.8.2)
# Requirement already satisfied: more-itertools in c:\users\lavanya maran\anaconda3\lib\site-packages (from Nasdaq-Data-Link) (8.10.0)
# Requirement already satisfied: pytz>=2017.3 in c:\users\lavanya maran\anaconda3\lib\site-packages (from pandas>=0.14->Nasdaq-Data-Link) (2021.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\lavanya maran\anaconda3\lib\site-packages (from requests>=2.7.0->Nasdaq-Data-Link) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lavanya maran\anaconda3\lib\site-packages (from requests>=2.7.0->Nasdaq-Data-Link) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lavanya maran\anaconda3\lib\site-packages (from requests>=2.7.0->Nasdaq-Data-Link) (3.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\lavanya maran\anaconda3\lib\site-packages (from requests>=2.7.0->Nasdaq-Data-Link) (1.26.7)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install quandl
# Out:
# Requirement already satisfied: quandl in c:\users\lavanya maran\anaconda3\lib\site-packages (3.7.0)
# Requirement already satisfied: pandas>=0.14 in c:\users\lavanya maran\anaconda3\lib\site-packages (from quandl) (1.3.5)
# Requirement already satisfied: six in c:\users\lavanya maran\anaconda3\lib\site-packages (from quandl) (1.16.0)
# Requirement already satisfied: requests>=2.7.0 in c:\users\lavanya maran\anaconda3\lib\site-packages (from quandl) (2.26.0)
# Requirement already satisfied: more-itertools in c:\users\lavanya maran\anaconda3\lib\site-packages (from quandl) (8.10.0)
# Requirement already satisfied: inflection>=0.3.1 in c:\users\lavanya maran\anaconda3\lib\site-packages (from quandl) (0.5.1)
# Requirement already satisfied: python-dateutil in c:\users\lavanya maran\anaconda3\lib\site-packages (from quandl) (2.8.2)
# Requirement already satisfied: numpy>=1.8 in c:\users\lavanya maran\anaconda3\lib\site-packages (from quandl) (1.20.3)
# Requirement already satisfied: pytz>=2017.3 in c:\users\lavanya maran\anaconda3\lib\site-packages (from pandas>=0.14->quandl) (2021.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\lavanya maran\anaconda3\lib\site-packages (from requests>=2.7.0->quandl) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lavanya maran\anaconda3\lib\site-packages (from requests>=2.7.0->quandl) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\lavanya maran\anaconda3\lib\site-packages (from requests>=2.7.0->quandl) (1.26.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lavanya maran\anaconda3\lib\site-packages (from requests>=2.7.0->quandl) (3.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import nasdaqdatalink
import quandl

# %%
quandl.get('USTREASURY/YIELD')['5 YR']
#expected return from US 5y treasury bond is 1.78
# Out:
# Date
# 1990-01-02    7.87
# 1990-01-03    7.92
# 1990-01-04    7.91
# 1990-01-05    7.92
# 1990-01-08    7.92
#               ...
# 2022-01-31    1.62
# 2022-02-01    1.63
# 2022-02-02    1.60
# 2022-02-03    1.66
# 2022-02-04    1.78
# Name: 5 YR, Length: 8032, dtype: float64

# %% [markdown]
# ## Aggressive Model 1: 70% Stocks & 30% Bonds

# %%
def calculate_returns(weights, log_returns):
    # Annual log Returns

    return np.sum(log_returns.mean()*weights) * 252

# %%
n = len(adjClose_5y[top_40_ret_data['ticker']].columns)
log_returns_test = np.log(adjClose_5y[top_40_ret_data['ticker']] / adjClose_5y[top_40_ret_data['ticker']].shift(1)).dropna() # Same as 1 + stocks_data.pct_change()
log_returns_test

# %%
def function_to_minimize(weights):

    # minimize a -1 * SR (that's how the math works here, but it is the same as maximizing SR)
    return -1 * ((calculate_returns(weights, log_returns_test) - 0 )/calculate_volatility(weights, log_returns_test)) # assuming rf =0

# %%
required_return = 0.70
constraints = ({'type':'eq','fun': lambda weights: np.sum(weights)-1},
               {'type':'eq','fun': lambda weights: calculate_returns(weights,log_returns_test) - required_return})
bounds = tuple((0,1) for n in range(n))
equal_weights = n * [1/n] #going to be our starting point then the function will look at either direction for minimum negative SG

# %%
def calculate_vol(weights):
    annualized_cov = np.dot(log_returns_test.cov()*252,weights)
    vol = np.dot(weights.transpose(),annualized_cov)
    return np.sqrt(vol)

# %%
result = minimize(fun=calculate_vol,x0=equal_weights,bounds=bounds,constraints=constraints)
result
