# %%
import pandas as pd
df = pd.read_csv('../income model/selected_stocks_income_v3_sharpe_0.5.csv')

# %%
df
# Out:
#     Unnamed: 0 ticker                             name  \
# 0           78    ETR              Entergy Corporation
# 1          466  FWONK  Liberty Media Corporation - Ser
# 2           56   CTLT                   Catalent, Inc.
# 3          287   BRKR               Bruker Corporation
# 4          542   ICLR                         ICON plc
# 5          651   MODV                   ModivCare Inc.
# 6           15    AME                     AMETEK, Inc.
# 7           37    CAT                Caterpillar, Inc.
# 8           72    EFX                    Equifax, Inc.
# 9           92    GWW              W.W. Grainger, Inc.
# 10         112      J    Jacobs Engineering Group Inc.
# 11         125    LHX      L3Harris Technologies, Inc.
# 12         158   ODFL  Old Dominion Freight Line, Inc.
# 13         180    ROK        Rockwell Automation, Inc.
# 14         219    XYL                       Xylem Inc.
# 15         428   FELE      Franklin Electric Co., Inc.
# ...

# %%
df.groupby('sector')['annu_return_5y'].mean()
# Out:
# sector
# Basic Materials           0.193174
# Communication Services    0.156119
# Consumer Cyclical         0.247990
# Financial Services        0.219613
# Healthcare                0.238476
# Industrials               0.192971
# Real Estate               0.209832
# Technology                0.240453
# Utilities                 0.118782
# Name: annu_return_5y, dtype: float64

# %%
df.groupby('sector')['AHV_5y'].mean()
# Out:
# sector
# Basic Materials           0.360322
# Communication Services    0.371499
# Consumer Cyclical         0.369208
# Financial Services        0.334445
# Healthcare                0.343514
# Industrials               0.312573
# Real Estate               0.297035
# Technology                0.352218
# Utilities                 0.260092
# Name: AHV_5y, dtype: float64

# %%
df.groupby('sector')['sharpe'].mean()
# Out:
# sector
# Basic Materials           0.709000
# Communication Services    0.510000
# Consumer Cyclical         0.739500
# Financial Services        0.714250
# Healthcare                0.784000
# Industrials               0.698400
# Real Estate               0.716667
# Technology                0.718000
# Utilities                 0.533000
# Name: sharpe, dtype: float64

# %%
df.groupby('sector')['AHV_5y'].count()
# Out:
# sector
# Basic Materials            1
# Communication Services     1
# Consumer Cyclical          6
# Financial Services         4
# Healthcare                 4
# Industrials               15
# Real Estate                3
# Technology                15
# Utilities                  1
# Name: AHV_5y, dtype: int64
