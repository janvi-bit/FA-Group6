# %%
import pandas as pd
import numpy as np
from datetime import date
import matplotlib.pyplot as plt
import seaborn as sns
from tabulate import tabulate
from pandas_datareader import data
from scipy.optimize import minimize
import matplotlib.pyplot as plt
import scipy.stats
from scipy.stats import norm
import pyfolio as pf
# %matplotlib inline
# Out:
# C:\Users\LAVANYA MARAN\anaconda3\lib\site-packages\pyfolio\pos.py:26: UserWarning: Module "zipline.assets" not found; mutltipliers will not be applied to position notionals.
#   warnings.warn(

# %%
import csv
df = pd.read_csv('Final_stock_data_V2.csv')
df
# Out:
#     ticker                             name                  sector  \
# 0      AAP          Advance Auto Parts Inc.       Consumer Cyclical
# 1      ABT              Abbott Laboratories              Healthcare
# 2      ACN                    Accenture plc              Technology
# 3      ADM   Archer-Daniels-Midland Company      Consumer Defensive
# 4      ADP  Automatic Data Processing, Inc.             Industrials
# ..     ...                              ...                     ...
# 933    XRX       Xerox Holdings Corporation              Technology
# 934     ZD                 Ziff Davis, Inc.  Communication Services
# 935   ZUMZ                      Zumiez Inc.       Consumer Cyclical
# 936   ESNT                Essent Group Ltd.      Financial Services
# 937   SAFE                    Safehold Inc.             Real Estate
#
#     Earnings_expectation        irv_status  capm_status       esg_status  \
# 0               Increase  Above Fair Price  UnderValued      Sustainable
# 1               Increase  Above Fair Price   OverValued          Average
# 2               Increase  Above Fair Price   OverValued      Sustainable
# 3               Increase  Above Fair Price   OverValued  Not Sustainable
# 4               Increase  Above Fair Price   OverValued      Sustainable
# ..                   ...               ...          ...              ...
# 933             Increase  Above Fair Price  UnderValued          No Data
# 934             Increase  Above Fair Price   OverValued          No Data
# 935             Decrease  Above Fair Price  UnderValued          No Data
# 936             Increase  Above Fair Price  UnderValued          No Data
# 937             Increase  Below Fair Price   OverValued          No Data
#
#      current_price  annu_return_10y    market_cap  ...  beta  eps_ttm  \
# 0         214.1500         0.103398  1.308405e+10  ...  1.25    9.550
# 1         118.2900         0.181179  2.091710e+11  ...  0.74    3.940
# 2         323.9050         0.208836  2.047083e+11  ...  1.21    9.613
# 3          76.9850         0.122815  4.327843e+10  ...  0.81    4.790
# 4         201.0100         0.182708  8.443324e+10  ...  0.83    6.460
# ..             ...              ...           ...  ...   ...      ...
# 933        20.6059         0.029031  3.678401e+09  ...  1.75    1.459
# 934       102.4800         0.145864  4.941668e+09  ...  1.01    4.120
# 935        42.6600         0.035214  9.777245e+08  ...  1.68    4.870
# 936        44.4800         0.082041  4.912015e+09  ...  1.33    5.569
# 937        60.4700         0.133037  3.420177e+09  ... -0.29    1.261
#
#      growth_estimate_5y  pe_forward  pe_trailing  irv_FairValue  ESG_risk  \
# 0                0.1525   13.932986    22.424082     109.188247     12.97
# 1                0.1318   22.924420    30.022842      51.234756     25.96
# 2                0.1135   31.025385    33.694477     121.148794      9.45
# 3                0.0660   14.804809    16.072025      19.449588     36.42
# 4                0.1371   26.483530    31.116098      90.801919     14.18
# ..                  ...         ...          ...            ...       ...
# 933             -0.1600   10.302950    14.123303       0.609810    999.00
# 934              0.1140   14.193907    24.873789      38.485339    999.00
# 935              0.1500    9.233767     8.759754      21.330001    999.00
# 936              0.1555    7.339934     7.987071      23.215807    999.00
# 937              0.3690   34.752872    47.954006     145.164511    999.00
#
#      capm_expected_return    AHV_5y  annu_return_5y
# 0                0.171149  0.355467        0.049267
# 1                0.109154  0.249769        0.247649
# 2                0.166287  0.254874        0.245322
# 3                0.117663  0.252289        0.150693
# 4                0.120094  0.272415        0.178939
# ..                    ...       ...             ...
# 933              0.231929  0.405374       -0.032851
# 934              0.141975  0.308007        0.055993
# 935              0.223419  0.513665        0.157523
# 936              0.180874  0.502764        0.045034
# 937             -0.016052       NaN             NaN
#
# [938 rows x 21 columns]

# %%
df['sector'].hist(xrot=90)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Filter based on 2/3 criteria

# %%
def check_criteria(each):
    check = []
    if each["capm_status"] == "UnderValued":
        check.append(True)
    if each["Earnings_expectation"] == "Increase":
        check.append(True)
    if each["irv_status"] == "Below Fair Price":
        check.append(True)
    return check

# %%
def check_number(criteria):
    if len(criteria) >= 2:
        return True
    else:
        return False

# %%
rows = []
for i in range(938):
    each = df.iloc[i]
    criteria = check_criteria(each)
    result = check_number(criteria)
    if result:
        rows.append(i)

# %%
len(rows)
# Out:
# 476

# %%
df = df.iloc[rows]
df
# Out:
#     ticker                          name              sector  \
# 0      AAP       Advance Auto Parts Inc.   Consumer Cyclical
# 5     ADSK                Autodesk, Inc.          Technology
# 11     ALK        Alaska Air Group, Inc.         Industrials
# 12    ALLE                  Allegion plc         Industrials
# 14     AMD  Advanced Micro Devices, Inc.          Technology
# ..     ...                           ...                 ...
# 931   XOMA              XOMA Corporation          Healthcare
# 932     XP                       XP Inc.  Financial Services
# 933    XRX    Xerox Holdings Corporation          Technology
# 936   ESNT             Essent Group Ltd.  Financial Services
# 937   SAFE                 Safehold Inc.         Real Estate
#
#     Earnings_expectation        irv_status  capm_status   esg_status  \
# 0               Increase  Above Fair Price  UnderValued  Sustainable
# 5               Increase  Below Fair Price  UnderValued  Sustainable
# 11              Increase  Above Fair Price  UnderValued      No Data
# 12              Increase  Above Fair Price  UnderValued      Average
# 14              Increase  Below Fair Price   OverValued      No Data
# ..                   ...               ...          ...          ...
# 931             Increase  Above Fair Price  UnderValued      No Data
# 932             Increase  Above Fair Price  UnderValued      No Data
# 933             Increase  Above Fair Price  UnderValued      No Data
# 936             Increase  Above Fair Price  UnderValued      No Data
# 937             Increase  Below Fair Price   OverValued      No Data
#
#      current_price  annu_return_10y    market_cap  ...  beta  eps_ttm  \
# 0         214.1500         0.103398  1.308405e+10  ...  1.25    9.550
# 5         217.3800         0.190997  4.781773e+10  ...  1.43    5.928
# 11         58.9750         0.141697  7.425660e+09  ...  1.55    3.770
# 12        114.1447         0.097180  1.023831e+10  ...  1.14    5.086
# 14        117.1100         0.319034  1.414232e+11  ...  1.95    3.242
# ..             ...              ...           ...  ...   ...      ...
# 931        20.7600        -0.034853  2.348205e+08  ...  0.81    0.082
# 932        34.1100        -0.001020  1.908622e+10  ...  1.91    0.986
# 933        20.6059         0.029031  3.678401e+09  ...  1.75    1.459
# 936        44.4800         0.082041  4.912015e+09  ...  1.33    5.569
# 937        60.4700         0.133037  3.420177e+09  ... -0.29    1.261
#
#      growth_estimate_5y  pe_forward  pe_trailing  irv_FairValue  ESG_risk  \
# 0                0.1525   13.932986    22.424082     109.188247     12.97
# 5                0.2883   31.967648    36.670040     302.038344     15.45
# 11              -0.2340    9.073076    15.643236       0.761055    999.00
# 12               0.0777   19.955368    22.442923      31.814578     23.59
# 14               0.3532   35.062874    36.122765     253.245268    999.00
# ..                  ...         ...          ...            ...       ...
# 931              0.1900  -90.260870   253.170730      14.120154    999.00
# 932              0.0478   27.508064    34.594322       7.380346    999.00
# 933             -0.1600   10.302950    14.123303       0.609810    999.00
# 936              0.1555    7.339934     7.987071      23.215807    999.00
# 937              0.3690   34.752872    47.954006     145.164511    999.00
#
#      capm_expected_return    AHV_5y  annu_return_5y
# 0                0.171149  0.355467        0.049267
# 5                0.193030  0.384894        0.209161
# 11               0.207617  0.454054       -0.086043
# 12               0.157777  0.279213        0.118004
# 14               0.256240  0.564107        0.569607
# ..                    ...       ...             ...
# 931              0.117663  0.689078        0.371572
# 932              0.251378       NaN             NaN
# 933              0.231929  0.405374       -0.032851
# 936              0.180874  0.502764        0.045034
# 937             -0.016052       NaN             NaN
#
# [476 rows x 21 columns]

# %%
#total number of stocks for each sector 

df["sector"].value_counts()
# Out:
# Industrials               93
# Technology                89
# Consumer Cyclical         79
# Financial Services        68
# Healthcare                52
# Communication Services    29
# Basic Materials           20
# Consumer Defensive        19
# Energy                    15
# Real Estate               11
# Utilities                  1
# Name: sector, dtype: int64

# %%
#df for each sector

df_BM = df.loc[df['sector'] == 'Basic Materials']
df_CS = df.loc[df['sector'] == 'Communication Services']
df_CC = df.loc[df['sector'] == 'Consumer Cyclical']
df_CD = df.loc[df['sector'] == 'Consumer Defensive']
df_energy = df.loc[df['sector'] == 'Energy']
df_FS = df.loc[df['sector'] == 'Financial Services']
df_healthcare = df.loc[df['sector'] == 'Healthcare']
df_industrials = df.loc[df['sector'] == 'Industrials']
df_RE = df.loc[df['sector'] == 'Real Estate']
df_tech = df.loc[df['sector'] == 'Technology']
df_utilities = df.loc[df['sector'] == 'Utilities']

# %% [markdown]
# ## Helper Functions

# %%
def get_closeprice(ticker):    
    start_date = str(date.today().year - 5) +'-0'+ str(date.today().month) +'-'+ str(date.today().day)
    end_date = str(date.today())
    
    panel_data = data.DataReader([ticker],'yahoo', start_date, end_date)
    closes = panel_data[["Close", "Adj Close"]]
    
    return closes

# %%
def get_sharpe_ratio(ticker):
    
    closes = get_closeprice(ticker)
    adj_close = closes["Adj Close"]
    
    risk_free_ann_ret_rate = 0.0195  #assuming this rate based on the latest data
     
    #Rp
    returns_ts = adj_close.pct_change().dropna()
    
    #Average Rp
    avg_daily_ret = returns_ts.mean()

    #Average risk-free rate for the year (Annual rate / number of trading days to spread it out)
    returns_ts['RiskFree_Rate'] = risk_free_ann_ret_rate/252

    #Average Rf
    avg_rf_ret = returns_ts['RiskFree_Rate'].mean()

    #calculate sharpe ratio

    #Add the excess return columns for each ETF: Rp - Rf
    returns_ts['Excess_ret'] = returns_ts[ticker] - returns_ts['RiskFree_Rate']
    
    sharpe = ((avg_daily_ret[ticker] - avg_rf_ret) /returns_ts['Excess_ret'].std())*np.sqrt(252)

    return sharpe.round(3)

# %%
def get_return_series(ticker):
    closes = get_closeprice(ticker)
    return_series_close = (closes['Close'].pct_change()+ 1).cumprod() - 1
    return return_series_close

# %% [markdown]
# # Basic Materials

# %% [markdown]
# ## Filtering Stocks based on Sharpe Ratio

# %%
sharpe_list = []
for i in range(len(df_BM)):
    each = df_BM.iloc[i]
    ticker = each["ticker"]
    sharpe = get_sharpe_ratio(ticker)
    sharpe_list.append(sharpe)

# %%
sharpe_list
# Out:
# [0.458,
#  0.833,
#  0.799,
#  0.145,
#  0.46,
#  0.741,
#  0.288,
#  0.46,
#  0.416,
#  0.416,
#  0.355,
#  0.339,
#  0.486,
#  0.402,
#  0.417,
#  0.327,
#  0.675,
#  0.502,
#  0.689,
#  0.646]

# %%
df_BM["sharpe"] = sharpe_list
df_BM
# Out:
# C:\Users\LAVANY~1\AppData\Local\Temp/ipykernel_21904/295372314.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_BM["sharpe"] = sharpe_list
#     ticker                             name           sector  \
# 42      CE  Celanese Corporation Celanese C  Basic Materials
# 58    CTVA                    Corteva, Inc.  Basic Materials
# 82     FCX           Freeport-McMoRan, Inc.  Basic Materials
# 103    IFF  International Flavors & Fragran  Basic Materials
# 129    LYB     LyondellBasell Industries NV  Basic Materials
# 157    NUE                Nucor Corporation  Basic Materials
# 170    PPG             PPG Industries, Inc.  Basic Materials
# 271   BCPC              Balchem Corporation  Basic Materials
# 507   HDSN        Hudson Technologies, Inc.  Basic Materials
# 557   IOSP                    Innospec Inc.  Basic Materials
# 633   MEOH             Methanex Corporation  Basic Materials
# 634   MERC        Mercer International Inc.  Basic Materials
# 636   METC           Ramaco Resources, Inc.  Basic Materials
# 690   NTIC  Northern Technologies Internati  Basic Materials
# 722   PAAS        Pan American Silver Corp.  Basic Materials
# 782   RKDA        Arcadia Biosciences, Inc.  Basic Materials
# 809   SCHN  Schnitzer Steel Industries, Inc  Basic Materials
# 852   SSRM                  SSR Mining Inc.  Basic Materials
# 855   STLD             Steel Dynamics, Inc.  Basic Materials
# 878   TGLS                  Tecnoglass Inc.  Basic Materials
#
#     Earnings_expectation        irv_status  capm_status       esg_status  \
# 42              Decrease  Below Fair Price  UnderValued  Not Sustainable
# 58              Increase  Below Fair Price  UnderValued          No Data
# 82              Increase  Below Fair Price  UnderValued  Not Sustainable
# 103             Increase  Above Fair Price  UnderValued          Average
# 129             Decrease  Below Fair Price  UnderValued          Average
# 157             Increase  Below Fair Price  UnderValued  Not Sustainable
# 170             Increase  Above Fair Price  UnderValued          Average
# 271             Increase  Below Fair Price   OverValued          No Data
# 507             Decrease  Below Fair Price  UnderValued          No Data
# 557             Increase  Above Fair Price  UnderValued          No Data
# 633             Decrease  Below Fair Price  UnderValued          No Data
# 634             Increase  Above Fair Price  UnderValued          No Data
# 636             Increase  Above Fair Price  UnderValued          No Data
# 690             Increase  Above Fair Price  UnderValued          No Data
# 722             Increase  Above Fair Price  UnderValued          No Data
# 782             Increase  Above Fair Price  UnderValued          No Data
# 809             Increase  Above Fair Price  UnderValued          No Data
# 852             Increase  Above Fair Price  UnderValued          No Data
# 855             Increase  Below Fair Price  UnderValued  Not Sustainable
# 878             Increase  Above Fair Price  UnderValued          No Data
#
#      current_price  annu_return_10y    market_cap  ... eps_ttm  \
#
# 852              0.145622  0.466643        0.122974   0.502
# 855              0.202754  0.411506        0.159118   0.689
# 878              0.230713  0.620494        0.151889   0.646
#
# [20 rows x 22 columns]

# %%
df_BM = df_BM[df_BM["sharpe"] > 0.6]
df_BM
# Out:
#     ticker                             name           sector  \
# 58    CTVA                    Corteva, Inc.  Basic Materials
# 82     FCX           Freeport-McMoRan, Inc.  Basic Materials
# 157    NUE                Nucor Corporation  Basic Materials
# 809   SCHN  Schnitzer Steel Industries, Inc  Basic Materials
# 855   STLD             Steel Dynamics, Inc.  Basic Materials
# 878   TGLS                  Tecnoglass Inc.  Basic Materials
#
#     Earnings_expectation        irv_status  capm_status       esg_status  \
# 58              Increase  Below Fair Price  UnderValued          No Data
# 82              Increase  Below Fair Price  UnderValued  Not Sustainable
# 157             Increase  Below Fair Price  UnderValued  Not Sustainable
# 809             Increase  Above Fair Price  UnderValued          No Data
# 855             Increase  Below Fair Price  UnderValued  Not Sustainable
# 878             Increase  Above Fair Price  UnderValued          No Data
#
#      current_price  annu_return_10y    market_cap  ... eps_ttm  \
# 58          50.785         0.061890  3.701765e+10  ...   2.202
# 82          42.740         0.018945  6.276241e+10  ...   2.641
# 157        122.640         0.142526  3.505039e+10  ...  16.577
# 809         41.580         0.019844  1.156909e+09  ...   5.657
# 855         63.230         0.186302  1.254806e+10  ...  11.005
# 878         19.490         0.099058  9.291818e+08  ...   1.404
#
#      growth_estimate_5y  pe_forward  pe_trailing  irv_FairValue  ESG_risk  \
# 58               0.2487   19.608109    23.063126      53.278002    999.00
# 82               0.2890   12.039437    16.183264      59.676070     34.50
# 157              0.3499    7.334929     7.398202     259.439419     36.58
# 809              0.1000    5.766991     7.350186      13.935037    999.00
# 855              0.3632    5.062450     5.745570     146.099525     34.29
# 878              0.0094   10.708791    13.881765       3.013498    999.00
#
#      capm_expected_return    AHV_5y  annu_return_5y  sharpe
# 58               0.115232       NaN             NaN   0.833
# 82               0.270827  0.507643        0.234986   0.799
# 157              0.194245  0.360322        0.193174   0.741
# 809              0.203970  0.472387        0.156052   0.675
# 855              0.202754  0.411506        0.159118   0.689
# 878              0.230713  0.620494        0.151889   0.646
#
# [6 rows x 22 columns]

# %% [markdown]
# # Consumer Defensive

# %% [markdown]
# ## Filtering Stocks based on Sharpe Ratio

# %%
sharpe_list = []
for i in range(len(df_CD)):
    each = df_CD.iloc[i]
    ticker = each["ticker"]
    sharpe = get_sharpe_ratio(ticker)
    sharpe_list.append(sharpe)

# %%
sharpe_list
# Out:
# [0.039,
#  0.14,
#  0.062,
#  -0.303,
#  0.44,
#  0.329,
#  1.064,
#  0.199,
#  0.278,
#  0.061,
#  0.131,
#  0.313,
#  0.302,
#  0.036,
#  0.757,
#  0.303,
#  0.204,
#  0.107,
#  0.28]

# %%
df_CD["sharpe"] = sharpe_list
df_CD
# Out:
# C:\Users\LAVANY~1\AppData\Local\Temp/ipykernel_21904/4153434586.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_CD["sharpe"] = sharpe_list
#     ticker                             name              sector  \
# 36     CAG             ConAgra Brands, Inc.  Consumer Defensive
# 46      CL        Colgate-Palmolive Company  Consumer Defensive
# 117      K                  Kellogg Company  Consumer Defensive
# 119    KHC          The Kraft Heinz Company  Consumer Defensive
# 191    SYY                Sysco Corporation  Consumer Defensive
# 306   CCEP  Coca-Cola Europacific Partners   Consumer Defensive
# 312   CELH           Celsius Holdings, Inc.  Consumer Defensive
# 388   DTEA                   DAVIDsTEA Inc.  Consumer Defensive
# 438   FIZZ          National Beverage Corp.  Consumer Defensive
# 500   HAIN   The Hain Celestial Group, Inc.  Consumer Defensive
# 569    JVA         Coffee Holding Co., Inc.  Consumer Defensive
# 609   LOPE     Grand Canyon Education, Inc.  Consumer Defensive
# 754   PRDO   Perdoceo Education Corporation  Consumer Defensive
# 761   PSMT                 PriceSmart, Inc.  Consumer Defensive
# 835   SMPL    The Simply Good Foods Company  Consumer Defensive
# 844   SPTN              SpartanNash Company  Consumer Defensive
# 854   STKL                    SunOpta, Inc.  Consumer Defensive
# 856   STRA        Strategic Education, Inc.  Consumer Defensive
# 897   TWNK             Hostess Brands, Inc.  Consumer Defensive
#
#     Earnings_expectation        irv_status  capm_status       esg_status  \
# 36              Increase  Above Fair Price  UnderValued  Not Sustainable
# 46              Increase  Above Fair Price  UnderValued          Average
# 117             Increase  Above Fair Price  UnderValued          Average
# 119             Increase  Above Fair Price  UnderValued  Not Sustainable
# 191             Increase  Below Fair Price  UnderValued      Sustainable
# 306             Increase  Below Fair Price   OverValued          No Data
# 312             Increase  Below Fair Price   OverValued          No Data
# 388             Increase  Above Fair Price  UnderValued          No Data
# 438             Increase  Below Fair Price   OverValued          No Data
# 500             Increase  Above Fair Price  UnderValued          No Data
# 569             Increase  Above Fair Price  UnderValued          No Data
# 609             Increase  Below Fair Price   OverValued          No Data
# 754             Increase  Above Fair Price  UnderValued          No Data
# 761             Increase  Above Fair Price  UnderValued          No Data
# 835             Increase  Above Fair Price  UnderValued          No Data
# 844             Increase  Above Fair Price  UnderValued          No Data
# 854             Decrease  Below Fair Price  UnderValued          No Data
# 856             Increase  Above Fair Price  UnderValued          No Data
# 897             Increase  Above Fair Price  UnderValued          No Data
#
#      current_price  annu_return_10y    market_cap  ... eps_ttm  \
# 36         35.7000         0.090652  1.712493e+10  ...   2.481
# 46         79.0900         0.078620  6.666093e+10  ...   3.140
# 117        66.3900         0.056187  2.264716e+10  ...   3.668
# 119        39.7900        -0.035146  4.870455e+10  ...   1.858
# 191        84.0500         0.143456  4.308874e+10  ...   1.332
# 306        54.0900         0.128504  2.491753e+10  ...   1.515
# 312        55.8575         0.717423  4.178984e+09  ...   0.110
# 388         3.0500        -0.195930  8.039800e+07  ...   1.431
# 438        42.3300         0.219583  3.950329e+09  ...   1.800
# 500        36.0000         0.058080  3.343734e+09  ...   0.962
# 569         4.0500        -0.068383  2.311983e+07  ...   0.092
# 609        86.2900         0.170795  3.457951e+09  ...   5.729
# 754        10.1100        -0.012971  7.087666e+08  ...   1.569
# 761        70.5600         0.011350  2.177658e+09  ...   3.180
# 835        38.1200         0.121790  3.660747e+09  ...   0.420
# 844        27.0800         0.069797  9.733743e+08  ...   1.780
# 854         4.6580        -0.011171  5.001248e+08  ...   0.638
# 856        50.9500        -0.062787  1.253395e+09  ...   1.623
# 897        21.1800         0.082395  2.930825e+09  ...   0.626
#
#      growth_estimate_5y  pe_forward  pe_trailing  irv_FairValue  ESG_risk  \
# 36               0.0224   13.522727    14.389359       6.193629     32.92
# 46               0.0612   23.330381    25.187897      19.186076     22.12
# 117              0.0315   15.959135    18.099781      12.474271     26.78
# 119             -0.0244   15.071969    21.415500       4.528032     34.47
# 191              0.5309   19.964370    63.100600     551.757903     12.14
# 306              0.3135   20.258427    35.702972      89.469938    999.00
# 312              0.6720  146.993420   507.795440     810.769459    999.00
# 388             -1.3172 -101.666664     2.131377      -0.000014    999.00
# 438              0.2556   22.162306    23.516668      46.665884    999.00
# 500              0.1300   19.459460    37.422035      15.370851    999.00
# 569              0.1600   10.125000    44.021740       2.189104    999.00
# 609              0.9000   13.588977    15.061965    3957.603724    999.00
# 754              0.1500    5.877907     6.443594       5.055000    999.00
# 761              0.1500   17.465345    22.188679      35.280000    999.00
# 835              0.0918   24.593548    90.761900      11.943459    999.00
# 844             -0.0879   14.104167    15.213484       1.681590    999.00
# 854              0.3000   33.271427     7.300941       7.020679    999.00
# 856              0.0600   10.956989    31.392483      12.234505    999.00
# 897              0.1008   22.531916    33.833866       7.144818    999.00
#
#      capm_expected_return    AHV_5y  annu_return_5y  sharpe
# 36               0.115232  0.287178        0.000833   0.039
# 46               0.094567  0.206239        0.051918   0.140
# 117              0.090920  0.233473        0.006971   0.062
# 119              0.150484  0.322340       -0.118555  -0.303
# 191              0.182089  0.361481        0.130098   0.440
# 306              0.109154  0.295493        0.110419   0.329
# 312              0.262318  0.729476        0.799096   1.064
# 388              0.421561  0.875885       -0.151658   0.199
# 438              0.135897  0.463844        0.137329   0.278
# 500              0.099429  0.344834       -0.020295   0.061
# 569              0.176011  0.527264       -0.021047   0.131
# 609              0.075117  0.335656        0.079754   0.313
# 754              0.160209  0.393648        0.007507   0.302
# 761              0.123741  0.322618       -0.031776   0.036
# 835              0.148053       NaN             NaN   0.757
# 844              0.109154  0.525851       -0.036807   0.303
# 854              0.281768  0.632288       -0.056654   0.204
# 856              0.082411  0.397622       -0.079989   0.107
# 897              0.103076  0.279978        0.076044   0.280
#
# [19 rows x 22 columns]

# %%
df_CD = df_CD[df_CD["sharpe"] > 0.6]
df_CD
# Out:
#     ticker                           name              sector  \
# 312   CELH         Celsius Holdings, Inc.  Consumer Defensive
# 835   SMPL  The Simply Good Foods Company  Consumer Defensive
#
#     Earnings_expectation        irv_status  capm_status esg_status  \
# 312             Increase  Below Fair Price   OverValued    No Data
# 835             Increase  Above Fair Price  UnderValued    No Data
#
#      current_price  annu_return_10y    market_cap  ... eps_ttm  \
# 312        55.8575         0.717423  4.178984e+09  ...    0.11
# 835        38.1200         0.121790  3.660747e+09  ...    0.42
#
#      growth_estimate_5y  pe_forward  pe_trailing  irv_FairValue  ESG_risk  \
# 312              0.6720  146.993420    507.79544     810.769459     999.0
# 835              0.0918   24.593548     90.76190      11.943459     999.0
#
#      capm_expected_return    AHV_5y  annu_return_5y  sharpe
# 312              0.262318  0.729476        0.799096   1.064
# 835              0.148053       NaN             NaN   0.757
#
# [2 rows x 22 columns]

# %% [markdown]
# # Real Estate Sector

# %% [markdown]
# ## Filtering Stocks based on Sharpe Ratio

# %%
sharpe_list = []
for i in range(len(df_RE)):
    each = df_RE.iloc[i]
    ticker = each["ticker"]
    sharpe = get_sharpe_ratio(ticker)
    sharpe_list.append(sharpe)

# %%
sharpe_list
# Out:
# [0.68, 0.833, 0.77, 0.748]

# %%
df_RE["sharpe"] = sharpe_list
df_RE
# Out:
# C:\Users\LAVANY~1\AppData\Local\Temp/ipykernel_21904/483777690.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_RE["sharpe"] = sharpe_list
#     ticker                            name       sector Earnings_expectation  \
# 39    CBRE                  CBRE Group Inc  Real Estate             Increase
# 184   SBAC  SBA Communications Corporation  Real Estate             Increase
# 416   EXPI        eXp World Holdings, Inc.  Real Estate             Increase
# 937   SAFE                   Safehold Inc.  Real Estate             Increase
#
#            irv_status  capm_status   esg_status  current_price  \
# 39   Above Fair Price  UnderValued  Sustainable          99.53
# 184  Below Fair Price   OverValued  Sustainable         297.16
# 416  Above Fair Price  UnderValued      No Data          25.15
# 937  Below Fair Price   OverValued      No Data          60.47
#
#      annu_return_10y    market_cap  ... eps_ttm  growth_estimate_5y  \
# 39          0.182808  3.330930e+10  ...   4.290              0.1100
# 184         0.204253  3.232536e+10  ...   2.606              1.8932
# 416         0.156613  3.710555e+09  ...   0.467              0.1000
# 937         0.133037  3.420177e+09  ...   1.261              0.3690
#
#      pe_forward  pe_trailing  irv_FairValue  ESG_risk  capm_expected_return  \
# 39    17.647163    23.200466      36.186806      6.99              0.189383
# 184   74.663315   114.029170  599909.754404     14.52              0.056883
# 416   36.985294    53.854390       8.428719    999.00              0.397249
# 937   34.752872    47.954006     145.164511    999.00             -0.016052
#
#        AHV_5y  annu_return_5y  sharpe
# 39   0.351216        0.244065   0.680
# 184  0.267604        0.237268   0.833
# 416       NaN             NaN   0.770
# 937       NaN             NaN   0.748
#
# [4 rows x 22 columns]

# %%
df_RE = df_RE[df_RE["sharpe"] > 0.6]
df_RE
# Out:
#     ticker                            name       sector Earnings_expectation  \
# 39    CBRE                  CBRE Group Inc  Real Estate             Increase
# 184   SBAC  SBA Communications Corporation  Real Estate             Increase
# 416   EXPI        eXp World Holdings, Inc.  Real Estate             Increase
# 937   SAFE                   Safehold Inc.  Real Estate             Increase
#
#            irv_status  capm_status   esg_status  current_price  \
# 39   Above Fair Price  UnderValued  Sustainable          99.53
# 184  Below Fair Price   OverValued  Sustainable         297.16
# 416  Above Fair Price  UnderValued      No Data          25.15
# 937  Below Fair Price   OverValued      No Data          60.47
#
#      annu_return_10y    market_cap  ... eps_ttm  growth_estimate_5y  \
# 39          0.182808  3.330930e+10  ...   4.290              0.1100
# 184         0.204253  3.232536e+10  ...   2.606              1.8932
# 416         0.156613  3.710555e+09  ...   0.467              0.1000
# 937         0.133037  3.420177e+09  ...   1.261              0.3690
#
#      pe_forward  pe_trailing  irv_FairValue  ESG_risk  capm_expected_return  \
# 39    17.647163    23.200466      36.186806      6.99              0.189383
# 184   74.663315   114.029170  599909.754404     14.52              0.056883
# 416   36.985294    53.854390       8.428719    999.00              0.397249
# 937   34.752872    47.954006     145.164511    999.00             -0.016052
#
#        AHV_5y  annu_return_5y  sharpe
# 39   0.351216        0.244065   0.680
# 184  0.267604        0.237268   0.833
# 416       NaN             NaN   0.770
# 937       NaN             NaN   0.748
#
# [4 rows x 22 columns]

# %% [markdown]
# # Financial Services

# %% [markdown]
# ## Filtering Stocks based on Sharpe Ratio

# %%
sharpe_list = []
for i in range(len(df_FS)):
    each = df_FS.iloc[i]
    ticker = each["ticker"]
    sharpe = get_sharpe_ratio(ticker)
    sharpe_list.append(sharpe)

# %%
sharpe_list
# Out:
# [0.666,
#  0.037,
#  0.255,
#  0.448,
#  0.145,
#  0.3,
#  0.478,
#  0.377,
#  0.342,
#  0.316,
#  0.504,
#  0.552,
#  0.284,
#  0.391,
#  0.693,
#  0.178,
#  0.043,
#  0.093,
#  0.233,
#  0.336,
#  0.115,
#  0.074,
#  0.83,
#  -0.067,
#  0.628,
#  0.264,
#  0.445,
#  0.052,
#  0.407,
#  0.165,
#  0.31,
#  0.32,
#  0.735,
#  -0.034,
#  -0.472,
#  0.947,
#  0.025,
#  0.171,
#  0.155,
#  0.333,
#  0.292,
#  0.068,
#  0.278,
#  0.584,
#  0.176,
#  0.478,
#  0.018,
#  0.188,
#  0.251,
#  -0.116,
#  0.264,
#  0.997,
#  0.354,
#  0.385,
#  0.308,
#  0.484,
#  0.244,
#  0.531,
#  0.896,
#  0.223,
#  0.355,
#  1.022,
#  0.372,
#  0.717,
#  0.315,
#  0.202,
#  0.277,
#  0.308]

# %%
df_FS["sharpe"] = sharpe_list
df_FS
# Out:
# C:\Users\LAVANY~1\AppData\Local\Temp/ipykernel_21904/3122362208.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_FS["sharpe"] = sharpe_list
#     ticker                             name              sector  \
# 26     AXP         American Express Company  Financial Services
# 28     BEN         Franklin Resources, Inc.  Financial Services
# 31      BK  The Bank of New York Mellon Cor  Financial Services
# 51     COF  Capital One Financial Corporati  Financial Services
# 111    IVZ                      Invesco Ltd  Financial Services
# ..     ...                              ...                 ...
# 911   VCTR  Victory Capital Holdings, Inc.   Financial Services
# 915    VLY          Valley National Bancorp  Financial Services
# 922   WAFD         Washington Federal, Inc.  Financial Services
# 932     XP                          XP Inc.  Financial Services
# 936   ESNT                Essent Group Ltd.  Financial Services
#
#     Earnings_expectation        irv_status  capm_status       esg_status  \
# 26              Increase  Below Fair Price  UnderValued  Not Sustainable
# 28              Increase  Above Fair Price  UnderValued      Sustainable
# 31              Increase  Above Fair Price  UnderValued          Average
# 51              Decrease  Below Fair Price  UnderValued          Average
# 111             Increase  Above Fair Price  UnderValued  Not Sustainable
# ..                   ...               ...          ...              ...
# 911             Increase  Above Fair Price  UnderValued          No Data
# 915             Increase  Above Fair Price  UnderValued          No Data
# 922             Increase  Above Fair Price  UnderValued          No Data
# 932             Increase  Above Fair Price  UnderValued          No Data
# 936             Increase  Above Fair Price  UnderValued          No Data
#
#      current_price  annu_return_10y    market_cap  ... eps_ttm  \
# 26        195.1100         0.155990  1.511236e+11  ...   9.573
# 28         29.9300         0.009948  1.501872e+10  ...   3.570
# 31         55.7400         0.123563  4.603126e+10  ...   3.925
# 51        153.6800         0.140197  6.540959e+10  ...  26.739
# 111        22.0725         0.030092  1.017999e+10  ...   2.530
# ..             ...              ...           ...  ...     ...
# 911        32.2100         0.110286  2.193565e+09  ...   3.551
# 915        13.9850         0.063284  5.691251e+09  ...   1.110
# 922        35.9200         0.109876  2.342835e+09  ...   2.390
# 932        34.1100        -0.001020  1.908622e+10  ...   0.986
# 936        44.4800         0.082041  4.912015e+09  ...   5.569
#
#      growth_estimate_5y  pe_forward  pe_trailing  irv_FairValue  ESG_risk  \
# 26               0.4330   20.176836    20.381280     706.617956     20.34
# 28               0.0949    7.876316     8.383754       9.619805     19.51
# 31               0.1356   12.196937    14.201275      24.881978     22.79
# 51               0.4520    7.958571     5.747410     626.622996     23.22
# 111              0.2130    7.911291     8.724308      17.835618     20.28
# ..                  ...         ...          ...            ...       ...
# 911              0.1170    6.100378     9.070683      12.392493    999.00
# 915              0.0500   11.654166    12.599098       3.083582    999.00
# 922              0.0700   11.777049    15.029287       9.385982    999.00
# 932              0.0478   27.508064    34.594322       7.380346    999.00
# 936              0.1555    7.339934     7.987071      23.215807    999.00
#
#      capm_expected_return    AHV_5y  annu_return_5y  sharpe
# 26               0.169933  0.343000        0.210121   0.666
# 28               0.165071  0.345803       -0.016066   0.037
# 31               0.158993  0.298729        0.053724   0.255
# 51               0.219773  0.398322        0.129511   0.448
# 111              0.168718  0.427328       -0.024774   0.145
# ..                    ...       ...             ...     ...
# 911              0.150484       NaN             NaN   0.717
# 915              0.166287  0.360308        0.060302   0.315
# 922              0.122525  0.323025        0.026584   0.202
# 932              0.251378       NaN             NaN   0.277
# 936              0.180874  0.502764        0.045034   0.308
#
# [68 rows x 22 columns]

# %%
df_FS = df_FS[df_FS["sharpe"] > 0.6]
df_FS
# Out:
#     ticker                             name              sector  \
# 26     AXP         American Express Company  Financial Services
# 197   TROW        T. Rowe Price Group, Inc.  Financial Services
# 317     CG           The Carlyle Group Inc.  Financial Services
# 360   CSWC    Capital Southwest Corporation  Financial Services
# 464   FUTU            Futu Holdings Limited  Financial Services
# 492   GSHD        Goosehead Insurance, Inc.  Financial Services
# 744   PLMR           Palomar Holdings, Inc.  Financial Services
# 869   TBBK                The Bancorp, Inc.  Financial Services
# 896     TW            Tradeweb Markets Inc.  Financial Services
# 911   VCTR  Victory Capital Holdings, Inc.   Financial Services
#
#     Earnings_expectation        irv_status  capm_status       esg_status  \
# 26              Increase  Below Fair Price  UnderValued  Not Sustainable
# 197             Increase  Above Fair Price  UnderValued      Sustainable
# 317             Decrease  Below Fair Price  UnderValued          No Data
# 360             Increase  Above Fair Price  UnderValued          No Data
# 464             Increase  Above Fair Price  UnderValued          No Data
# 492             Increase  Below Fair Price   OverValued          No Data
# 744             Increase  Below Fair Price   OverValued          No Data
# 869             Increase  Above Fair Price  UnderValued          No Data
# 896             Increase  Above Fair Price  UnderValued          No Data
# 911             Increase  Above Fair Price  UnderValued          No Data
#
#      current_price  annu_return_10y    market_cap  ... eps_ttm  \
# 26         195.110         0.155990  1.511236e+11  ...   9.573
# 197        142.560         0.120724  3.267447e+10  ...  13.270
# 317         44.830         0.139004  1.598019e+10  ...   7.730
# 360         24.420         0.082236  5.699872e+08  ...   1.740
# 464         40.520         0.102151  5.943150e+09  ...   2.459
# 492         85.540         0.187638  3.194397e+09  ...   0.396
# 744         56.450         0.115100  1.434694e+09  ...   1.043
# 869         29.290         0.126627  1.668956e+09  ...   1.825
# 896         80.965         0.086434  1.883205e+10  ...   1.136
# 911         32.210         0.110286  2.193565e+09  ...   3.551
#
#      growth_estimate_5y  pe_forward  pe_trailing  irv_FairValue  ESG_risk  \
# 26               0.4330   20.176836    20.381280     706.617956     20.34
# 197              0.1220   10.678651    10.743029      57.098253     16.74
# 317              0.2826   11.041873     5.799483      59.852092    999.00
# 360              0.0100   12.652850    14.034483       3.796011    999.00
# 464              0.0903   10.389744    16.478243      12.539291    999.00
# 492              0.3410   89.104170   216.010100     170.497371    999.00
# 744              1.1985   19.532871    54.122726    9627.014851    999.00
# 869              0.1200   13.497696    16.049314      11.544390    999.00
# 896              0.1994   44.002716    71.272000      59.110294    999.00
# 911              0.1170    6.100378     9.070683      12.392493    999.00
#
#      capm_expected_return    AHV_5y  annu_return_5y  sharpe
# 26               0.169933  0.343000        0.210121   0.666
# 197              0.167502  0.300412        0.193441   0.693
# 317              0.193030  0.363420        0.276296   0.830
# 360              0.174796  0.330948        0.198592   0.628
# 464              0.135897       NaN             NaN   0.735
# 492              0.081195       NaN             NaN   0.947
# 744              0.010691       NaN             NaN   0.997
# 869              0.177227  0.537796        0.404302   0.896
# 896              0.120094       NaN             NaN   1.022
# 911              0.150484       NaN             NaN   0.717
#
# [10 rows x 22 columns]

# %% [markdown]
# # Consumer Cyclical Sector

# %% [markdown]
# ## Filtering Stocks based on Sharpe Ratio

# %%
sharpe_list = []
for i in range(len(df_CC)):
    each = df_CC.iloc[i]
    ticker = each["ticker"]
    sharpe = get_sharpe_ratio(ticker)
    sharpe_list.append(sharpe)

# %%
sharpe_list
# Out:
# [0.355,
#  0.459,
#  0.625,
#  0.434,
#  0.404,
#  0.102,
#  0.714,
#  0.418,
#  0.48,
#  0.577,
#  0.496,
#  0.151,
#  0.325,
#  1.225,
#  0.174,
#  0.254,
#  0.191,
#  0.008,
#  0.3,
#  0.136,
#  0.136,
#  0.218,
#  0.065,
#  0.108,
#  0.855,
#  0.211,
#  0.888,
#  0.435,
#  0.405,
#  0.112,
#  0.447,
#  0.492,
#  0.52,
#  0.447,
#  0.292,
#  0.083,
#  0.304,
#  0.778,
#  0.721,
#  0.34,
#  0.618,
#  0.364,
#  0.714,
#  0.155,
#  0.426,
#  0.358,
#  0.528,
#  -0.121,
#  0.371,
#  -0.018,
#  0.506,
#  0.176,
#  0.535,
#  0.172,
#  0.971,
#  0.621,
#  0.413,
#  0.66,
#  0.097,
#  -0.025,
#  0.327,
#  0.385,
#  0.057,
#  0.705,
#  0.667,
#  0.325,
#  0.402,
#  0.483,
#  0.382,
#  0.427,
#  0.215,
#  0.472,
#  0.092,
#  0.216,
#  0.498,
#  0.251,
#  0.236,
#  0.222,
#  0.209]

# %%
df_CC["sharpe"] = sharpe_list
df_CC
# Out:
# C:\Users\LAVANY~1\AppData\Local\Temp/ipykernel_21904/3842492468.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_CC["sharpe"] = sharpe_list
#     ticker                     name             sector Earnings_expectation  \
# 0      AAP  Advance Auto Parts Inc.  Consumer Cyclical             Increase
# 21    APTV                Aptiv PLC  Consumer Cyclical             Increase
# 65     DHI        D.R. Horton, Inc.  Consumer Cyclical             Increase
# 80       F       Ford Motor Company  Consumer Cyclical             Increase
# 91     GPC    Genuine Parts Company  Consumer Cyclical             Increase
# ..     ...                      ...                ...                  ...
# 898   TXRH    Texas Roadhouse, Inc.  Consumer Cyclical             Increase
# 907   URBN   Urban Outfitters, Inc.  Consumer Cyclical             Increase
# 910     VC      Visteon Corporation  Consumer Cyclical             Increase
# 917    VRA       Vera Bradley, Inc.  Consumer Cyclical             Increase
# 929     WW   WW International, Inc.  Consumer Cyclical             Increase
#
#            irv_status  capm_status   esg_status  current_price  \
# 0    Above Fair Price  UnderValued  Sustainable       214.1500
# 21   Below Fair Price  UnderValued  Sustainable       139.9800
# 65   Above Fair Price  UnderValued      Average        81.3366
# 80   Below Fair Price  UnderValued      Average        17.4300
# 91   Above Fair Price  UnderValued  Sustainable       124.8900
# ..                ...          ...          ...            ...
# 898  Below Fair Price   OverValued      No Data        87.7900
# 907  Below Fair Price  UnderValued      No Data        25.3600
# 910  Below Fair Price  UnderValued      No Data       131.3900
# 917  Above Fair Price  UnderValued      No Data         7.7900
# 929  Above Fair Price  UnderValued      No Data        10.4000
#
#      annu_return_10y    market_cap  ... eps_ttm  growth_estimate_5y  \
# 0           0.103398  1.308405e+10  ...   9.550              0.1525
# 21          0.197323  3.786655e+10  ...   2.941              0.4626
# 65          0.204622  2.897055e+10  ...  11.410              0.1060
# 80          0.074129  6.965446e+10  ...   0.713              0.7767
# 91          0.103717  1.778708e+10  ...   5.609              0.0460
# ..               ...           ...  ...     ...                 ...
# 898         0.199828  6.114135e+09  ...   3.020              0.8417
# 907        -0.015427  2.482336e+09  ...   2.987              3.1615
# 910         0.155275  3.678473e+09  ...   0.984              0.9518
# 917        -0.141295  2.627583e+08  ...   0.607              0.1630
# 929        -0.182074  7.282184e+08  ...   0.700             -0.0670
#
#      pe_forward  pe_trailing  irv_FairValue  ESG_risk  capm_expected_return  \
# 0     13.932986    22.424082   1.091882e+02     12.97              0.171149
# 21    30.364424    47.596054   6.093763e+02     13.49              0.274474
# 65     5.326562     7.128537   2.862672e+01     22.55              0.217341
# 80     8.758794    24.446003   4.370325e+02     29.57              0.150484
# 91    17.202478    22.266000   2.660739e+01     12.53              0.150484
# ..          ...          ...            ...       ...                   ...
# 898   24.251383    29.069536   3.041617e+03    999.00              0.145622
# 907    8.128205     8.490124   1.349236e+06    999.00              0.203970
# 910   30.204597   133.526410   7.676611e+03    999.00              0.268396
# 917   10.116883    12.833608   4.309673e+00    999.00              0.240438
# 929    6.011560    14.857142   7.918767e-01    999.00              0.212479
#
#        AHV_5y  annu_return_5y  sharpe
# 0    0.355467        0.049267   0.355
# 21   0.428095        0.175759   0.459
# 65   0.370627        0.238886   0.625
# 80   0.375582        0.108521   0.434
# 91   0.294242        0.076618   0.404
# ..        ...             ...     ...
# 898  0.401041        0.159949   0.498
# 907  0.503745        0.001591   0.251
# 910  0.463500        0.066498   0.236
# 917  0.593731       -0.064284   0.222
# 929  0.702709       -0.028970   0.209
#
# [79 rows x 22 columns]

# %%
df_CC = df_CC[df_CC["sharpe"] > 0.6]
df_CC
# Out:
#     ticker                            name             sector  \
# 65     DHI               D.R. Horton, Inc.  Consumer Cyclical
# 98     HLT  Hilton Worldwide Holdings Inc.  Consumer Cyclical
# 199   TSLA                     Tesla, Inc.  Consumer Cyclical
# 321   CHDN   Churchill Downs, Incorporated  Consumer Cyclical
# 326   CLAR              Clarus Corporation  Consumer Cyclical
# 437   FIVE                Five Below, Inc.  Consumer Cyclical
# 442    FLL        Full House Resorts, Inc.  Consumer Cyclical
# 447   FNKO                     Funko, Inc.  Consumer Cyclical
# 452   FOXF       Fox Factory Holding Corp.  Consumer Cyclical
# 616   LULU        lululemon athletica inc.  Consumer Cyclical
# 625   MBUU              Malibu Boats, Inc.  Consumer Cyclical
# 629   MCRI   Monarch Casino & Resort, Inc.  Consumer Cyclical
# 780   RICK  RCI Hospitality Holdings, Inc.  Consumer Cyclical
# 792  RUSHA          Rush Enterprises, Inc.  Consumer Cyclical
#
#     Earnings_expectation        irv_status  capm_status   esg_status  \
# 65              Increase  Above Fair Price  UnderValued      Average
# 98              Increase  Below Fair Price  UnderValued  Sustainable
# 199             Increase  Below Fair Price   OverValued      Average
# 321             Increase  Below Fair Price   OverValued      No Data
# 326             Increase  Below Fair Price  UnderValued      No Data
# 437             Increase  Below Fair Price   OverValued      No Data
# 442             Increase  Above Fair Price  UnderValued      No Data
# 447             Increase  Above Fair Price  UnderValued      No Data
# 452             Increase  Above Fair Price  UnderValued      No Data
# 616             Increase  Below Fair Price  UnderValued  Sustainable
# 625             Increase  Above Fair Price  UnderValued      No Data
# 629             Increase  Above Fair Price  UnderValued      No Data
# 780             Increase  Below Fair Price  UnderValued      No Data
# 792             Increase  Below Fair Price  UnderValued      No Data
#
#      current_price  annu_return_10y    market_cap  ... eps_ttm  \
# 65         81.3366         0.204622  2.897055e+10  ...  11.410
# 98        147.9550         0.134492  4.123831e+10  ...   0.140
# 199       806.0500         0.609586  8.094838e+11  ...   3.062
# 321       214.5100         0.285760  8.204814e+09  ...   5.574
# 326        21.4100         0.104810  7.919045e+08  ...   0.554
# 437       159.6400         0.196712  8.943895e+09  ...   4.662
# 442         8.7500         0.119495  2.994906e+08  ...   0.331
# 447        17.1200         0.092467  6.835999e+08  ...   1.037
# 452       120.9000         0.205780  5.090374e+09  ...   3.731
# 616       304.5800         0.164012  3.938189e+10  ...   6.661
# 625        67.3700         0.142686  1.403971e+09  ...   5.497
# 629        73.2800         0.212274  1.373003e+09  ...   3.315
# 780        63.2700         0.212191  6.010593e+08  ...   3.369
# 792        49.3400         0.123774  2.712585e+09  ...   3.708
#
#      growth_estimate_5y  pe_forward  pe_trailing  irv_FairValue  ESG_risk  \
# 65               0.1060    5.326562     7.128537   2.862672e+01     22.55
# 98               2.7265   34.408140  1056.821400   2.914266e+06     19.95
# 199              0.7295   92.014840   263.242980   1.586122e+04     28.54
# 321              2.0990   23.598460    38.484030   8.037688e+05    999.00
# 326              0.3290   13.993464    38.646206   3.935781e+01    999.00
# 437              0.4612   27.242321    34.242813   6.889982e+02    999.00
# 442              0.1500   19.444445    26.435045   4.375000e+00    999.00
# 447              0.0270   11.972029    16.509163   3.092625e+00    999.00
# 452              0.1500   23.613281    32.404182   6.045000e+01    999.00
# 616              0.2790   32.927567    45.725870   3.964841e+02     16.06
# 625              0.1500    8.715395    12.255775   3.368500e+01    999.00
# 629              0.1400   16.654545    22.105580   3.387026e+01    999.00
# 780              0.4000   12.704820    18.780054   1.857974e+02    999.00
# 792              0.2866   11.803828    13.306365   6.774551e+01    999.00
#
#      capm_expected_return    AHV_5y  annu_return_5y  sharpe
# 65               0.217341  0.370627        0.238886   0.625
# 98               0.168718  0.314619        0.209851   0.714
# 199              0.267181  0.611157        0.739589   1.225
# 321              0.165071  0.428761        0.357716   0.855
# 326              0.122525  0.393534        0.306635   0.888
# 437              0.178443  0.452922        0.332526   0.778
# 442              0.240438  0.704348        0.296359   0.721
# 447              0.293924       NaN             NaN   0.618
# 452              0.230713  0.462622        0.367678   0.714
# 616              0.179658  0.392863        0.361296   0.971
# 625              0.229497  0.490083        0.277316   0.621
# 629              0.223419  0.466259        0.268473   0.660
# 780              0.258672  0.608473        0.302701   0.705
# 792              0.167502  0.352175        0.187417   0.667
#
# [14 rows x 22 columns]

# %% [markdown]
# # Technology

# %% [markdown]
# ## Filtering Stocks based on Sharpe Ratio

# %%
sharpe_list = []
for i in range(len(df_tech)):
    each = df_tech.iloc[i]
    ticker = each["ticker"]
    sharpe = get_sharpe_ratio(ticker)
    sharpe_list.append(sharpe)

# %%
sharpe_list
# Out:
# [0.613,
#  1.017,
#  0.767,
#  0.762,
#  0.755,
#  0.708,
#  1.38,
#  1.052,
#  0.829,
#  0.821,
#  0.877,
#  0.651,
#  0.708,
#  0.686,
#  0.66,
#  0.784,
#  0.716,
#  0.891,
#  0.636,
#  0.727,
#  1.824,
#  1.121,
#  0.604,
#  0.688]

# %%
df_tech["sharpe"] = sharpe_list
df_tech
# Out:
# C:\Users\LAVANY~1\AppData\Local\Temp/ipykernel_21904/505389931.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_tech["sharpe"] = sharpe_list
#     ticker                             name      sector Earnings_expectation  \
# 5     ADSK                   Autodesk, Inc.  Technology             Increase
# 14     AMD     Advanced Micro Devices, Inc.  Technology             Increase
# 17    ANSS                      ANSYS, Inc.  Technology             Increase
# 73    EPAM               EPAM Systems, Inc.  Technology             Increase
# 176   QCOM            QUALCOMM Incorporated  Technology             Increase
# 243   AOSL  Alpha and Omega Semiconductor L  Technology             Increase
# 244   APPS            Digital Turbine, Inc.  Technology             Increase
# 249   ASML  ASML Holding N.V. - New York Re  Technology             Increase
# 258   AUDC                  AudioCodes Ltd.  Technology             Increase
# 381   DIOD              Diodes Incorporated  Technology             Increase
# 386   DSGX  The Descartes Systems Group Inc  Technology             Increase
# 555   INOD                    Innodata Inc.  Technology             Increase
# 621   MANT  ManTech International Corporati  Technology             Increase
# 639   MGIC  Magic Software Enterprises Ltd.  Technology             Increase
# 686   NSIT        Insight Enterprises, Inc.  Technology             Increase
# 708     ON     ON Semiconductor Corporation  Technology             Increase
# 751   POWI         Power Integrations, Inc.  Technology             Increase
# 781   RIOT             Riot Blockchain, Inc  Technology             Increase
# 783   RMBS                     Rambus, Inc.  Technology             Increase
# 818    SGH      SMART Global Holdings, Inc.  Technology             Increase
# 825   SITM               SiTime Corporation  Technology             Increase
# 890    TTD             The Trade Desk, Inc.  Technology             Increase
# 901   UCTT       Ultra Clean Holdings, Inc.  Technology             Increase
# 923   WDAY                    Workday, Inc.  Technology             Increase
#
#            irv_status  capm_status   esg_status  current_price  \
# 5    Below Fair Price  UnderValued  Sustainable       217.3800
# 14   Below Fair Price   OverValued      No Data       117.1100
# 17   Above Fair Price  UnderValued  Sustainable       305.4575
# 73   Below Fair Price   OverValued      No Data       428.8350
# 176  Below Fair Price  UnderValued  Sustainable       165.6500
# 243  Above Fair Price  UnderValued      No Data        49.2600
# 244  Below Fair Price  UnderValued      No Data        43.8000
# 249  Below Fair Price   OverValued      No Data       634.7900
# 258  Below Fair Price   OverValued      No Data        27.6750
# 381  Above Fair Price  UnderValued      No Data        87.1300
# 386  Below Fair Price   OverValued      No Data        69.6200
# 555  Above Fair Price  UnderValued      No Data         5.0600
# 621  Above Fair Price  UnderValued      No Data        78.5700
# 639  Above Fair Price  UnderValued      No Data        18.3000
# 686  Above Fair Price  UnderValued      No Data        99.4000
# 708  Below Fair Price  UnderValued      Average        58.4400
# 751  Below Fair Price   OverValued      No Data        87.7500
# 781  Above Fair Price  UnderValued      No Data        15.9500
# 783  Above Fair Price  UnderValued      No Data        26.2900
# 818  Below Fair Price   OverValued      No Data        28.9900
# 825  Below Fair Price   OverValued      No Data       188.8200
# 890  Below Fair Price   OverValued      No Data        73.6800
# 901  Above Fair Price  UnderValued      No Data        45.8500
# 923  Above Fair Price  UnderValued  Sustainable       216.5600
#
#      annu_return_10y    market_cap  ... eps_ttm  growth_estimate_5y  \
# 5           0.190997  4.781773e+10  ...   5.928              0.2883
# 14          0.319034  1.414232e+11  ...   3.242              0.3532
# 17          0.163292  2.665208e+10  ...   5.318              0.1118
# 73          0.408649  2.432335e+10  ...   7.211              0.2850
# 176         0.130769  1.855280e+11  ...   7.870              0.2562
# 243         0.165397  1.299356e+09  ...   2.612              0.1700
# 244         0.278657  4.232205e+09  ...   0.530              0.5000
# 249         0.341963  2.580256e+11  ...  15.017              0.2980
# 258         0.234188  9.141052e+08  ...   1.028              0.2500
# 381         0.131229  3.922401e+09  ...   4.123              0.1500
# 386         0.240316  5.893862e+09  ...   0.980              0.2600
# 555        -0.007579  1.373967e+08  ...   0.017              0.2000
# 621         0.109370  3.200871e+09  ...   3.401              0.0538
# 639         0.134997  9.082454e+08  ...   0.570              0.1000
# 686         0.162830  3.467649e+09  ...   5.767              0.0744
# 708         0.204125  2.517794e+10  ...   1.532              0.5545
# 751         0.172236  5.294107e+09  ...   2.458              0.2529
# 781         0.208131  1.859499e+09  ...   0.188              0.2000
# 783         0.131836  2.875206e+09  ...   0.002              0.0998
# 818         0.155233  7.154384e+08  ...   0.830              0.3606
# 825         0.302106  3.881006e+09  ...   0.727              1.2498
# 890         0.376786  3.793717e+10  ...   0.561              0.2800
# 901         0.183616  2.058665e+09  ...   2.230              0.2000
# 923         0.160951  5.414000e+10  ...   0.117              0.1579
#
#      pe_forward   pe_trailing  irv_FairValue  ESG_risk  capm_expected_return  \
# 5     31.967648     36.670040     302.038344     15.45              0.193030
# 14    35.062874     36.122765     253.245268    999.00              0.256240
# 17    38.470715     57.438416     112.688671     13.16              0.169933
# 73    38.391674     59.469560     582.247739    999.00              0.193030
# 176   14.231099     21.048285     183.404501     18.00              0.173580
# 243   11.617925     18.859112      28.764485    999.00              0.330391
# 244   20.372091     82.641510     239.323247    999.00              0.285415
# 249   32.420326     42.271423     943.608234    999.00              0.134681
# 258   16.875000     26.921206      29.306718    999.00              0.084842
# 381   14.919519     21.132670      43.564999    999.00              0.148053
# 386   66.942314     71.040820      79.206056    999.00              0.144406
# 555 -101.200000    297.647030       3.710831    999.00              0.268396
# 621   22.512894     23.102028      17.896575    999.00              0.115232
# 639   17.428572     32.105263       6.133024    999.00              0.188167
# 686   12.925878     17.235998      26.950686    999.00              0.234360
# 708   17.926380     38.146214     440.267051     26.16              0.230713
# 751   26.753050     35.699757      94.882094    999.00              0.138328
# 781    8.763736     84.840430      11.697185    999.00              0.539473
# 783   18.006850  13145.000000       8.796370    999.00              0.139544
# 818    4.288461     34.927710      65.843339    999.00              0.148053
# 825   55.049564    259.724900   39630.782889    999.00              0.143190
# 890   80.967030    131.336900      96.589249    999.00              0.302433
# 901    9.713984     20.560537      33.624820    999.00              0.261103
# 923   60.831463   1850.940200     115.161464     13.09              0.183305
#
#        AHV_5y  annu_return_5y  sharpe
# 5    0.384894        0.209161   0.613
# 14   0.564107        0.569607   1.017
# 17   0.316793        0.271663   0.767
# 73   0.376405        0.422642   0.762
# 176  0.375961        0.297623   0.755
# 243  0.570794        0.201750   0.708
# 244  0.719036        1.325025   1.380
# 249  0.360669        0.411064   1.052
# 258  0.446357        0.362672   0.829
# 381  0.401822        0.286506   0.821
# 386  0.291432        0.265617   0.877
# 555  0.669394        0.192740   0.651
# 621  0.344249        0.170329   0.708
# 639  0.334100        0.227677   0.686
# 686  0.366896        0.221251   0.660
# 708  0.507655        0.343777   0.784
# 751  0.396886        0.226355   0.716
# 781  1.229896        0.422364   0.891
# 783  0.349622        0.160927   0.636
# 818       NaN             NaN   0.727
# 825       NaN             NaN   1.824
# 890  0.683392        0.956083   1.121
# 901  0.610451        0.290763   0.604
# 923  0.383779        0.213788   0.688
#
# [24 rows x 22 columns]

# %%
df_tech = df_tech[df_tech["sharpe"] > 0.6]
df_tech
# Out:
#     ticker                             name      sector Earnings_expectation  \
# 5     ADSK                   Autodesk, Inc.  Technology             Increase
# 14     AMD     Advanced Micro Devices, Inc.  Technology             Increase
# 17    ANSS                      ANSYS, Inc.  Technology             Increase
# 73    EPAM               EPAM Systems, Inc.  Technology             Increase
# 176   QCOM            QUALCOMM Incorporated  Technology             Increase
# 243   AOSL  Alpha and Omega Semiconductor L  Technology             Increase
# 244   APPS            Digital Turbine, Inc.  Technology             Increase
# 249   ASML  ASML Holding N.V. - New York Re  Technology             Increase
# 258   AUDC                  AudioCodes Ltd.  Technology             Increase
# 381   DIOD              Diodes Incorporated  Technology             Increase
# 386   DSGX  The Descartes Systems Group Inc  Technology             Increase
# 555   INOD                    Innodata Inc.  Technology             Increase
# 621   MANT  ManTech International Corporati  Technology             Increase
# 639   MGIC  Magic Software Enterprises Ltd.  Technology             Increase
# 686   NSIT        Insight Enterprises, Inc.  Technology             Increase
# 708     ON     ON Semiconductor Corporation  Technology             Increase
# 751   POWI         Power Integrations, Inc.  Technology             Increase
# 781   RIOT             Riot Blockchain, Inc  Technology             Increase
# 783   RMBS                     Rambus, Inc.  Technology             Increase
# 818    SGH      SMART Global Holdings, Inc.  Technology             Increase
# 825   SITM               SiTime Corporation  Technology             Increase
# 890    TTD             The Trade Desk, Inc.  Technology             Increase
# 901   UCTT       Ultra Clean Holdings, Inc.  Technology             Increase
# 923   WDAY                    Workday, Inc.  Technology             Increase
#
#            irv_status  capm_status   esg_status  current_price  \
# 5    Below Fair Price  UnderValued  Sustainable       217.3800
# 14   Below Fair Price   OverValued      No Data       117.1100
# 17   Above Fair Price  UnderValued  Sustainable       305.4575
# 73   Below Fair Price   OverValued      No Data       428.8350
# 176  Below Fair Price  UnderValued  Sustainable       165.6500
# 243  Above Fair Price  UnderValued      No Data        49.2600
# 244  Below Fair Price  UnderValued      No Data        43.8000
# 249  Below Fair Price   OverValued      No Data       634.7900
# 258  Below Fair Price   OverValued      No Data        27.6750
# 381  Above Fair Price  UnderValued      No Data        87.1300
# 386  Below Fair Price   OverValued      No Data        69.6200
# 555  Above Fair Price  UnderValued      No Data         5.0600
# 621  Above Fair Price  UnderValued      No Data        78.5700
# 639  Above Fair Price  UnderValued      No Data        18.3000
# 686  Above Fair Price  UnderValued      No Data        99.4000
# 708  Below Fair Price  UnderValued      Average        58.4400
# 751  Below Fair Price   OverValued      No Data        87.7500
# 781  Above Fair Price  UnderValued      No Data        15.9500
# 783  Above Fair Price  UnderValued      No Data        26.2900
# 818  Below Fair Price   OverValued      No Data        28.9900
# 825  Below Fair Price   OverValued      No Data       188.8200
# 890  Below Fair Price   OverValued      No Data        73.6800
# 901  Above Fair Price  UnderValued      No Data        45.8500
# 923  Above Fair Price  UnderValued  Sustainable       216.5600
#
#      annu_return_10y    market_cap  ... eps_ttm  growth_estimate_5y  \
# 5           0.190997  4.781773e+10  ...   5.928              0.2883
# 14          0.319034  1.414232e+11  ...   3.242              0.3532
# 17          0.163292  2.665208e+10  ...   5.318              0.1118
# 73          0.408649  2.432335e+10  ...   7.211              0.2850
# 176         0.130769  1.855280e+11  ...   7.870              0.2562
# 243         0.165397  1.299356e+09  ...   2.612              0.1700
# 244         0.278657  4.232205e+09  ...   0.530              0.5000
# 249         0.341963  2.580256e+11  ...  15.017              0.2980
# 258         0.234188  9.141052e+08  ...   1.028              0.2500
# 381         0.131229  3.922401e+09  ...   4.123              0.1500
# 386         0.240316  5.893862e+09  ...   0.980              0.2600
# 555        -0.007579  1.373967e+08  ...   0.017              0.2000
# 621         0.109370  3.200871e+09  ...   3.401              0.0538
# 639         0.134997  9.082454e+08  ...   0.570              0.1000
# 686         0.162830  3.467649e+09  ...   5.767              0.0744
# 708         0.204125  2.517794e+10  ...   1.532              0.5545
# 751         0.172236  5.294107e+09  ...   2.458              0.2529
# 781         0.208131  1.859499e+09  ...   0.188              0.2000
# 783         0.131836  2.875206e+09  ...   0.002              0.0998
# 818         0.155233  7.154384e+08  ...   0.830              0.3606
# 825         0.302106  3.881006e+09  ...   0.727              1.2498
# 890         0.376786  3.793717e+10  ...   0.561              0.2800
# 901         0.183616  2.058665e+09  ...   2.230              0.2000
# 923         0.160951  5.414000e+10  ...   0.117              0.1579
#
#      pe_forward   pe_trailing  irv_FairValue  ESG_risk  capm_expected_return  \
# 5     31.967648     36.670040     302.038344     15.45              0.193030
# 14    35.062874     36.122765     253.245268    999.00              0.256240
# 17    38.470715     57.438416     112.688671     13.16              0.169933
# 73    38.391674     59.469560     582.247739    999.00              0.193030
# 176   14.231099     21.048285     183.404501     18.00              0.173580
# 243   11.617925     18.859112      28.764485    999.00              0.330391
# 244   20.372091     82.641510     239.323247    999.00              0.285415
# 249   32.420326     42.271423     943.608234    999.00              0.134681
# 258   16.875000     26.921206      29.306718    999.00              0.084842
# 381   14.919519     21.132670      43.564999    999.00              0.148053
# 386   66.942314     71.040820      79.206056    999.00              0.144406
# 555 -101.200000    297.647030       3.710831    999.00              0.268396
# 621   22.512894     23.102028      17.896575    999.00              0.115232
# 639   17.428572     32.105263       6.133024    999.00              0.188167
# 686   12.925878     17.235998      26.950686    999.00              0.234360
# 708   17.926380     38.146214     440.267051     26.16              0.230713
# 751   26.753050     35.699757      94.882094    999.00              0.138328
# 781    8.763736     84.840430      11.697185    999.00              0.539473
# 783   18.006850  13145.000000       8.796370    999.00              0.139544
# 818    4.288461     34.927710      65.843339    999.00              0.148053
# 825   55.049564    259.724900   39630.782889    999.00              0.143190
# 890   80.967030    131.336900      96.589249    999.00              0.302433
# 901    9.713984     20.560537      33.624820    999.00              0.261103
# 923   60.831463   1850.940200     115.161464     13.09              0.183305
#
#        AHV_5y  annu_return_5y  sharpe
# 5    0.384894        0.209161   0.613
# 14   0.564107        0.569607   1.017
# 17   0.316793        0.271663   0.767
# 73   0.376405        0.422642   0.762
# 176  0.375961        0.297623   0.755
# 243  0.570794        0.201750   0.708
# 244  0.719036        1.325025   1.380
# 249  0.360669        0.411064   1.052
# 258  0.446357        0.362672   0.829
# 381  0.401822        0.286506   0.821
# 386  0.291432        0.265617   0.877
# 555  0.669394        0.192740   0.651
# 621  0.344249        0.170329   0.708
# 639  0.334100        0.227677   0.686
# 686  0.366896        0.221251   0.660
# 708  0.507655        0.343777   0.784
# 751  0.396886        0.226355   0.716
# 781  1.229896        0.422364   0.891
# 783  0.349622        0.160927   0.636
# 818       NaN             NaN   0.727
# 825       NaN             NaN   1.824
# 890  0.683392        0.956083   1.121
# 901  0.610451        0.290763   0.604
# 923  0.383779        0.213788   0.688
#
# [24 rows x 22 columns]

# %% [markdown]
# # Industrials

# %% [markdown]
# ## Filtering Stocks based on Sharpe Ratio

# %%
sharpe_list = []
for i in range(len(df_industrials)):
    each = df_industrials.iloc[i]
    ticker = each["ticker"]
    sharpe = get_sharpe_ratio(ticker)
    sharpe_list.append(sharpe)

# %%
sharpe_list
# Out:
# [-0.005,
#  0.396,
#  0.767,
#  0.743,
#  0.401,
#  0.406,
#  0.487,
#  0.262,
#  0.359,
#  0.631,
#  0.335,
#  0.739,
#  0.753,
#  0.496,
#  0.733,
#  -0.014,
#  1.235,
#  0.542,
#  0.409,
#  0.322,
#  0.679,
#  0.509,
#  0.166,
#  0.25,
#  0.221,
#  0.71,
#  0.048,
#  0.397,
#  0.105,
#  0.873,
#  -0.003,
#  0.482,
#  0.242,
#  -0.338,
#  0.313,
#  0.218,
#  0.339,
#  0.214,
#  0.455,
#  0.632,
#  0.561,
#  0.337,
#  0.48,
#  0.313,
#  0.61,
#  0.034,
#  0.759,
#  0.541,
#  0.353,
#  0.226,
#  0.656,
#  -0.154,
#  0.445,
#  0.181,
#  0.653,
#  0.346,
#  0.789,
#  0.396,
#  0.465,
#  0.083,
#  0.56,
#  -0.175,
#  0.032,
#  0.74,
#  0.249,
#  0.271,
#  0.43,
#  0.563,
#  0.593,
#  0.401,
#  0.427,
#  0.239,
#  0.599,
#  0.662,
#  0.489,
#  0.241,
#  0.585,
#  0.212,
#  0.518,
#  1.049,
#  0.633,
#  0.221,
#  0.126,
#  -0.084,
#  0.496,
#  1.007,
#  0.374,
#  0.219,
#  0.445,
#  0.631,
#  0.385,
#  0.282,
#  0.483]

# %%
df_industrials["sharpe"] = sharpe_list
df_industrials
# Out:
# C:\Users\LAVANY~1\AppData\Local\Temp/ipykernel_21904/77830193.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_industrials["sharpe"] = sharpe_list
#     ticker                             name       sector Earnings_expectation  \
# 11     ALK           Alaska Air Group, Inc.  Industrials             Increase
# 12    ALLE                     Allegion plc  Industrials             Increase
# 15     AME                     AMETEK, Inc.  Industrials             Increase
# 37     CAT                Caterpillar, Inc.  Industrials             Increase
# 45    CHRW    C.H. Robinson Worldwide, Inc.  Industrials             Increase
# ..     ...                              ...          ...                  ...
# 904    ULH  Universal Logistics Holdings, I  Industrials             Increase
# 908   USAK                  USA Truck, Inc.  Industrials             Increase
# 918   VRRM       Verra Mobility Corporation  Industrials             Increase
# 920   VSEC                  VSE Corporation  Industrials             Increase
# 930    WWD                   Woodward, Inc.  Industrials             Increase
#
#            irv_status  capm_status       esg_status  current_price  \
# 11   Above Fair Price  UnderValued          No Data        58.9750
# 12   Above Fair Price  UnderValued          Average       114.1447
# 15   Above Fair Price  UnderValued          Average       128.2800
# 37   Below Fair Price  UnderValued  Not Sustainable       193.1600
# 45   Above Fair Price  UnderValued      Sustainable        92.0950
# ..                ...          ...              ...            ...
# 904  Above Fair Price  UnderValued          No Data        18.0900
# 908  Below Fair Price  UnderValued          No Data        24.0400
# 918  Below Fair Price  UnderValued          No Data        17.2700
# 920  Above Fair Price  UnderValued          No Data        47.3300
# 930  Above Fair Price  UnderValued          No Data       120.0800
#
#      annu_return_10y    market_cap  ... eps_ttm  growth_estimate_5y  \
# 11          0.141697  7.425660e+09  ...   3.770             -0.2340
# 12          0.097180  1.023831e+10  ...   5.086              0.0777
# 15          0.155568  2.967437e+10  ...   3.990             -0.0120
# 37          0.084214  1.044884e+11  ...   9.348              0.3224
# 45          0.055239  1.197115e+10  ...   5.646              0.1239
# ..               ...           ...  ...     ...                 ...
# 904         0.030170  4.869738e+08  ...   2.740              0.0300
# 908         0.108008  2.136505e+08  ...   2.057              0.2760
# 918         0.056159  2.695225e+09  ...   0.058              0.3080
# 920         0.148449  6.016543e+08  ...   0.633              0.1960
# 930         0.111932  7.573710e+09  ...   3.180              0.1820
#
#      pe_forward  pe_trailing  irv_FairValue  ESG_risk  capm_expected_return  \
# 11     9.073076    15.643236       0.761055    999.00              0.207617
# 12    19.955368    22.442923      31.814578     23.59              0.157777
# 15    23.799630    32.150375      16.355389     25.95              0.178443
# 37    17.721102    20.663244     339.525357     34.28              0.128603
# 45    15.222314    16.311548      37.451959     19.83              0.111585
# ..          ...          ...            ...       ...                   ...
# 904    5.566154     6.602190       3.354772    999.00              0.199108
# 908    9.246155    11.686924      30.639383    999.00              0.273259
# 918   18.178947   297.758640      27.507524    999.00              0.196676
# 920   12.198454    74.770935      33.682675    999.00              0.199108
# 930   25.333336    37.761005      76.863011    999.00              0.218557
#
#        AHV_5y  annu_return_5y  sharpe
# 11   0.454054       -0.086043  -0.005
# 12   0.279213        0.118004   0.396
# 15   0.269622        0.206944   0.767
# 37   0.314958        0.175801   0.743
# 45   0.262005        0.071573   0.401
# ..        ...             ...     ...
# 904  0.403463        0.069257   0.445
# 908  0.638308        0.234642   0.631
# 918       NaN             NaN   0.385
# 920  0.472182        0.061138   0.282
# 930  0.389052        0.119014   0.483
#
# [93 rows x 22 columns]

# %%
df_industrials = df_industrials[df_industrials["sharpe"] > 0.6]
df_industrials
# Out:
#     ticker                             name       sector Earnings_expectation  \
# 15     AME                     AMETEK, Inc.  Industrials             Increase
# 37     CAT                Caterpillar, Inc.  Industrials             Increase
# 92     GWW              W.W. Grainger, Inc.  Industrials             Increase
# 107     IR              Ingersoll Rand Inc.  Industrials             Increase
# 112      J    Jacobs Engineering Group Inc.  Industrials             Increase
# 125    LHX      L3Harris Technologies, Inc.  Industrials             Increase
# 158   ODFL  Old Dominion Freight Line, Inc.  Industrials             Increase
# 207    URI             United Rentals, Inc.  Industrials             Increase
# 245   ARCB              ArcBest Corporation  Industrials             Increase
# 297    CAR          Avis Budget Group, Inc.  Industrials             Increase
# 410   ESEA                    Euroseas Ltd.  Industrials             Increase
# 467   FWRD          Forward Air Corporation  Industrials             Increase
# 477   GLDD  Great Lakes Dredge & Dock Corpo  Industrials             Increase
# 525   HSON              Hudson Global, Inc.  Industrials             Increase
# 563   ISSC  Innovative Solutions and Suppor  Industrials             Increase
# 577   KRNT              Kornit Digital Ltd.  Industrials             Increase
# 642   MGRC                 McGrath RentCorp  Industrials             Increase
# 772   RCII               Rent-A-Center Inc.  Industrials             Increase
# 798   SAIA                       Saia, Inc.  Industrials             Increase
# 806   SBLK         Star Bulk Carriers Corp.  Industrials             Increase
# 885   TRNS                   Transcat, Inc.  Industrials             Increase
# 908   USAK                  USA Truck, Inc.  Industrials             Increase
#
#            irv_status  capm_status       esg_status  current_price  \
# 15   Above Fair Price  UnderValued          Average         128.28
# 37   Below Fair Price  UnderValued  Not Sustainable         193.16
# 92   Above Fair Price  UnderValued      Sustainable         474.32
# 107  Above Fair Price  UnderValued          No Data          53.31
# 112  Above Fair Price  UnderValued          Average         120.31
# 125  Below Fair Price   OverValued          No Data         220.65
# 158  Below Fair Price   OverValued          No Data         287.86
# 207  Above Fair Price  UnderValued      Sustainable         311.82
# 245  Below Fair Price  UnderValued          No Data          85.22
# 297  Below Fair Price   OverValued          No Data         152.02
# 410  Above Fair Price  UnderValued          No Data          26.80
# 467  Above Fair Price  UnderValued          No Data          98.63
# 477  Above Fair Price  UnderValued          No Data          13.96
# 525  Above Fair Price  UnderValued          No Data          29.45
# 563  Above Fair Price  UnderValued          No Data           7.26
# 577  Below Fair Price  UnderValued          No Data          87.40
# 642  Above Fair Price  UnderValued          No Data          72.98
# 772  Below Fair Price  UnderValued          No Data          37.71
# 798  Below Fair Price   OverValued          No Data         257.07
# 806  Above Fair Price  UnderValued          No Data          31.31
# 885  Below Fair Price   OverValued          No Data          74.73
# 908  Below Fair Price  UnderValued          No Data          24.04
#
#      annu_return_10y    market_cap  ... eps_ttm  growth_estimate_5y  \
#
# 297  0.807664        0.347936   0.873
# 410  0.931402        0.144480   0.632
# 467  0.314318        0.173151   0.610
# 477  0.407094        0.222752   0.759
# 525  0.472020        0.175286   0.656
# 563  0.544723        0.172245   0.653
# 577  0.510600        0.392363   0.789
# 642  0.339468        0.179086   0.740
# 772  0.480356        0.294029   0.662
# 798  0.398032        0.398455   1.049
# 806  0.584302        0.270187   0.633
# 885  0.423816        0.457382   1.007
# 908  0.638308        0.234642   0.631
#
# [22 rows x 22 columns]

# %% [markdown]
# # Healthcare

# %% [markdown]
# ## Filtering Stocks based on Sharpe Ratio

# %%
sharpe_list = []
for i in range(len(df_healthcare)):
    each = df_healthcare.iloc[i]
    ticker = each["ticker"]
    sharpe = get_sharpe_ratio(ticker)
    sharpe_list.append(sharpe)

# %%
sharpe_list
# Out:
# [0.073,
#  0.861,
#  0.903,
#  0.782,
#  -0.181,
#  -0.016,
#  -0.049,
#  0.384,
#  0.613,
#  -0.061,
#  0.087,
#  0.748,
#  0.414,
#  0.816,
#  -0.008,
#  0.445,
#  0.274,
#  0.669,
#  0.601,
#  0.606,
#  0.585,
#  0.046,
#  0.208,
#  0.43,
#  0.331,
#  0.057,
#  0.343,
#  0.822,
#  -0.068,
#  1.211,
#  0.114,
#  0.087,
#  0.937,
#  0.629,
#  0.338,
#  0.738,
#  1.143,
#  0.392,
#  0.059,
#  0.391,
#  0.073,
#  0.996,
#  0.204,
#  0.431,
#  0.946,
#  0.163,
#  0.567,
#  0.316,
#  0.443,
#  0.454,
#  0.924,
#  0.705]

# %%
df_healthcare["sharpe"] = sharpe_list
df_healthcare
# Out:
# C:\Users\LAVANY~1\AppData\Local\Temp/ipykernel_21904/4048192744.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_healthcare["sharpe"] = sharpe_list
#     ticker                             name      sector Earnings_expectation  \
# 30    BIIB                      Biogen Inc.  Healthcare             Increase
# 56    CTLT                   Catalent, Inc.  Healthcare             Increase
# 102   IDXX         IDEXX Laboratories, Inc.  Healthcare             Increase
# 106    IQV             IQVIA Holdings, Inc.  Healthcare             Increase
# 212    WBA   Walgreens Boots Alliance, Inc.  Healthcare             Increase
# 218   XRAY             DENTSPLY SIRONA Inc.  Healthcare             Increase
# 230   AGIO      Agios Pharmaceuticals, Inc.  Healthcare             Increase
# 255   ATRS             Antares Pharma, Inc.  Healthcare             Decrease
# 272   BDSI  BioDelivery Sciences Internatio  Healthcare             Increase
# 277   BIOC                    Biocept, Inc.  Healthcare             Increase
# 281   BMRN     BioMarin Pharmaceutical Inc.  Healthcare             Increase
# 287   BRKR               Bruker Corporation  Healthcare             Increase
# 308   CCRN   Cross Country Healthcare, Inc.  Healthcare             Decrease
# 310   CDMO           Avid Bioservices, Inc.  Healthcare             Increase
# 316   CFMS                  Conformis, Inc.  Healthcare             Increase
# 337   COLL   Collegium Pharmaceutical, Inc.  Healthcare             Increase
# 345   CPSI  Computer Programs and Systems,   Healthcare             Increase
# 351   CRSP           CRISPR Therapeutics AG  Healthcare             Increase
# 355   CSBR         Champions Oncology, Inc.  Healthcare             Increase
# 367   CUTR                     Cutera, Inc.  Healthcare             Increase
# 395   EDAP                    EDAP TMS S.A.  Healthcare             Increase
# 403   ENDP           Endo International plc  Healthcare             Increase
# 414   EXEL                   Exelixis, Inc.  Healthcare             Increase
# 481   GMAB                       Genmab A/S  Healthcare             Increase
# 524   HSKA                Heska Corporation  Healthcare             Increase
# 526   HSTM               HealthStream, Inc.  Healthcare             Increase
# 536   IART  Integra LifeSciences Holdings C  Healthcare             Increase
# 542   ICLR                         ICON plc  Healthcare             Increase
# 553   INGN                      Inogen, Inc  Healthcare             Increase
# 554   INMD                      InMode Ltd.  Healthcare             Increase
# 561   IRWD   Ironwood Pharmaceuticals, Inc.  Healthcare             Decrease
# 576   KMDA                      Kamada Ltd.  Healthcare             Increase
# 631   MEDP           Medpace Holdings, Inc.  Healthcare             Increase
# 651   MODV                   ModivCare Inc.  Healthcare             Increase
# 697   NXGN         NextGen Healthcare, Inc.  Healthcare             Increase
# 711   OPCH         Option Care Health, Inc.  Healthcare             Increase
# 715   OPRX           OptimizeRx Corporation  Healthcare             Increase
# 716   ORGO      Organogenesis Holdings Inc.  Healthcare             Increase
# 724   PAHC  Phibro Animal Health Corporatio  Healthcare             Increase
# 727   PCRX         Pacira BioSciences, Inc.  Healthcare             Increase
# 731   PDCO        Patterson Companies, Inc.  Healthcare             Increase
# 739   PGNY                    Progyny, Inc.  Healthcare             Decrease
# 740   PINC                    Premier, Inc.  Healthcare             Increase
# 750   PNTG          The Pennant Group, Inc.  Healthcare             Increase
# 778   RGEN             Repligen Corporation  Healthcare             Increase
# 797   SAGE          Sage Therapeutics, Inc.  Healthcare             Increase
# 821   SIGA           SIGA Technologies Inc.  Healthcare             Increase
# 839    SNY                           Sanofi  Healthcare             Increase
# 848   SRDX                  Surmodics, Inc.  Healthcare             Increase
# 865   SYNH              Syneos Health, Inc.  Healthcare             Increase
# 882   TNDM       Tandem Diabetes Care, Inc.  Healthcare             Increase
# 931   XOMA                 XOMA Corporation  Healthcare             Increase
#
#            irv_status  capm_status       esg_status  current_price  \
# 30   Above Fair Price  UnderValued  Not Sustainable       210.0000
# 56   Above Fair Price  UnderValued          No Data        97.6100
# 102  Below Fair Price   OverValued  Not Sustainable       489.5600
# 106  Above Fair Price  UnderValued      Sustainable       226.1600
# 212  Above Fair Price  UnderValued      Sustainable        46.1800
# 218  Below Fair Price  UnderValued  Not Sustainable        55.1800
# 230  Below Fair Price  UnderValued          No Data        29.0000
# 255  Below Fair Price  UnderValued          No Data         3.4250
# 272  Below Fair Price  UnderValued          No Data         5.5600
# 277  Below Fair Price  UnderValued          No Data         2.2600
# 281  Below Fair Price   OverValued          Average        86.3650
# 287  Above Fair Price  UnderValued          No Data        68.9650
# 308  Below Fair Price  UnderValued          No Data        20.9450
# 310  Above Fair Price  UnderValued          No Data        19.6450
# 316  Above Fair Price  UnderValued          No Data         0.5864
# 337  Above Fair Price  UnderValued          No Data        22.1700
# 345  Above Fair Price  UnderValued          No Data        29.8300
# 351  Above Fair Price  UnderValued          No Data        55.6600
# 355  Above Fair Price  UnderValued          No Data         7.8900
# 367  Above Fair Price  UnderValued          No Data        33.4500
# 395  Above Fair Price  UnderValued          No Data         7.2100
# 403  Above Fair Price  UnderValued          No Data         3.0100
# 414  Below Fair Price   OverValued          No Data        19.6000
# 481  Below Fair Price   OverValued          No Data        31.1500
# 524  Below Fair Price   OverValued          No Data       122.8900
# 526  Above Fair Price  UnderValued          No Data        19.7600
# 536  Above Fair Price  UnderValued          No Data        65.3800
# 542  Below Fair Price   OverValued          No Data       220.2500
# 553  Above Fair Price  UnderValued          No Data        28.5400
# 554  Below Fair Price  UnderValued          No Data        40.9000
# 561  Below Fair Price  UnderValued          No Data        10.8700
# 576  Above Fair Price  UnderValued          No Data         5.7200
# 631  Above Fair Price  UnderValued          No Data       140.0300
# 651  Below Fair Price   OverValued          No Data       101.5100
# 697  Above Fair Price  UnderValued          No Data        18.7900
# 711  Above Fair Price  UnderValued          No Data        23.1900
# 715  Below Fair Price   OverValued          No Data        41.6500
# 716  Below Fair Price  UnderValued          No Data         6.7800
# 724  Above Fair Price  UnderValued          No Data        20.6300
# 727  Below Fair Price   OverValued          No Data        62.7100
# 731  Above Fair Price  UnderValued          No Data        29.3600
# 739  Below Fair Price  UnderValued          No Data        36.1700
# 740  Above Fair Price  UnderValued          No Data        35.8100
# 750  Below Fair Price  UnderValued          No Data        13.8800
# 778  Below Fair Price   OverValued          No Data       181.4600
# 797  Below Fair Price  UnderValued          No Data        34.0400
# 821  Above Fair Price  UnderValued          No Data         6.1700
# 839  Above Fair Price  UnderValued          No Data        52.8900
# 848  Above Fair Price  UnderValued          No Data        43.1400
# 865  Above Fair Price  UnderValued          No Data        78.5000
# 882  Below Fair Price  UnderValued          No Data       105.2100
# 931  Above Fair Price  UnderValued          No Data        20.7600
#
#      annu_return_10y    market_cap  ...  eps_ttm  growth_estimate_5y  \
# 30          0.060577  3.084753e+10  ...  10.2170             -0.0650
# 56          0.171804  1.670966e+10  ...   3.1770              0.1617
# 102         0.272290  4.151156e+10  ...   8.7180              0.2430
# 106         0.183066  4.320561e+10  ...   3.9290              0.2213
# 212         0.056427  3.989698e+10  ...   2.9330              0.0293
# 218         0.044138  1.206273e+10  ...   1.9020              0.2497
# 230        -0.007540  1.574947e+09  ...  24.9500              0.3900
# 255         0.024070  5.823939e+08  ...   0.3740              0.7890
# 272         0.091710  5.493052e+08  ...   0.2900              0.2500
# 277        -0.560788  3.806337e+07  ...   0.2190              0.4000
# 281         0.093654  1.585601e+10  ...   0.0360              0.3216
# 287         0.159607  1.045889e+10  ...   1.7710              0.2055
# 308         0.132787  7.959875e+08  ...   1.5970              0.4109
# 310         0.146303  1.209769e+09  ...   0.1360              0.1500
# 316        -0.276880  1.091267e+08  ...   0.0450             -0.1458
# 337         0.060770  7.761451e+08  ...   2.6910              0.0055
# 345        -0.042905  4.369618e+08  ...   1.1010              0.1278
# 351         0.147264  4.259493e+09  ...   5.2630             -2.0040
# 355        -0.013077  1.066326e+08  ...   0.0200              0.1500
# 414  0.481829       -0.001584   0.208
# 481  0.368723        0.101859   0.430
# 524  0.472013        0.115631   0.331
# 526  0.344848       -0.021774   0.057
# 536  0.314247        0.093163   0.343
# 542  0.296964        0.223068   0.822
# 553  0.558805       -0.144877  -0.068
# 554       NaN             NaN   1.211
# 561  0.444789       -0.032112   0.114
# 576  0.420981       -0.029577   0.087
# 631  0.498130        0.345048   0.937
# 651  0.383729        0.202971   0.629
# 697  0.524048        0.054445   0.338
# 711  0.604863        0.286065   0.738
# 715  0.679004        0.808683   1.143
# 716  1.191157       -0.061847   0.392
# 724  0.435793       -0.036614   0.059
# 727  0.440678        0.085321   0.391
# 731  0.398813       -0.036010   0.073
# 739       NaN             NaN   0.996
# 740  0.281507        0.026264   0.204
# 750       NaN             NaN   0.431
# 778  0.415307        0.448328   0.946
# 797  0.766963       -0.064564   0.163
# 821  0.443060        0.152124   0.567
# 839  0.217861        0.089328   0.316
# 848  0.422809        0.116237   0.443
# 865  0.484851        0.075306   0.454
# 882  0.791402        0.353611   0.924
# 931  0.689078        0.371572   0.705
#
# [52 rows x 22 columns]

# %%
df_healthcare = df_healthcare[df_healthcare["sharpe"] > 0.6]
df_healthcare
# Out:
#     ticker                             name      sector Earnings_expectation  \
# 56    CTLT                   Catalent, Inc.  Healthcare             Increase
# 102   IDXX         IDEXX Laboratories, Inc.  Healthcare             Increase
# 106    IQV             IQVIA Holdings, Inc.  Healthcare             Increase
# 272   BDSI  BioDelivery Sciences Internatio  Healthcare             Increase
# 287   BRKR               Bruker Corporation  Healthcare             Increase
# 310   CDMO           Avid Bioservices, Inc.  Healthcare             Increase
# 351   CRSP           CRISPR Therapeutics AG  Healthcare             Increase
# 355   CSBR         Champions Oncology, Inc.  Healthcare             Increase
# 367   CUTR                     Cutera, Inc.  Healthcare             Increase
# 542   ICLR                         ICON plc  Healthcare             Increase
# 554   INMD                      InMode Ltd.  Healthcare             Increase
# 631   MEDP           Medpace Holdings, Inc.  Healthcare             Increase
# 651   MODV                   ModivCare Inc.  Healthcare             Increase
# 711   OPCH         Option Care Health, Inc.  Healthcare             Increase
# 715   OPRX           OptimizeRx Corporation  Healthcare             Increase
# 739   PGNY                    Progyny, Inc.  Healthcare             Decrease
# 778   RGEN             Repligen Corporation  Healthcare             Increase
# 882   TNDM       Tandem Diabetes Care, Inc.  Healthcare             Increase
# 931   XOMA                 XOMA Corporation  Healthcare             Increase
#
#            irv_status  capm_status       esg_status  current_price  \
# 56   Above Fair Price  UnderValued          No Data         97.610
# 102  Below Fair Price   OverValued  Not Sustainable        489.560
# 106  Above Fair Price  UnderValued      Sustainable        226.160
# 272  Below Fair Price  UnderValued          No Data          5.560
# 287  Above Fair Price  UnderValued          No Data         68.965
# 310  Above Fair Price  UnderValued          No Data         19.645
# 351  Above Fair Price  UnderValued          No Data         55.660
# 355  Above Fair Price  UnderValued          No Data          7.890
# 367  Above Fair Price  UnderValued          No Data         33.450
# 542  Below Fair Price   OverValued          No Data        220.250
# 554  Below Fair Price  UnderValued          No Data         40.900
# 367  0.621925        0.136882   0.606
# 542  0.296964        0.223068   0.822
# 554       NaN             NaN   1.211
# 631  0.498130        0.345048   0.937
# 651  0.383729        0.202971   0.629
# 711  0.604863        0.286065   0.738
# 715  0.679004        0.808683   1.143
# 739       NaN             NaN   0.996
# 778  0.415307        0.448328   0.946
# 882  0.791402        0.353611   0.924
# 931  0.689078        0.371572   0.705
#
# [19 rows x 22 columns]

# %% [markdown]
# # Communication Services

# %% [markdown]
# ## Filtering Stocks based on Sharpe Ratio

# %%
sharpe_list = []
for i in range(len(df_CS)):
    each = df_CS.iloc[i]
    ticker = each["ticker"]
    sharpe = get_sharpe_ratio(ticker)
    sharpe_list.append(sharpe)

# %%
sharpe_list
# Out:
# [0.172,
#  0.325,
#  0.079,
#  0.946,
#  0.124,
#  0.398,
#  0.452,
#  -0.005,
#  0.493,
#  0.508,
#  -0.022,
#  0.009,
#  0.402,
#  -0.156,
#  0.597,
#  -0.212,
#  -0.016,
#  0.289,
#  0.636,
#  -0.026,
#  0.824,
#  0.12,
#  0.136,
#  0.277,
#  0.231,
#  -0.204,
#  1.136,
#  0.241,
#  -0.307]

# %%
df_CS["sharpe"] = sharpe_list
df_CS
# Out:
# C:\Users\LAVANY~1\AppData\Local\Temp/ipykernel_21904/344717606.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_CS["sharpe"] = sharpe_list
#     ticker                             name                  sector  \
# 67   DISCA       Discovery, Inc. - Series A  Communication Services
# 71      EA             Electronic Arts Inc.  Communication Services
# 236   AMCX                AMC Networks Inc.  Communication Services
# 259   AVID            Avid Technology, Inc.  Communication Services
# 276   BIDU                      Baidu, Inc.  Communication Services
# 298   CARG                   CarGurus, Inc.  Communication Services
# 307   CCOI  Cogent Communications Holdings,  Communication Services
# 352   CRTO                      Criteo S.A.  Communication Services
# 465  FWONA  Liberty Media Corporation - Ser  Communication Services
# 466  FWONK  Liberty Media Corporation - Ser  Communication Services
# 468   GAIA                       Gaia, Inc.  Communication Services
# 544   IDCC               InterDigital, Inc.  Communication Services
# 588  LBRDA    Liberty Broadband Corporation  Communication Services
# 600  LILAK       Liberty Latin America Ltd.  Communication Services
# 640   MGNI                    Magnite, Inc.  Communication Services
# 653   MOMO                 Hello Group Inc.  Communication Services
# 713   OPRA                    Opera Limited  Communication Services
# 742   PLAY  Dave & Buster's Entertainment,   Communication Services
# 767   QNST                 QuinStreet, Inc.  Communication Services
# 770   RBBN       Ribbon Communications Inc.  Communication Services
# 789   ROKU                       Roku, Inc.  Communication Services
# 808   SCHL           Scholastic Corporation  Communication Services
# 810   SCPL              SciPlay Corporation  Communication Services
# 824   SIRI          Sirius XM Holdings Inc.  Communication Services
# 851    SSP       E.W. Scripps Company (The)  Communication Services
# 887   TRUE                    TrueCar, Inc.  Communication Services
# 893   TTGT                 TechTarget, Inc.  Communication Services
# 899   TZOO                        Travelzoo  Communication Services
# 912   VEON                        VEON Ltd.  Communication Services
#
#     Earnings_expectation        irv_status  capm_status   esg_status  \
# 67              Increase  Above Fair Price  UnderValued  Sustainable
# 71              Increase  Below Fair Price   OverValued  Sustainable
# 236             Increase  Above Fair Price  UnderValued      No Data
# 259             Increase  Above Fair Price  UnderValued      No Data
# 276             Increase  Above Fair Price  UnderValued      Average
# 298             Increase  Above Fair Price  UnderValued      No Data
# 307             Increase  Below Fair Price   OverValued      No Data
# 352             Increase  Above Fair Price  UnderValued      No Data
# 465             Increase  Above Fair Price  UnderValued      No Data
# 466             Increase  Above Fair Price  UnderValued      No Data
# 468             Increase  Above Fair Price  UnderValued      No Data
# 544             Increase  Above Fair Price  UnderValued      No Data
# 588             Increase  Below Fair Price  UnderValued      No Data
# 600             Decrease  Below Fair Price  UnderValued      No Data
# 640             Increase  Above Fair Price  UnderValued      No Data
# 653             Increase  Above Fair Price  UnderValued      No Data
# 713             Decrease  Below Fair Price  UnderValued      No Data
# 742             Increase  Above Fair Price  UnderValued      No Data
# 767             Increase  Below Fair Price  UnderValued      No Data
# 770             Increase  Above Fair Price  UnderValued      No Data
# 789             Decrease  Below Fair Price  UnderValued      No Data
# 808             Increase  Above Fair Price  UnderValued      No Data
# 810             Increase  Above Fair Price  UnderValued      No Data
# 824             Increase  Above Fair Price  UnderValued  Sustainable
# 851             Increase  Above Fair Price  UnderValued      No Data
# 887             Increase  Below Fair Price  UnderValued      No Data
# 893             Increase  Below Fair Price   OverValued      No Data
# 899             Increase  Above Fair Price  UnderValued      No Data
# 912             Increase  Above Fair Price  UnderValued      No Data
#
#      current_price  annu_return_10y    market_cap  ... eps_ttm  \
# 67         29.6600         0.027716  1.475057e+10  ...   1.495
# 71        128.5400         0.223319  3.635214e+10  ...   2.715
# 236        38.5050        -0.015313  1.626921e+09  ...   7.502
# 259        29.9300         0.097825  1.347508e+09  ...   0.717
# 276       152.9950         0.014219  5.402162e+10  ...   6.069
# 298        32.4150         0.016284  3.814695e+09  ...   0.884
# 307        62.5000         0.173571  2.979612e+09  ...   0.481
# 352        31.6500        -0.011107  1.921861e+09  ...   1.656
# 465        56.6200         0.108724  1.382502e+10  ...   0.004
# 466        61.8700         0.096506  1.418951e+10  ...   0.004
# 468         6.3100         0.060406  1.290559e+08  ...   0.101
# 544        64.2900         0.068054  1.972289e+09  ...   1.023
# 588       144.1600         0.123105  2.556808e+10  ...   3.234
# 600        10.9300        -0.111830  2.541531e+09  ...   0.606
# 640        11.7100        -0.052547  1.543530e+09  ...   0.045
# 653        10.1200        -0.041815  2.086036e+09  ...   1.447
# 713         6.1700        -0.072598  7.104508e+08  ...   0.826
# 742        41.4700         0.093736  2.008094e+09  ...   0.534
# 767        10.7600        -0.002836  5.836483e+08  ...   0.223
# 770         3.3700        -0.135178  5.008662e+08  ...   0.281
# 789       121.9700         0.179013  1.638826e+10  ...   2.067
# 808        42.6400         0.048361  1.473498e+09  ...   1.084
# 810        13.1000        -0.016444  3.214308e+08  ...   0.862
# 824         6.0150         0.117463  2.405693e+10  ...   0.077
# 851        21.5300         0.110167  1.776748e+09  ...   3.191
# 887         3.2150        -0.107808  3.083895e+08  ...   0.646
# 893        73.2000         0.263308  2.109602e+09  ...   0.694
# 899         9.1163        -0.095851  1.117531e+08  ...   0.393
# 899              0.246516  0.718764        0.012711   0.241
# 912              0.180874  0.423563       -0.219292  -0.307
#
# [29 rows x 22 columns]

# %%
df_CS = df_CS[df_CS["sharpe"] > 0.6]
df_CS
# Out:
#     ticker                   name                  sector  \
# 259   AVID  Avid Technology, Inc.  Communication Services
# 767   QNST       QuinStreet, Inc.  Communication Services
# 789   ROKU             Roku, Inc.  Communication Services
# 893   TTGT       TechTarget, Inc.  Communication Services
#
#     Earnings_expectation        irv_status  capm_status esg_status  \
# 259             Increase  Above Fair Price  UnderValued    No Data
# 767             Increase  Below Fair Price  UnderValued    No Data
# 789             Decrease  Below Fair Price  UnderValued    No Data
# 893             Increase  Below Fair Price   OverValued    No Data
#
#      current_price  annu_return_10y    market_cap  ... eps_ttm  \
# 259          29.93         0.097825  1.347508e+09  ...   0.717
# 767          10.76        -0.002836  5.836483e+08  ...   0.223
# 789         121.97         0.179013  1.638826e+10  ...   2.067
# 893          73.20         0.263308  2.109602e+09  ...   0.694
#
#      growth_estimate_5y  pe_forward  pe_trailing  irv_FairValue  ESG_risk  \
# 259              0.1500   19.690790    41.743374      14.965000     999.0
# 767              0.2500   11.569893    48.251120      11.394409     999.0
# 789              0.4910   73.035934    59.008230     631.308006     999.0
# 893              0.3883   28.262548   105.475500     199.319788     999.0
#
#      capm_expected_return    AHV_5y  annu_return_5y  sharpe
# 259              0.167502  0.613275        0.402675   0.946
# 767              0.107938  0.587975        0.269590   0.636
# 789              0.228282       NaN             NaN   0.824
# 893              0.127388  0.455710        0.540216   1.136
#
# [4 rows x 22 columns]

# %% [markdown]
# # Energy

# %% [markdown]
# ## Filtering Stocks based on Sharpe Ratio

# %%
sharpe_list = []
for i in range(len(df_energy)):
    each = df_energy.iloc[i]
    ticker = each["ticker"]
    sharpe = get_sharpe_ratio(ticker)
    sharpe_list.append(sharpe)

# %%
sharpe_list
# Out:
# [0.224,
#  0.65,
#  0.523,
#  0.499,
#  0.483,
#  0.391,
#  0.283,
#  0.587,
#  0.206,
#  0.214,
#  0.283,
#  -0.049,
#  0.165,
#  0.437,
#  0.209]

# %%
df_energy["sharpe"] = sharpe_list
df_energy
# Out:
# C:\Users\LAVANY~1\AppData\Local\Temp/ipykernel_21904/1547337999.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_energy["sharpe"] = sharpe_list
#     ticker                             name  sector Earnings_expectation  \
# 32     BKR             Baker Hughes Company  Energy             Increase
# 52     COP                   ConocoPhillips  Energy             Increase
# 60     CVX              Chevron Corporation  Energy             Increase
# 145    MPC   Marathon Petroleum Corporation  Energy             Decrease
# 159    OKE                      ONEOK, Inc.  Energy             Increase
# 175    PXD  Pioneer Natural Resources Compa  Energy             Increase
# 246   ARLP  Alliance Resource Partners, L.P  Energy             Increase
# 284   BOOM                  DMC Global Inc.  Energy             Increase
# 324    CHX            ChampionX Corporation  Energy             Increase
# 443   FLMN      Falcon Minerals Corporation  Energy             Increase
# 486    GPP         Green Plains Partners LP  Energy             Increase
# 671   NCSM    NCS Multistage Holdings, Inc.  Energy             Increase
# 675   NESR  National Energy Services Reunit  Energy             Increase
# 730   PDCE                 PDC Energy, Inc.  Energy             Increase
# 791   RTLR             Rattler Midstream LP  Energy             Increase
#
#            irv_status  capm_status       esg_status  current_price  \
# 32   Below Fair Price  UnderValued          No Data         29.185
# 52   Above Fair Price  UnderValued  Not Sustainable         89.270
# 60   Above Fair Price  UnderValued  Not Sustainable        134.370
# 145  Below Fair Price  UnderValued          Average         75.660
# 159  Above Fair Price  UnderValued          Average         60.580
# 175  Below Fair Price  UnderValued  Not Sustainable        223.510
# 246  Above Fair Price  UnderValued          No Data         12.640
# 284  Above Fair Price  UnderValued          No Data         34.600
# 324  Above Fair Price  UnderValued          No Data         20.840
# 443  Above Fair Price  UnderValued          No Data          5.500
# 486  Above Fair Price  UnderValued          No Data         13.100
# 671  Below Fair Price  UnderValued          No Data         41.950
# 675  Below Fair Price  UnderValued          No Data          9.280
# 730  Below Fair Price  UnderValued          No Data         52.980
# 791  Above Fair Price  UnderValued          No Data         12.940
#
#      annu_return_10y    market_cap  ... eps_ttm  growth_estimate_5y  \
# 32         -0.001522  2.539002e+10  ...   0.180              3.4810
# 52          0.080856  1.177427e+11  ...   3.687             -0.0180
# 60          0.064948  2.590237e+11  ...   5.173             -0.0490
# 145         0.168450  4.657539e+10  ...  14.246              0.4380
# 159         0.112232  2.701486e+10  ...   3.195              0.0986
# 175         0.077453  5.456639e+10  ...   6.280              0.7775
# 246        -0.022929  1.607745e+09  ...   1.243             -0.0683
# 284         0.042223  6.669496e+08  ...   0.093              0.2000
# 324        -0.058303  4.211139e+09  ...   0.380             -0.0594
# 443        -0.033091  2.550719e+08  ...   0.120              0.0309
# 486         0.051475  3.042829e+08  ...   1.723              0.1500
# 671        -0.201922  9.985652e+07  ...   0.903              1.0000
# 675        -0.002445  8.478319e+08  ...   0.407              0.5030
# 730         0.039460  5.159251e+09  ...   0.426              0.2720
# 791        -0.021450  5.163810e+08  ...   0.830              0.1390
#
#      pe_forward  pe_trailing  irv_FairValue  ESG_risk  capm_expected_return  \
# 32    24.119833   162.138890   3.021507e+06    999.00              0.216126
# 52    11.444871    24.212095   1.077453e+01     34.87              0.216126
# 60    14.129336    25.975256   1.215112e+01     43.22              0.173580
# 145   17.928911     5.310965   2.827390e+02     28.78              0.272043
# 159   15.858640    18.960876   2.007128e+01     24.08              0.234360
# 175   11.203508    35.590763   5.626948e+03     36.08              0.242869
# 246    5.056000    10.168946   9.504327e-01    999.00              0.227066
# 284   32.952380   372.043000   2.537446e+01    999.00              0.150484
# 324   17.081966    54.842106   1.706994e+00    999.00              0.413052
# 443   16.176470    45.833336   1.028019e+00    999.00              0.251378
# 486    5.822222     7.603018   6.550000e+00    999.00              0.112801
# 671 -116.527780    46.456257   3.052751e+03    999.00              0.246516
# 675   11.317073    22.800982   5.162597e+01    999.00              0.115232
# 730    5.287425   124.366196   6.564254e+01    999.00              0.409405
# 791    9.953846    15.590362   5.933859e+00    999.00              0.487203
#
#        AHV_5y  annu_return_5y  sharpe
# 32   0.473062       -0.050113   0.224
# 52   0.420681        0.148794   0.650
# 60   0.334478        0.084378   0.523
# 145  0.462210        0.134486   0.499
# 159  0.494682        0.088954   0.483
# 175  0.477352        0.058166   0.391
# 246  0.586706       -0.044919   0.283
# 284  0.574497        0.163848   0.587
# 324       NaN             NaN   0.206
# 443       NaN             NaN   0.214
# 486  0.534683        0.024805   0.283
# 671       NaN             NaN  -0.049
# 675       NaN             NaN   0.165
# 730  0.872904       -0.056411   0.437
# 791       NaN             NaN   0.209
#
# [15 rows x 22 columns]

# %%
df_energy = df_energy[df_energy["sharpe"] > 0.6]
df_energy
# Out:
#    ticker            name  sector Earnings_expectation        irv_status  \
# 52    COP  ConocoPhillips  Energy             Increase  Above Fair Price
#
#     capm_status       esg_status  current_price  annu_return_10y  \
# 52  UnderValued  Not Sustainable          89.27         0.080856
#
#       market_cap  ... eps_ttm  growth_estimate_5y  pe_forward  pe_trailing  \
# 52  1.177427e+11  ...   3.687              -0.018   11.444871    24.212095
#
#     irv_FairValue  ESG_risk  capm_expected_return    AHV_5y  annu_return_5y  \
# 52       10.77453     34.87              0.216126  0.420681        0.148794
#
#     sharpe
# 52    0.65
#
# [1 rows x 22 columns]

# %% [markdown]
# # Utilities

# %% [markdown]
# ## Filtering Stocks based on Sharpe Ratio

# %%
sharpe_list = []
for i in range(len(df_utilities)):
    each = df_utilities.iloc[i]
    ticker = each["ticker"]
    sharpe = get_sharpe_ratio(ticker)
    sharpe_list.append(sharpe)

# %%
sharpe_list
# Out:
# [0.519]

# %%
df_utilities["sharpe"] = sharpe_list
df_utilities
# Out:
# C:\Users\LAVANY~1\AppData\Local\Temp/ipykernel_21904/4073155429.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_utilities["sharpe"] = sharpe_list
#    ticker                 name     sector Earnings_expectation  \
# 78    ETR  Entergy Corporation  Utilities             Increase
#
#           irv_status  capm_status       esg_status  current_price  \
# 78  Above Fair Price  UnderValued  Not Sustainable        105.055
#
#     annu_return_10y    market_cap  ... eps_ttm  growth_estimate_5y  \
# 78         0.092009  2.111406e+10  ...   6.179                0.06
#
#     pe_forward  pe_trailing  irv_FairValue  ESG_risk  capm_expected_return  \
# 78   16.570189    17.001942      25.226614     30.28              0.093351
#
#       AHV_5y  annu_return_5y  sharpe
# 78  0.260092        0.118782   0.519
#
# [1 rows x 22 columns]

# %%
df_utilities = df_utilities[df_utilities["sharpe"] > 0.6]
df_utilities
# Out:
# Empty DataFrame
# Columns: [ticker, name, sector, Earnings_expectation, irv_status, capm_status, esg_status, current_price, annu_return_10y, market_cap, marketcap_cat, beta, eps_ttm, growth_estimate_5y, pe_forward, pe_trailing, irv_FairValue, ESG_risk, capm_expected_return, AHV_5y, annu_return_5y, sharpe]
# Index: []
#
# [0 rows x 22 columns]

# %% [markdown]
# # Putting everything into 1 DF

# %%
df_BM
# Out:
#     ticker                             name           sector  \
# 58    CTVA                    Corteva, Inc.  Basic Materials
# 82     FCX           Freeport-McMoRan, Inc.  Basic Materials
# 157    NUE                Nucor Corporation  Basic Materials
# 809   SCHN  Schnitzer Steel Industries, Inc  Basic Materials
# 855   STLD             Steel Dynamics, Inc.  Basic Materials
# 878   TGLS                  Tecnoglass Inc.  Basic Materials
#
#     Earnings_expectation        irv_status  capm_status       esg_status  \
# 58              Increase  Below Fair Price  UnderValued          No Data
# 82              Increase  Below Fair Price  UnderValued  Not Sustainable
# 157             Increase  Below Fair Price  UnderValued  Not Sustainable
# 809             Increase  Above Fair Price  UnderValued          No Data
# 855             Increase  Below Fair Price  UnderValued  Not Sustainable
# 878             Increase  Above Fair Price  UnderValued          No Data
#
#      current_price  annu_return_10y    market_cap  ... eps_ttm  \
# 58          50.785         0.061890  3.701765e+10  ...   2.202
# 82          42.740         0.018945  6.276241e+10  ...   2.641
# 157        122.640         0.142526  3.505039e+10  ...  16.577
# 809         41.580         0.019844  1.156909e+09  ...   5.657
# 855         63.230         0.186302  1.254806e+10  ...  11.005
# 878         19.490         0.099058  9.291818e+08  ...   1.404
#
#      growth_estimate_5y  pe_forward  pe_trailing  irv_FairValue  ESG_risk  \
# 58               0.2487   19.608109    23.063126      53.278002    999.00
# 82               0.2890   12.039437    16.183264      59.676070     34.50
# 157              0.3499    7.334929     7.398202     259.439419     36.58
# 809              0.1000    5.766991     7.350186      13.935037    999.00
# 855              0.3632    5.062450     5.745570     146.099525     34.29
# 878              0.0094   10.708791    13.881765       3.013498    999.00
#
#      capm_expected_return    AHV_5y  annu_return_5y  sharpe
# 58               0.115232       NaN             NaN   0.833
# 82               0.270827  0.507643        0.234986   0.799
# 157              0.194245  0.360322        0.193174   0.741
# 809              0.203970  0.472387        0.156052   0.675
# 855              0.202754  0.411506        0.159118   0.689
# 878              0.230713  0.620494        0.151889   0.646
#
# [6 rows x 22 columns]

# %%
df_BM.to_csv("selected_stocks_BM.csv")

# %%
df_RE
# Out:
#     ticker                            name       sector Earnings_expectation  \
# 39    CBRE                  CBRE Group Inc  Real Estate             Increase
# 184   SBAC  SBA Communications Corporation  Real Estate             Increase
# 416   EXPI        eXp World Holdings, Inc.  Real Estate             Increase
# 937   SAFE                   Safehold Inc.  Real Estate             Increase
#
#            irv_status  capm_status   esg_status  current_price  \
# 39   Above Fair Price  UnderValued  Sustainable          99.53
# 184  Below Fair Price   OverValued  Sustainable         297.16
# 416  Above Fair Price  UnderValued      No Data          25.15
# 937  Below Fair Price   OverValued      No Data          60.47
#
#      annu_return_10y    market_cap  ... eps_ttm  growth_estimate_5y  \
# 39          0.182808  3.330930e+10  ...   4.290              0.1100
# 184         0.204253  3.232536e+10  ...   2.606              1.8932
# 416         0.156613  3.710555e+09  ...   0.467              0.1000
# 937         0.133037  3.420177e+09  ...   1.261              0.3690
#
#      pe_forward  pe_trailing  irv_FairValue  ESG_risk  capm_expected_return  \
# 39    17.647163    23.200466      36.186806      6.99              0.189383
# 184   74.663315   114.029170  599909.754404     14.52              0.056883
# 416   36.985294    53.854390       8.428719    999.00              0.397249
# 937   34.752872    47.954006     145.164511    999.00             -0.016052
#
#        AHV_5y  annu_return_5y  sharpe
# 39   0.351216        0.244065   0.680
# 184  0.267604        0.237268   0.833
# 416       NaN             NaN   0.770
# 937       NaN             NaN   0.748
#
# [4 rows x 22 columns]

# %%
df_RE = df_RE.dropna()
df_RE
# Out:
#     ticker                            name       sector Earnings_expectation  \
# 39    CBRE                  CBRE Group Inc  Real Estate             Increase
# 184   SBAC  SBA Communications Corporation  Real Estate             Increase
#
#            irv_status  capm_status   esg_status  current_price  \
# 39   Above Fair Price  UnderValued  Sustainable          99.53
# 184  Below Fair Price   OverValued  Sustainable         297.16
#
#      annu_return_10y    market_cap  ... eps_ttm  growth_estimate_5y  \
# 39          0.182808  3.330930e+10  ...   4.290              0.1100
# 184         0.204253  3.232536e+10  ...   2.606              1.8932
#
#      pe_forward  pe_trailing  irv_FairValue  ESG_risk  capm_expected_return  \
# 39    17.647163    23.200466      36.186806      6.99              0.189383
# 184   74.663315   114.029170  599909.754404     14.52              0.056883
#
#        AHV_5y  annu_return_5y  sharpe
# 39   0.351216        0.244065   0.680
# 184  0.267604        0.237268   0.833
#
# [2 rows x 22 columns]

# %%
df_RE.to_csv("selected_stocks_RE.csv")

# %%
df_FS
# Out:
#     ticker                             name              sector  \
# 26     AXP         American Express Company  Financial Services
# 197   TROW        T. Rowe Price Group, Inc.  Financial Services
# 317     CG           The Carlyle Group Inc.  Financial Services
# 360   CSWC    Capital Southwest Corporation  Financial Services
# 464   FUTU            Futu Holdings Limited  Financial Services
# 492   GSHD        Goosehead Insurance, Inc.  Financial Services
# 744   PLMR           Palomar Holdings, Inc.  Financial Services
# 869   TBBK                The Bancorp, Inc.  Financial Services
# 896     TW            Tradeweb Markets Inc.  Financial Services
# 911   VCTR  Victory Capital Holdings, Inc.   Financial Services
#
#     Earnings_expectation        irv_status  capm_status       esg_status  \
# 26              Increase  Below Fair Price  UnderValued  Not Sustainable
# 197             Increase  Above Fair Price  UnderValued      Sustainable
# 317             Decrease  Below Fair Price  UnderValued          No Data
# 360             Increase  Above Fair Price  UnderValued          No Data
# 464             Increase  Above Fair Price  UnderValued          No Data
# 492             Increase  Below Fair Price   OverValued          No Data
# 744             Increase  Below Fair Price   OverValued          No Data
# 869             Increase  Above Fair Price  UnderValued          No Data
# 896             Increase  Above Fair Price  UnderValued          No Data
# 911             Increase  Above Fair Price  UnderValued          No Data
#
#      current_price  annu_return_10y    market_cap  ... eps_ttm  \
# 26         195.110         0.155990  1.511236e+11  ...   9.573
# 197        142.560         0.120724  3.267447e+10  ...  13.270
# 317         44.830         0.139004  1.598019e+10  ...   7.730
# 360         24.420         0.082236  5.699872e+08  ...   1.740
# 464         40.520         0.102151  5.943150e+09  ...   2.459
# 492         85.540         0.187638  3.194397e+09  ...   0.396
# 744         56.450         0.115100  1.434694e+09  ...   1.043
# 869         29.290         0.126627  1.668956e+09  ...   1.825
# 896         80.965         0.086434  1.883205e+10  ...   1.136
# 911         32.210         0.110286  2.193565e+09  ...   3.551
#
#      growth_estimate_5y  pe_forward  pe_trailing  irv_FairValue  ESG_risk  \
# 26               0.4330   20.176836    20.381280     706.617956     20.34
# 197              0.1220   10.678651    10.743029      57.098253     16.74
# 317              0.2826   11.041873     5.799483      59.852092    999.00
# 360              0.0100   12.652850    14.034483       3.796011    999.00
# 464              0.0903   10.389744    16.478243      12.539291    999.00
# 492              0.3410   89.104170   216.010100     170.497371    999.00
# 744              1.1985   19.532871    54.122726    9627.014851    999.00
# 869              0.1200   13.497696    16.049314      11.544390    999.00
# 896              0.1994   44.002716    71.272000      59.110294    999.00
# 911              0.1170    6.100378     9.070683      12.392493    999.00
#
#      capm_expected_return    AHV_5y  annu_return_5y  sharpe
# 26               0.169933  0.343000        0.210121   0.666
# 197              0.167502  0.300412        0.193441   0.693
# 317              0.193030  0.363420        0.276296   0.830
# 360              0.174796  0.330948        0.198592   0.628
# 464              0.135897       NaN             NaN   0.735
# 492              0.081195       NaN             NaN   0.947
# 744              0.010691       NaN             NaN   0.997
# 869              0.177227  0.537796        0.404302   0.896
# 896              0.120094       NaN             NaN   1.022
# 911              0.150484       NaN             NaN   0.717
#
# [10 rows x 22 columns]

# %%
df_FS.to_csv("selected_stocks_FS.csv")

# %%
df_CC
# Out:
#     ticker                            name             sector  \
# 65     DHI               D.R. Horton, Inc.  Consumer Cyclical
# 98     HLT  Hilton Worldwide Holdings Inc.  Consumer Cyclical
# 199   TSLA                     Tesla, Inc.  Consumer Cyclical
# 321   CHDN   Churchill Downs, Incorporated  Consumer Cyclical
# 326   CLAR              Clarus Corporation  Consumer Cyclical
# 437   FIVE                Five Below, Inc.  Consumer Cyclical
# 442    FLL        Full House Resorts, Inc.  Consumer Cyclical
# 447   FNKO                     Funko, Inc.  Consumer Cyclical
# 452   FOXF       Fox Factory Holding Corp.  Consumer Cyclical
# 616   LULU        lululemon athletica inc.  Consumer Cyclical
# 625   MBUU              Malibu Boats, Inc.  Consumer Cyclical
# 629   MCRI   Monarch Casino & Resort, Inc.  Consumer Cyclical
# 780   RICK  RCI Hospitality Holdings, Inc.  Consumer Cyclical
# 792  RUSHA          Rush Enterprises, Inc.  Consumer Cyclical
#
#     Earnings_expectation        irv_status  capm_status   esg_status  \
# 65              Increase  Above Fair Price  UnderValued      Average
# 98              Increase  Below Fair Price  UnderValued  Sustainable
# 199             Increase  Below Fair Price   OverValued      Average
# 321             Increase  Below Fair Price   OverValued      No Data
# 326             Increase  Below Fair Price  UnderValued      No Data
# 437             Increase  Below Fair Price   OverValued      No Data
# 442             Increase  Above Fair Price  UnderValued      No Data
# 447             Increase  Above Fair Price  UnderValued      No Data
# 452             Increase  Above Fair Price  UnderValued      No Data
# 616             Increase  Below Fair Price  UnderValued  Sustainable
# 625             Increase  Above Fair Price  UnderValued      No Data
# 629             Increase  Above Fair Price  UnderValued      No Data
# 780             Increase  Below Fair Price  UnderValued      No Data
# 792             Increase  Below Fair Price  UnderValued      No Data
#
#      current_price  annu_return_10y    market_cap  ... eps_ttm  \
# 65         81.3366         0.204622  2.897055e+10  ...  11.410
# 98        147.9550         0.134492  4.123831e+10  ...   0.140
# 199       806.0500         0.609586  8.094838e+11  ...   3.062
# 321       214.5100         0.285760  8.204814e+09  ...   5.574
# 326        21.4100         0.104810  7.919045e+08  ...   0.554
# 437       159.6400         0.196712  8.943895e+09  ...   4.662
# 442         8.7500         0.119495  2.994906e+08  ...   0.331
# 447        17.1200         0.092467  6.835999e+08  ...   1.037
# 452       120.9000         0.205780  5.090374e+09  ...   3.731
# 616       304.5800         0.164012  3.938189e+10  ...   6.661
# 625        67.3700         0.142686  1.403971e+09  ...   5.497
# 629        73.2800         0.212274  1.373003e+09  ...   3.315
# 780        63.2700         0.212191  6.010593e+08  ...   3.369
# 792        49.3400         0.123774  2.712585e+09  ...   3.708
#
#      growth_estimate_5y  pe_forward  pe_trailing  irv_FairValue  ESG_risk  \
# 65               0.1060    5.326562     7.128537   2.862672e+01     22.55
# 98               2.7265   34.408140  1056.821400   2.914266e+06     19.95
# 199              0.7295   92.014840   263.242980   1.586122e+04     28.54
# 321              2.0990   23.598460    38.484030   8.037688e+05    999.00
# 326              0.3290   13.993464    38.646206   3.935781e+01    999.00
# 437              0.4612   27.242321    34.242813   6.889982e+02    999.00
# 442              0.1500   19.444445    26.435045   4.375000e+00    999.00
# 447              0.0270   11.972029    16.509163   3.092625e+00    999.00
# 452              0.1500   23.613281    32.404182   6.045000e+01    999.00
# 616              0.2790   32.927567    45.725870   3.964841e+02     16.06
# 625              0.1500    8.715395    12.255775   3.368500e+01    999.00
# 629              0.1400   16.654545    22.105580   3.387026e+01    999.00
# 780              0.4000   12.704820    18.780054   1.857974e+02    999.00
# 792              0.2866   11.803828    13.306365   6.774551e+01    999.00
#
#      capm_expected_return    AHV_5y  annu_return_5y  sharpe
# 65               0.217341  0.370627        0.238886   0.625
# 98               0.168718  0.314619        0.209851   0.714
# 199              0.267181  0.611157        0.739589   1.225
# 321              0.165071  0.428761        0.357716   0.855
# 326              0.122525  0.393534        0.306635   0.888
# 437              0.178443  0.452922        0.332526   0.778
# 442              0.240438  0.704348        0.296359   0.721
# 447              0.293924       NaN             NaN   0.618
# 452              0.230713  0.462622        0.367678   0.714
# 616              0.179658  0.392863        0.361296   0.971
# 625              0.229497  0.490083        0.277316   0.621
# 629              0.223419  0.466259        0.268473   0.660
# 780              0.258672  0.608473        0.302701   0.705
# 792              0.167502  0.352175        0.187417   0.667
#
# [14 rows x 22 columns]

# %%
df_industrials = df_industrials.dropna()
df_industrials

# %%
df_CC.to_csv("selected_stocks_CC.csv")

# %%
df_tech
# Out:
#     ticker                             name      sector Earnings_expectation  \
# 5     ADSK                   Autodesk, Inc.  Technology             Increase
# 14     AMD     Advanced Micro Devices, Inc.  Technology             Increase
# 17    ANSS                      ANSYS, Inc.  Technology             Increase
# 73    EPAM               EPAM Systems, Inc.  Technology             Increase
# 176   QCOM            QUALCOMM Incorporated  Technology             Increase
# 243   AOSL  Alpha and Omega Semiconductor L  Technology             Increase
# 244   APPS            Digital Turbine, Inc.  Technology             Increase
# 249   ASML  ASML Holding N.V. - New York Re  Technology             Increase
# 258   AUDC                  AudioCodes Ltd.  Technology             Increase
# 381   DIOD              Diodes Incorporated  Technology             Increase
# 386   DSGX  The Descartes Systems Group Inc  Technology             Increase
# 555   INOD                    Innodata Inc.  Technology             Increase
# 621   MANT  ManTech International Corporati  Technology             Increase
# 639   MGIC  Magic Software Enterprises Ltd.  Technology             Increase
# 686   NSIT        Insight Enterprises, Inc.  Technology             Increase
# 708     ON     ON Semiconductor Corporation  Technology             Increase
# 751   POWI         Power Integrations, Inc.  Technology             Increase
# 781   RIOT             Riot Blockchain, Inc  Technology             Increase
# 783   RMBS                     Rambus, Inc.  Technology             Increase
# 890    TTD             The Trade Desk, Inc.  Technology             Increase
# 901   UCTT       Ultra Clean Holdings, Inc.  Technology             Increase
# 923   WDAY                    Workday, Inc.  Technology             Increase
#
#            irv_status  capm_status   esg_status  current_price  \
# 5    Below Fair Price  UnderValued  Sustainable       217.3800
# 14   Below Fair Price   OverValued      No Data       117.1100
# 17   Above Fair Price  UnderValued  Sustainable       305.4575
# 73   Below Fair Price   OverValued      No Data       428.8350
# 176  Below Fair Price  UnderValued  Sustainable       165.6500
# 243  Above Fair Price  UnderValued      No Data        49.2600
# 244  Below Fair Price  UnderValued      No Data        43.8000
# 249  Below Fair Price   OverValued      No Data       634.7900
# 258  Below Fair Price   OverValued      No Data        27.6750
# 381  Above Fair Price  UnderValued      No Data        87.1300
# 386  Below Fair Price   OverValued      No Data        69.6200
# 555  Above Fair Price  UnderValued      No Data         5.0600
# 621  Above Fair Price  UnderValued      No Data        78.5700
# 639  Above Fair Price  UnderValued      No Data        18.3000
# 686  Above Fair Price  UnderValued      No Data        99.4000
# 708  Below Fair Price  UnderValued      Average        58.4400
# 751  Below Fair Price   OverValued      No Data        87.7500
# 781  Above Fair Price  UnderValued      No Data        15.9500
# 783  Above Fair Price  UnderValued      No Data        26.2900
# 890  Below Fair Price   OverValued      No Data        73.6800
# 901  Above Fair Price  UnderValued      No Data        45.8500
# 923  Above Fair Price  UnderValued  Sustainable       216.5600
#
#      annu_return_10y    market_cap  ... eps_ttm  growth_estimate_5y  \
#
# 244  0.719036        1.325025   1.380
# 249  0.360669        0.411064   1.052
# 258  0.446357        0.362672   0.829
# 381  0.401822        0.286506   0.821
# 386  0.291432        0.265617   0.877
# 555  0.669394        0.192740   0.651
# 621  0.344249        0.170329   0.708
# 639  0.334100        0.227677   0.686
# 686  0.366896        0.221251   0.660
# 708  0.507655        0.343777   0.784
# 751  0.396886        0.226355   0.716
# 781  1.229896        0.422364   0.891
# 783  0.349622        0.160927   0.636
# 890  0.683392        0.956083   1.121
# 901  0.610451        0.290763   0.604
# 923  0.383779        0.213788   0.688
#
# [22 rows x 22 columns]

# %%
df_tech = df_tech.dropna()
df_tech
# Out:
#     ticker                             name      sector Earnings_expectation  \
# 5     ADSK                   Autodesk, Inc.  Technology             Increase
# 14     AMD     Advanced Micro Devices, Inc.  Technology             Increase
# 17    ANSS                      ANSYS, Inc.  Technology             Increase
# 73    EPAM               EPAM Systems, Inc.  Technology             Increase
# 176   QCOM            QUALCOMM Incorporated  Technology             Increase
# 243   AOSL  Alpha and Omega Semiconductor L  Technology             Increase
# 244   APPS            Digital Turbine, Inc.  Technology             Increase
# 249   ASML  ASML Holding N.V. - New York Re  Technology             Increase
# 258   AUDC                  AudioCodes Ltd.  Technology             Increase
# 381   DIOD              Diodes Incorporated  Technology             Increase
# 386   DSGX  The Descartes Systems Group Inc  Technology             Increase
# 555   INOD                    Innodata Inc.  Technology             Increase
# 621   MANT  ManTech International Corporati  Technology             Increase
# 639   MGIC  Magic Software Enterprises Ltd.  Technology             Increase
# 686   NSIT        Insight Enterprises, Inc.  Technology             Increase
# 708     ON     ON Semiconductor Corporation  Technology             Increase
# 751   POWI         Power Integrations, Inc.  Technology             Increase
# 781   RIOT             Riot Blockchain, Inc  Technology             Increase
# 783   RMBS                     Rambus, Inc.  Technology             Increase
# 890    TTD             The Trade Desk, Inc.  Technology             Increase
# 901   UCTT       Ultra Clean Holdings, Inc.  Technology             Increase
# 923   WDAY                    Workday, Inc.  Technology             Increase
#
#            irv_status  capm_status   esg_status  current_price  \
# 5    Below Fair Price  UnderValued  Sustainable       217.3800
# 14   Below Fair Price   OverValued      No Data       117.1100
# 17   Above Fair Price  UnderValued  Sustainable       305.4575
# 73   Below Fair Price   OverValued      No Data       428.8350
# 176  Below Fair Price  UnderValued  Sustainable       165.6500
# 243  Above Fair Price  UnderValued      No Data        49.2600
# 244  Below Fair Price  UnderValued      No Data        43.8000
# 249  Below Fair Price   OverValued      No Data       634.7900
# 258  Below Fair Price   OverValued      No Data        27.6750
# 381  Above Fair Price  UnderValued      No Data        87.1300
# 386  Below Fair Price   OverValued      No Data        69.6200
# 555  Above Fair Price  UnderValued      No Data         5.0600
# 621  Above Fair Price  UnderValued      No Data        78.5700
# 639  Above Fair Price  UnderValued      No Data        18.3000
# 686  Above Fair Price  UnderValued      No Data        99.4000
# 708  Below Fair Price  UnderValued      Average        58.4400
# 751  Below Fair Price   OverValued      No Data        87.7500
# 781  Above Fair Price  UnderValued      No Data        15.9500
# 783  Above Fair Price  UnderValued      No Data        26.2900
# 890  Below Fair Price   OverValued      No Data        73.6800
# 901  Above Fair Price  UnderValued      No Data        45.8500
# 923  Above Fair Price  UnderValued  Sustainable       216.5600
#
#      annu_return_10y    market_cap  ... eps_ttm  growth_estimate_5y  \
#
# 381  0.401822        0.286506   0.821
# 386  0.291432        0.265617   0.877
# 555  0.669394        0.192740   0.651
# 621  0.344249        0.170329   0.708
# 639  0.334100        0.227677   0.686
# 686  0.366896        0.221251   0.660
# 708  0.507655        0.343777   0.784
# 751  0.396886        0.226355   0.716
# 781  1.229896        0.422364   0.891
# 783  0.349622        0.160927   0.636
# 890  0.683392        0.956083   1.121
# 901  0.610451        0.290763   0.604
# 923  0.383779        0.213788   0.688
#
# [22 rows x 22 columns]

# %%
df_tech.to_csv("selected_stocks_tech.csv")

# %%
df_industrials
# Out:
#     ticker                             name       sector Earnings_expectation  \
# 15     AME                     AMETEK, Inc.  Industrials             Increase
# 37     CAT                Caterpillar, Inc.  Industrials             Increase
# 92     GWW              W.W. Grainger, Inc.  Industrials             Increase
# 107     IR              Ingersoll Rand Inc.  Industrials             Increase
# 112      J    Jacobs Engineering Group Inc.  Industrials             Increase
# 125    LHX      L3Harris Technologies, Inc.  Industrials             Increase
# 158   ODFL  Old Dominion Freight Line, Inc.  Industrials             Increase
# 207    URI             United Rentals, Inc.  Industrials             Increase
# 245   ARCB              ArcBest Corporation  Industrials             Increase
# 297    CAR          Avis Budget Group, Inc.  Industrials             Increase
# 410   ESEA                    Euroseas Ltd.  Industrials             Increase
# 467   FWRD          Forward Air Corporation  Industrials             Increase
# 477   GLDD  Great Lakes Dredge & Dock Corpo  Industrials             Increase
# 525   HSON              Hudson Global, Inc.  Industrials             Increase
# 563   ISSC  Innovative Solutions and Suppor  Industrials             Increase
# 577   KRNT              Kornit Digital Ltd.  Industrials             Increase
# 642   MGRC                 McGrath RentCorp  Industrials             Increase
# 772   RCII               Rent-A-Center Inc.  Industrials             Increase
# 798   SAIA                       Saia, Inc.  Industrials             Increase
# 806   SBLK         Star Bulk Carriers Corp.  Industrials             Increase
# 885   TRNS                   Transcat, Inc.  Industrials             Increase
# 908   USAK                  USA Truck, Inc.  Industrials             Increase
#
#            irv_status  capm_status       esg_status  current_price  \
# 15   Above Fair Price  UnderValued          Average         128.28
# 37   Below Fair Price  UnderValued  Not Sustainable         193.16
# 92   Above Fair Price  UnderValued      Sustainable         474.32
# 107  Above Fair Price  UnderValued          No Data          53.31
# 112  Above Fair Price  UnderValued          Average         120.31
# 125  Below Fair Price   OverValued          No Data         220.65
# 158  Below Fair Price   OverValued          No Data         287.86
# 207  Above Fair Price  UnderValued      Sustainable         311.82
# 245  Below Fair Price  UnderValued          No Data          85.22
# 297  Below Fair Price   OverValued          No Data         152.02
# 410  Above Fair Price  UnderValued          No Data          26.80
# 467  Above Fair Price  UnderValued          No Data          98.63
# 477  Above Fair Price  UnderValued          No Data          13.96
# 525  Above Fair Price  UnderValued          No Data          29.45
# 563  Above Fair Price  UnderValued          No Data           7.26
# 577  Below Fair Price  UnderValued          No Data          87.40
# 642  Above Fair Price  UnderValued          No Data          72.98
# 772  Below Fair Price  UnderValued          No Data          37.71
# 798  Below Fair Price   OverValued          No Data         257.07
# 806  Above Fair Price  UnderValued          No Data          31.31
# 885  Below Fair Price   OverValued          No Data          74.73
# 908  Below Fair Price  UnderValued          No Data          24.04
#
#      annu_return_10y    market_cap  ... eps_ttm  growth_estimate_5y  \
#
# 467  0.314318        0.173151   0.610
# 477  0.407094        0.222752   0.759
# 525  0.472020        0.175286   0.656
# 563  0.544723        0.172245   0.653
# 577  0.510600        0.392363   0.789
# 642  0.339468        0.179086   0.740
# 772  0.480356        0.294029   0.662
# 798  0.398032        0.398455   1.049
# 806  0.584302        0.270187   0.633
# 885  0.423816        0.457382   1.007
# 908  0.638308        0.234642   0.631
#
# [22 rows x 22 columns]

# %%
df_industrials = df_industrials.dropna()
df_industrials
# Out:
#     ticker                             name       sector Earnings_expectation  \
# 15     AME                     AMETEK, Inc.  Industrials             Increase
# 37     CAT                Caterpillar, Inc.  Industrials             Increase
# 92     GWW              W.W. Grainger, Inc.  Industrials             Increase
# 112      J    Jacobs Engineering Group Inc.  Industrials             Increase
# 125    LHX      L3Harris Technologies, Inc.  Industrials             Increase
# 158   ODFL  Old Dominion Freight Line, Inc.  Industrials             Increase
# 207    URI             United Rentals, Inc.  Industrials             Increase
# 245   ARCB              ArcBest Corporation  Industrials             Increase
# 297    CAR          Avis Budget Group, Inc.  Industrials             Increase
# 410   ESEA                    Euroseas Ltd.  Industrials             Increase
# 467   FWRD          Forward Air Corporation  Industrials             Increase
# 477   GLDD  Great Lakes Dredge & Dock Corpo  Industrials             Increase
# 525   HSON              Hudson Global, Inc.  Industrials             Increase
# 563   ISSC  Innovative Solutions and Suppor  Industrials             Increase
# 577   KRNT              Kornit Digital Ltd.  Industrials             Increase
# 642   MGRC                 McGrath RentCorp  Industrials             Increase
# 772   RCII               Rent-A-Center Inc.  Industrials             Increase
# 798   SAIA                       Saia, Inc.  Industrials             Increase
# 806   SBLK         Star Bulk Carriers Corp.  Industrials             Increase
# 885   TRNS                   Transcat, Inc.  Industrials             Increase
# 908   USAK                  USA Truck, Inc.  Industrials             Increase
#
#            irv_status  capm_status       esg_status  current_price  \
# 15   Above Fair Price  UnderValued          Average         128.28
# 37   Below Fair Price  UnderValued  Not Sustainable         193.16
# 92   Above Fair Price  UnderValued      Sustainable         474.32
# 112  Above Fair Price  UnderValued          Average         120.31
# 125  Below Fair Price   OverValued          No Data         220.65
# 158  Below Fair Price   OverValued          No Data         287.86
# 207  Above Fair Price  UnderValued      Sustainable         311.82
# 245  Below Fair Price  UnderValued          No Data          85.22
# 297  Below Fair Price   OverValued          No Data         152.02
# 410  Above Fair Price  UnderValued          No Data          26.80
# 467  Above Fair Price  UnderValued          No Data          98.63
# 477  Above Fair Price  UnderValued          No Data          13.96
# 525  Above Fair Price  UnderValued          No Data          29.45
# 563  Above Fair Price  UnderValued          No Data           7.26
# 577  Below Fair Price  UnderValued          No Data          87.40
# 642  Above Fair Price  UnderValued          No Data          72.98
# 772  Below Fair Price  UnderValued          No Data          37.71
# 798  Below Fair Price   OverValued          No Data         257.07
# 806  Above Fair Price  UnderValued          No Data          31.31
# 885  Below Fair Price   OverValued          No Data          74.73
# 908  Below Fair Price  UnderValued          No Data          24.04
#
#      annu_return_10y    market_cap  ... eps_ttm  growth_estimate_5y  \
#
# 908  0.638308        0.234642   0.631
#
# [21 rows x 22 columns]

# %%
df_industrials.to_csv("selected_stocks_industrials.csv")

# %%
df_healthcare
# Out:
#     ticker                             name      sector Earnings_expectation  \
# 56    CTLT                   Catalent, Inc.  Healthcare             Increase
# 102   IDXX         IDEXX Laboratories, Inc.  Healthcare             Increase
# 106    IQV             IQVIA Holdings, Inc.  Healthcare             Increase
# 272   BDSI  BioDelivery Sciences Internatio  Healthcare             Increase
# 287   BRKR               Bruker Corporation  Healthcare             Increase
# 310   CDMO           Avid Bioservices, Inc.  Healthcare             Increase
# 351   CRSP           CRISPR Therapeutics AG  Healthcare             Increase
# 355   CSBR         Champions Oncology, Inc.  Healthcare             Increase
# 367   CUTR                     Cutera, Inc.  Healthcare             Increase
# 542   ICLR                         ICON plc  Healthcare             Increase
# 554   INMD                      InMode Ltd.  Healthcare             Increase
# 631   MEDP           Medpace Holdings, Inc.  Healthcare             Increase
# 651   MODV                   ModivCare Inc.  Healthcare             Increase
# 711   OPCH         Option Care Health, Inc.  Healthcare             Increase
# 715   OPRX           OptimizeRx Corporation  Healthcare             Increase
# 739   PGNY                    Progyny, Inc.  Healthcare             Decrease
# 778   RGEN             Repligen Corporation  Healthcare             Increase
# 882   TNDM       Tandem Diabetes Care, Inc.  Healthcare             Increase
# 931   XOMA                 XOMA Corporation  Healthcare             Increase
#
#            irv_status  capm_status       esg_status  current_price  \
# 56   Above Fair Price  UnderValued          No Data         97.610
# 102  Below Fair Price   OverValued  Not Sustainable        489.560
# 106  Above Fair Price  UnderValued      Sustainable        226.160
# 272  Below Fair Price  UnderValued          No Data          5.560
# 287  Above Fair Price  UnderValued          No Data         68.965
# 310  Above Fair Price  UnderValued          No Data         19.645
# 351  Above Fair Price  UnderValued          No Data         55.660
# 355  Above Fair Price  UnderValued          No Data          7.890
# 367  Above Fair Price  UnderValued          No Data         33.450
# 542  Below Fair Price   OverValued          No Data        220.250
# 554  Below Fair Price  UnderValued          No Data         40.900
# 631  Above Fair Price  UnderValued          No Data        140.030
# 651  Below Fair Price   OverValued          No Data        101.510
# 711  Above Fair Price  UnderValued          No Data         23.190
# 715  Below Fair Price   OverValued          No Data         41.650
# 739  Below Fair Price  UnderValued          No Data         36.170
# 778  Below Fair Price   OverValued          No Data        181.460
# 882  Below Fair Price  UnderValued          No Data        105.210
# 931  Above Fair Price  UnderValued          No Data         20.760
#
#      annu_return_10y    market_cap  ... eps_ttm  growth_estimate_5y  \
# 56          0.171804  1.670966e+10  ...   3.177              0.1617
# 102         0.272290  4.151156e+10  ...   8.718              0.2430
# 106         0.183066  4.320561e+10  ...   3.929              0.2213
# 272         0.091710  5.493052e+08  ...   0.290              0.2500
# 287         0.159607  1.045889e+10  ...   1.771              0.2055
# 310         0.146303  1.209769e+09  ...   0.136              0.1500
# 351         0.147264  4.259493e+09  ...   5.263             -2.0040
# 355        -0.013077  1.066326e+08  ...   0.020              0.1500
# 367         0.135705  6.006516e+08  ...   0.452              0.2500
# 542         0.264338  1.792787e+10  ...   2.939              0.2548
# 554         0.196788  3.124012e+09  ...   1.736              0.3320
# 631         0.175529  5.032566e+09  ...   4.830              0.1421
# 651         0.209990  1.421120e+09  ...   1.594              0.6845
# 711        -0.012280  4.171302e+09  ...   0.451              0.1000
# 715         0.330272  7.400997e+08  ...   0.067              0.5000
# 739         0.085391  3.270864e+09  ...   0.907              0.6020
# 778         0.455590  1.003265e+10  ...   2.101              0.2850
# 882        -0.058674  6.684275e+09  ...   0.339              5.9000
# 931        -0.034853  2.348205e+08  ...   0.082              0.1900
#
#      pe_forward  pe_trailing  irv_FairValue  ESG_risk  capm_expected_return  \
# 56    23.240477    30.723953   5.346009e+01    999.00              0.182089
# 102   52.025505    56.155080   4.928736e+02     20.74              0.133466
# 106   22.281775    57.561720   1.943151e+02     19.24              0.189383
# 272   16.848484    19.172415   5.887818e+00    999.00              0.121310
# 287   30.115719    38.941273   5.270151e+01    999.00              0.168718
# 310   61.390630   144.448530   9.822500e+00    999.00              0.298786
# 351   -7.906250    10.575717  -8.200419e+00    999.00              0.272043
# 355   34.304348   394.500000   3.945000e+00    999.00              0.141975
# 367   42.341770    74.004425   3.542221e+01    999.00              0.210048
# 542   19.152174    74.940460   2.414215e+02    999.00              0.124956
# 554   19.854370    23.559910   7.672746e+01    999.00              0.230713
# 631   25.552920    28.991718   6.580331e+01    999.00              0.179658
# 651   13.552737    63.682560   1.575569e+03    999.00              0.090920
# 711   25.766668    51.419070   7.771849e+00    999.00              0.245300
# 715   49.000000   621.641800   2.275756e+02    999.00              0.088489
# 739   64.589280    39.878720   3.572733e+02    999.00              0.227066
# 778   57.974440    86.368390   2.463760e+02    999.00              0.117663
# 882  140.280000   310.354000   5.301372e+08    999.00              0.065392
# 931  -90.260870   253.170730   1.412015e+01    999.00              0.117663
#
#        AHV_5y  annu_return_5y  sharpe
# 56   0.359504        0.285814   0.861
# 102  0.305168        0.291234   0.903
# 106  0.301323        0.240998   0.782
# 272  0.565891        0.246627   0.613
# 287  0.333862        0.242053   0.748
# 310  0.688251        0.654617   0.816
# 351  0.649606        0.295733   0.669
# 355  0.686045        0.120134   0.601
# 367  0.621925        0.136882   0.606
# 542  0.296964        0.223068   0.822
# 554       NaN             NaN   1.211
# 631  0.498130        0.345048   0.937
# 651  0.383729        0.202971   0.629
# 711  0.604863        0.286065   0.738
# 715  0.679004        0.808683   1.143
# 739       NaN             NaN   0.996
# 778  0.415307        0.448328   0.946
# 882  0.791402        0.353611   0.924
# 931  0.689078        0.371572   0.705
#
# [19 rows x 22 columns]

# %%
df_healthcare = df_healthcare.dropna()
df_healthcare
# Out:
#     ticker                             name      sector Earnings_expectation  \
# 56    CTLT                   Catalent, Inc.  Healthcare             Increase
# 102   IDXX         IDEXX Laboratories, Inc.  Healthcare             Increase
# 106    IQV             IQVIA Holdings, Inc.  Healthcare             Increase
# 272   BDSI  BioDelivery Sciences Internatio  Healthcare             Increase
# 287   BRKR               Bruker Corporation  Healthcare             Increase
# 310   CDMO           Avid Bioservices, Inc.  Healthcare             Increase
# 351   CRSP           CRISPR Therapeutics AG  Healthcare             Increase
# 355   CSBR         Champions Oncology, Inc.  Healthcare             Increase
# 367   CUTR                     Cutera, Inc.  Healthcare             Increase
# 542   ICLR                         ICON plc  Healthcare             Increase
# 631   MEDP           Medpace Holdings, Inc.  Healthcare             Increase
# 651   MODV                   ModivCare Inc.  Healthcare             Increase
# 711   OPCH         Option Care Health, Inc.  Healthcare             Increase
# 715   OPRX           OptimizeRx Corporation  Healthcare             Increase
# 778   RGEN             Repligen Corporation  Healthcare             Increase
# 882   TNDM       Tandem Diabetes Care, Inc.  Healthcare             Increase
# 931   XOMA                 XOMA Corporation  Healthcare             Increase
#
#            irv_status  capm_status       esg_status  current_price  \
# 56   Above Fair Price  UnderValued          No Data         97.610
# 102  Below Fair Price   OverValued  Not Sustainable        489.560
# 106  Above Fair Price  UnderValued      Sustainable        226.160
# 272  Below Fair Price  UnderValued          No Data          5.560
# 287  Above Fair Price  UnderValued          No Data         68.965
# 310  Above Fair Price  UnderValued          No Data         19.645
# 351  Above Fair Price  UnderValued          No Data         55.660
# 355  Above Fair Price  UnderValued          No Data          7.890
# 367  Above Fair Price  UnderValued          No Data         33.450
# 542  Below Fair Price   OverValued          No Data        220.250
# 631  Above Fair Price  UnderValued          No Data        140.030
# 651  Below Fair Price   OverValued          No Data        101.510
# 711  Above Fair Price  UnderValued          No Data         23.190
# 715  Below Fair Price   OverValued          No Data         41.650
# 778  Below Fair Price   OverValued          No Data        181.460
# 882  Below Fair Price  UnderValued          No Data        105.210
# 931  Above Fair Price  UnderValued          No Data         20.760
#
#      annu_return_10y    market_cap  ... eps_ttm  growth_estimate_5y  \
# 56          0.171804  1.670966e+10  ...   3.177              0.1617
# 102         0.272290  4.151156e+10  ...   8.718              0.2430
# 106         0.183066  4.320561e+10  ...   3.929              0.2213
# 272         0.091710  5.493052e+08  ...   0.290              0.2500
# 287         0.159607  1.045889e+10  ...   1.771              0.2055
# 310         0.146303  1.209769e+09  ...   0.136              0.1500
# 351         0.147264  4.259493e+09  ...   5.263             -2.0040
# 355        -0.013077  1.066326e+08  ...   0.020              0.1500
# 367         0.135705  6.006516e+08  ...   0.452              0.2500
# 542         0.264338  1.792787e+10  ...   2.939              0.2548
# 631         0.175529  5.032566e+09  ...   4.830              0.1421
# 651         0.209990  1.421120e+09  ...   1.594              0.6845
# 711        -0.012280  4.171302e+09  ...   0.451              0.1000
# 715         0.330272  7.400997e+08  ...   0.067              0.5000
# 778         0.455590  1.003265e+10  ...   2.101              0.2850
# 882        -0.058674  6.684275e+09  ...   0.339              5.9000
# 931        -0.034853  2.348205e+08  ...   0.082              0.1900
#
#      pe_forward  pe_trailing  irv_FairValue  ESG_risk  capm_expected_return  \
# 56    23.240477    30.723953   5.346009e+01    999.00              0.182089
# 102   52.025505    56.155080   4.928736e+02     20.74              0.133466
# 106   22.281775    57.561720   1.943151e+02     19.24              0.189383
# 272   16.848484    19.172415   5.887818e+00    999.00              0.121310
# 287   30.115719    38.941273   5.270151e+01    999.00              0.168718
# 310   61.390630   144.448530   9.822500e+00    999.00              0.298786
# 351   -7.906250    10.575717  -8.200419e+00    999.00              0.272043
# 355   34.304348   394.500000   3.945000e+00    999.00              0.141975
# 367   42.341770    74.004425   3.542221e+01    999.00              0.210048
# 542   19.152174    74.940460   2.414215e+02    999.00              0.124956
# 631   25.552920    28.991718   6.580331e+01    999.00              0.179658
# 651   13.552737    63.682560   1.575569e+03    999.00              0.090920
# 711   25.766668    51.419070   7.771849e+00    999.00              0.245300
# 715   49.000000   621.641800   2.275756e+02    999.00              0.088489
# 778   57.974440    86.368390   2.463760e+02    999.00              0.117663
# 882  140.280000   310.354000   5.301372e+08    999.00              0.065392
# 931  -90.260870   253.170730   1.412015e+01    999.00              0.117663
#
#        AHV_5y  annu_return_5y  sharpe
# 56   0.359504        0.285814   0.861
# 102  0.305168        0.291234   0.903
# 106  0.301323        0.240998   0.782
# 272  0.565891        0.246627   0.613
# 287  0.333862        0.242053   0.748
# 310  0.688251        0.654617   0.816
# 351  0.649606        0.295733   0.669
# 355  0.686045        0.120134   0.601
# 367  0.621925        0.136882   0.606
# 542  0.296964        0.223068   0.822
# 631  0.498130        0.345048   0.937
# 651  0.383729        0.202971   0.629
# 711  0.604863        0.286065   0.738
# 715  0.679004        0.808683   1.143
# 778  0.415307        0.448328   0.946
# 882  0.791402        0.353611   0.924
# 931  0.689078        0.371572   0.705
#
# [17 rows x 22 columns]

# %%
df_healthcare.to_csv("selected_stocks_healthcare.csv")

# %%
df_CS
# Out:
#     ticker                   name                  sector  \
# 259   AVID  Avid Technology, Inc.  Communication Services
# 767   QNST       QuinStreet, Inc.  Communication Services
# 789   ROKU             Roku, Inc.  Communication Services
# 893   TTGT       TechTarget, Inc.  Communication Services
#
#     Earnings_expectation        irv_status  capm_status esg_status  \
# 259             Increase  Above Fair Price  UnderValued    No Data
# 767             Increase  Below Fair Price  UnderValued    No Data
# 789             Decrease  Below Fair Price  UnderValued    No Data
# 893             Increase  Below Fair Price   OverValued    No Data
#
#      current_price  annu_return_10y    market_cap  ... eps_ttm  \
# 259          29.93         0.097825  1.347508e+09  ...   0.717
# 767          10.76        -0.002836  5.836483e+08  ...   0.223
# 789         121.97         0.179013  1.638826e+10  ...   2.067
# 893          73.20         0.263308  2.109602e+09  ...   0.694
#
#      growth_estimate_5y  pe_forward  pe_trailing  irv_FairValue  ESG_risk  \
# 259              0.1500   19.690790    41.743374      14.965000     999.0
# 767              0.2500   11.569893    48.251120      11.394409     999.0
# 789              0.4910   73.035934    59.008230     631.308006     999.0
# 893              0.3883   28.262548   105.475500     199.319788     999.0
#
#      capm_expected_return    AHV_5y  annu_return_5y  sharpe
# 259              0.167502  0.613275        0.402675   0.946
# 767              0.107938  0.587975        0.269590   0.636
# 789              0.228282       NaN             NaN   0.824
# 893              0.127388  0.455710        0.540216   1.136
#
# [4 rows x 22 columns]

# %%
df_CS.to_csv("selected_stocks_CS.csv")

# %%
df_energy
# Out:
#    ticker            name  sector Earnings_expectation        irv_status  \
# 52    COP  ConocoPhillips  Energy             Increase  Above Fair Price
#
#     capm_status       esg_status  current_price  annu_return_10y  \
# 52  UnderValued  Not Sustainable          89.27         0.080856
#
#       market_cap  ... eps_ttm  growth_estimate_5y  pe_forward  pe_trailing  \
# 52  1.177427e+11  ...   3.687              -0.018   11.444871    24.212095
#
#     irv_FairValue  ESG_risk  capm_expected_return    AHV_5y  annu_return_5y  \
# 52       10.77453     34.87              0.216126  0.420681        0.148794
#
#     sharpe
# 52    0.65
#
# [1 rows x 22 columns]

# %%
df_utilities
# Out:
# Empty DataFrame
# Columns: [ticker, name, sector, Earnings_expectation, irv_status, capm_status, esg_status, current_price, annu_return_10y, market_cap, marketcap_cat, beta, eps_ttm, growth_estimate_5y, pe_forward, pe_trailing, irv_FairValue, ESG_risk, capm_expected_return, AHV_5y, annu_return_5y, sharpe]
# Index: []
#
# [0 rows x 22 columns]

# %%
final_df_aggressive = pd.concat([df_utilities, df_energy, df_CS, df_healthcare, df_industrials, df_tech, df_CC, df_FS, df_RE, df_BM])
final_df_aggressive
# Out:
#     ticker                             name                  sector  \
# 52     COP                   ConocoPhillips                  Energy
# 259   AVID            Avid Technology, Inc.  Communication Services
# 767   QNST                 QuinStreet, Inc.  Communication Services
# 789   ROKU                       Roku, Inc.  Communication Services
# 893   TTGT                 TechTarget, Inc.  Communication Services
# ..     ...                              ...                     ...
# 82     FCX           Freeport-McMoRan, Inc.         Basic Materials
# 157    NUE                Nucor Corporation         Basic Materials
# 809   SCHN  Schnitzer Steel Industries, Inc         Basic Materials
# 855   STLD             Steel Dynamics, Inc.         Basic Materials
# 878   TGLS                  Tecnoglass Inc.         Basic Materials
#
#     Earnings_expectation        irv_status  capm_status       esg_status  \
# 52              Increase  Above Fair Price  UnderValued  Not Sustainable
# 259             Increase  Above Fair Price  UnderValued          No Data
# 767             Increase  Below Fair Price  UnderValued          No Data
# 789             Decrease  Below Fair Price  UnderValued          No Data
# 893             Increase  Below Fair Price   OverValued          No Data
# ..                   ...               ...          ...              ...
# 82              Increase  Below Fair Price  UnderValued  Not Sustainable
# 157             Increase  Below Fair Price  UnderValued  Not Sustainable
# 809             Increase  Above Fair Price  UnderValued          No Data
# 855             Increase  Below Fair Price  UnderValued  Not Sustainable
# 878             Increase  Above Fair Price  UnderValued          No Data
#
#      current_price  annu_return_10y    market_cap  ... eps_ttm  \
# 52           89.27         0.080856  1.177427e+11  ...   3.687
# 259          29.93         0.097825  1.347508e+09  ...   0.717
# 767          10.76        -0.002836  5.836483e+08  ...   0.223
# 789         121.97         0.179013  1.638826e+10  ...   2.067
# 893          73.20         0.263308  2.109602e+09  ...   0.694
# ..             ...              ...           ...  ...     ...
# 82           42.74         0.018945  6.276241e+10  ...   2.641
# 157         122.64         0.142526  3.505039e+10  ...  16.577
# 809          41.58         0.019844  1.156909e+09  ...   5.657
# 855          63.23         0.186302  1.254806e+10  ...  11.005
# 878          19.49         0.099058  9.291818e+08  ...   1.404
#
#      growth_estimate_5y  pe_forward  pe_trailing  irv_FairValue  ESG_risk  \
# 52              -0.0180   11.444871    24.212095      10.774530     34.87
# 259              0.1500   19.690790    41.743374      14.965000    999.00
# 767              0.2500   11.569893    48.251120      11.394409    999.00
# 789              0.4910   73.035934    59.008230     631.308006    999.00
# 893              0.3883   28.262548   105.475500     199.319788    999.00
# ..                  ...         ...          ...            ...       ...
# 82               0.2890   12.039437    16.183264      59.676070     34.50
# 157              0.3499    7.334929     7.398202     259.439419     36.58
# 809              0.1000    5.766991     7.350186      13.935037    999.00
# 855              0.3632    5.062450     5.745570     146.099525     34.29
# 878              0.0094   10.708791    13.881765       3.013498    999.00
#
#      capm_expected_return    AHV_5y  annu_return_5y  sharpe
# 52               0.216126  0.420681        0.148794   0.650
# 259              0.167502  0.613275        0.402675   0.946
# 767              0.107938  0.587975        0.269590   0.636
# 789              0.228282       NaN             NaN   0.824
# 893              0.127388  0.455710        0.540216   1.136
# ..                    ...       ...             ...     ...
# 82               0.270827  0.507643        0.234986   0.799
# 157              0.194245  0.360322        0.193174   0.741
# 809              0.203970  0.472387        0.156052   0.675
# 855              0.202754  0.411506        0.159118   0.689
# 878              0.230713  0.620494        0.151889   0.646
#
# [104 rows x 22 columns]

# %% [markdown]
# # Correlation

# %%
returns_list = []
for i in range(len(final_df_aggressive)):
    each = final_df_aggressive.iloc[i]
    ticker = each["ticker"]
    returns = get_return_series(ticker)
    if (len(returns) == 1260) or (len(returns) == 1261):
        returns_list.append(returns.iloc[:1260])

# %%
returns_list
# Out:
# [Symbols          COP
#  Date
#  2017-03-27       NaN
#  2017-03-28  0.024611
#  2017-03-29  0.037480
#  2017-03-30  0.128923
#  2017-03-31  0.125988
#  ...              ...
#  2022-03-21  1.320163
#  2022-03-22  1.297810
#  2022-03-23  1.356514
#  2022-03-24  1.360352
#  2022-03-25  1.427184
#
#  [1260 rows x 1 columns],
#  Symbols         AVID
#  Date
#  2017-03-27       NaN
#  2017-03-28  0.000000
#  2017-03-29  0.026144
#  2017-03-30  0.030501
#  2017-03-31  0.015250
#  ...              ...
#  2022-03-21  6.337690
#  2022-03-22  6.601307
#  2022-03-23  6.773420
#  2022-03-24  7.010893
#  2022-03-25  6.764705
#
#  [1260 rows x 1 columns],
#  Symbols             QNST
#  Date
#  2017-03-27           NaN
#  2017-03-28  1.856762e-02
#  2017-03-29 -1.110223e-16
#  2017-03-30  1.591510e-02
#  2017-03-31  3.448279e-02
#  ...                  ...
#  2022-03-21  2.196287e+00
#  2022-03-22  2.196287e+00
#  2022-03-23  2.090186e+00
#  2022-03-24  2.053050e+00
#  2022-03-25  2.015915e+00
#
#  [1260 rows x 1 columns],
#  Symbols         TTGT
#  Date
#  2017-03-27       NaN
#  2017-03-28  0.007847
#  2017-03-29  0.020179
#  2017-03-30  0.010090
#  2017-03-31  0.012332
#  ...              ...
#  2022-03-21  8.266816
#  2022-03-22  8.349776
#  2022-03-23  8.102018
#  2022-03-24  8.186099
#  2022-03-25  7.820628
#
#  [1260 rows x 1 columns],
#  Symbols         CTLT
#  Date
#  2017-03-27       NaN
#  2017-03-28  0.002109
#  2017-03-29  0.005624
#  2017-03-30  0.002109
#  2017-03-31 -0.004569
#  ...              ...
#  2022-03-21  2.788049
#  2022-03-22  2.792267
#  2022-03-23  2.689982
#  2022-03-24  2.792970
#  2022-03-25  2.763796
#
#  [1260 rows x 1 columns],
#  Symbols         IDXX
#  Date
#  2017-03-27       NaN
#  2017-03-28 -0.000974
#  2017-03-29  0.004936
#  2017-03-30  0.003637
#  2017-03-31  0.004222
#  ...              ...
#  2022-03-21  2.504742
#  2022-03-22  2.588335
#  2022-03-23  2.481813
#  2022-03-24  2.509938
#  2022-03-25  2.500454
#
#  [1260 rows x 1 columns],
#  Symbols          IQV
#  Date
#  2017-03-27       NaN
#  2017-03-28  0.000000
#  2017-03-29  0.018424
#  2017-03-30  0.015629
#  2017-03-31  0.023253
#  ...              ...
#  2022-03-21  1.883990
#  2022-03-22  1.908895
#  2022-03-23  1.799365
#  2022-03-24  1.854130
#  2022-03-25  1.855909
#
#  [1260 rows x 1 columns],
#  Symbols         BDSI
#  Date
#  2017-03-27       NaN
#  2017-03-28  0
#  Date
#  2017-03-27       NaN
#  2017-03-28  0.029484
#  2017-03-29  0.041769
#  2017-03-30  0.090090
#  2017-03-31  0.094185
#  ...              ...
#  2022-03-21  3.054873
#  2022-03-22  3.083538
#  2022-03-23  3.079443
#  2022-03-24  3.213759
#  2022-03-25  3.253071
#
#  [1260 rows x 1 columns],
#  Symbols          NUE
#  Date
#  2017-03-27       NaN
#  2017-03-28  0.011933
#  2017-03-29  0.004538
#  2017-03-30  0.010084
#  2017-03-31  0.003697
#  ...              ...
#  2022-03-21  1.399160
#  2022-03-22  1.420168
#  2022-03-23  1.472941
#  2022-03-24  1.580168
#  2022-03-25  1.649076
#
#  [1260 rows x 1 columns],
#  Symbols         SCHN
#  Date
#  2017-03-27       NaN
#  2017-03-28  0.017157
#  2017-03-29 -0.002451
#  2017-03-30 -0.004902
#  2017-03-31  0.012255
#  ...              ...
#  2022-03-21  1.440196
#  2022-03-22  1.390196
#  2022-03-23  1.396569
#  2022-03-24  1.735784
#  2022-03-25  1.687745
#
#  [1260 rows x 1 columns],
#  Symbols         STLD
#  Date
#  2017-03-27       NaN
#  2017-03-28  0.028165
#  2017-03-29  0.018085
#  2017-03-30  0.024311
#  2017-03-31  0.030537
#  ...              ...
#  2022-03-21  1.525348
#  2022-03-22  1.496294
#  2022-03-23  1.533650
#  2022-03-24  1.628521
#  2022-03-25  1.653128
#
#  [1260 rows x 1 columns],
#  Symbols         TGLS
#  Date
#  2017-03-27       NaN
#  2017-03-28 -0.002760
#  2017-03-29 -0.001840
#  2017-03-30 -0.001840
#  2017-03-31 -0.001840
#  ...              ...
#  2022-03-21  1.383625
#  2022-03-22  1.356946
#  2022-03-23  1.378105
#  2022-03-24  1.442502
#  2022-03-25  1.411223
#
#  [1260 rows x 1 columns]]

# %%
len(returns_list)
# Out:
# 89

# %%
return_series_close = pd.concat(returns_list, axis=1)
return_series_close
# Out:
# Symbols          COP      AVID          QNST      TTGT      CTLT      IDXX  \
# Date
# 2017-03-27       NaN       NaN           NaN       NaN       NaN       NaN
# 2017-03-28  0.024611  0.000000  1.856762e-02  0.007847  0.002109 -0.000974
# 2017-03-29  0.037480  0.026144 -1.110223e-16  0.020179  0.005624  0.004936
# 2017-03-30  0.128923  0.030501  1.591510e-02  0.010090  0.002109  0.003637
# 2017-03-31  0.125988  0.015250  3.448279e-02  0.012332 -0.004569  0.004222
# ...              ...       ...           ...       ...       ...       ...
# 2022-03-21  1.320163  6.337690  2.196287e+00  8.266816  2.788049  2.504742
# 2022-03-22  1.297810  6.601307  2.196287e+00  8.349776  2.792267  2.588335
# 2022-03-23  1.356514  6.773420  2.090186e+00  8.102018  2.689982  2.481813
# 2022-03-24  1.360352  7.010893  2.053050e+00  8.186099  2.792970  2.509938
# 2022-03-25  1.427184  6.764705  2.015915e+00  7.820628  2.763796  2.500454
#
# Symbols          IQV      BDSI      BRKR      CDMO  ...        CG      CSWC  \
# Date                                                ...
# 2017-03-27       NaN       NaN       NaN       NaN  ...       NaN       NaN
# 2017-03-28  0.000000  0.000000 -0.004399 -0.041096  ... -0.006250  0.015337
# 2017-03-29  0.018424  0.000000  0.003960 -0.027397  ... -0.012500  0.023313
# 2017-03-30  0.015629 -0.013158  0.009679 -0.082192  ... -0.006250  0.026994
# 2017-03-31  0.023253  0.000000  0.026397 -0.109589  ... -0.003125  0.037423
# ...              ...       ...       ...       ...  ...       ...       ...
# 2022-03-21  1.883990  1.944737  1.972283  3.236790  ...  1.902500  0.453988
# 2022-03-22  1.908895  1.942105  1.985042  3.317025  ...  1.932500  0.454601
# 2022-03-23  1.799365  1.942105  1.845139  3.183953  ...  1.885625  0.430061
# 2022-03-24  1.854130  1.942105  1.895733  3.289628  ...  1.912500  0.415951
# 2022-03-25  1.855909  1.942105  1.875935  3.221135  ...  1.892500  0.446012
#
# Symbols      TBBK      CBRE      SBAC       FCX       NUE      SCHN      STLD  \
# Date
# 2017-03-27    NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2017-03-28 -0.004  0.008605  0.006367  0.029484  0.011933  0.017157  0.028165
# 2017-03-29 -0.014  0.018398  0.016808  0.041769  0.004538 -0.002451  0.018085
# 2017-03-30  0.020  0.030861  0.009508  0.090090  0.010084 -0.004902  0.024311
# 2017-03-31  0.020  0.032344  0.021817  0.094185  0.003697  0.012255  0.030537
# ...           ...       ...       ...       ...       ...       ...       ...
# 2022-03-21  4.862  1.678635  1.780985  3.054873  1.399160  1.440196  1.525348
# 2022-03-22  5.054  1.717507  1.739643  3.083538  1.420168  1.390196  1.496294
# 2022-03-23  4.746  1.650742  1.720543  3.079443  1.472941  1.396569  1.533650
# 2022-03-24  4.866  1.672403  1.762394  3.213759  1.580168  1.735784  1.628521
# 2022-03-25  5.014  1.677745  1.792784  3.253071  1.649076  1.687745  1.653128
#
# Symbols         TGLS
# Date
# 2017-03-27       NaN
# 2017-03-28 -0.002760
# 2017-03-29 -0.001840
# 2017-03-30 -0.001840
# 2017-03-31 -0.001840
# ...              ...
# 2022-03-21  1.383625
# 2022-03-22  1.356946
# 2022-03-23  1.378105
# 2022-03-24  1.442502
# 2022-03-25  1.411223
#
# [1260 rows x 89 columns]

# %%
return_series_close.plot(figsize=(16,9))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
return_series_close.tail(1)
# Out:
# Symbols          COP      AVID      QNST      TTGT      CTLT      IDXX  \
# Date
# 2022-03-25  1.427184  6.764705  2.015915  7.820628  2.763796  2.500454
#
# Symbols          IQV      BDSI      BRKR      CDMO  ...      CG      CSWC  \
# Date                                                ...
# 2022-03-25  1.855909  1.942105  1.875935  3.221135  ...  1.8925  0.446012
#
# Symbols      TBBK      CBRE      SBAC       FCX       NUE      SCHN      STLD  \
# Date
# 2022-03-25  5.014  1.677745  1.792784  3.253071  1.649076  1.687745  1.653128
#
# Symbols         TGLS
# Date
# 2022-03-25  1.411223
#
# [1 rows x 89 columns]

# %%
correlation = return_series_close.corr()
# # correlation
# fig, ax = plt.subplots(figsize=(16,10))
# sns.heatmap(correlation, annot = True, ax = ax, cmap="YlGnBu")

# %%
correlation = correlation[correlation < 0.2]
correlation.dropna(thresh=1, inplace=True, axis=1)
correlation.dropna(thresh=1, inplace=True, axis=0)

# %%
correlation
# Out:
# Symbols       COP  AVID  QNST  TTGT      CTLT      IDXX  IQV      BDSI  BRKR  \
# Symbols
# COP           NaN   NaN   NaN   NaN  0.064382  0.163861  NaN  0.090327   NaN
# AVID          NaN   NaN   NaN   NaN       NaN       NaN  NaN  0.119094   NaN
# QNST          NaN   NaN   NaN   NaN       NaN       NaN  NaN       NaN   NaN
# TTGT          NaN   NaN   NaN   NaN       NaN       NaN  NaN  0.139407   NaN
# CTLT     0.064382   NaN   NaN   NaN       NaN       NaN  NaN       NaN   NaN
# ...           ...   ...   ...   ...       ...       ...  ...       ...   ...
# FCX           NaN   NaN   NaN   NaN       NaN       NaN  NaN -0.035476   NaN
# NUE           NaN   NaN   NaN   NaN       NaN       NaN  NaN -0.077926   NaN
# SCHN          NaN   NaN   NaN   NaN       NaN       NaN  NaN -0.185204   NaN
# STLD          NaN   NaN   NaN   NaN       NaN       NaN  NaN -0.199716   NaN
# TGLS          NaN   NaN   NaN   NaN       NaN       NaN  NaN -0.085201   NaN
#
# Symbols  CDMO  ...  RUSHA  TROW  CG  TBBK      SBAC  FCX  NUE  SCHN  STLD  \
# Symbols        ...
# COP       NaN  ...    NaN   NaN NaN   NaN -0.004604  NaN  NaN   NaN   NaN
# AVID      NaN  ...    NaN   NaN NaN   NaN       NaN  NaN  NaN   NaN   NaN
# QNST      NaN  ...    NaN   NaN NaN   NaN       NaN  NaN  NaN   NaN   NaN
# TTGT      NaN  ...    NaN   NaN NaN   NaN       NaN  NaN  NaN   NaN   NaN
# CTLT      NaN  ...    NaN   NaN NaN   NaN       NaN  NaN  NaN   NaN   NaN
# ...       ...  ...    ...   ...  ..   ...       ...  ...  ...   ...   ...
# FCX       NaN  ...    NaN   NaN NaN   NaN       NaN  NaN  NaN   NaN   NaN
# NUE       NaN  ...    NaN   NaN NaN   NaN       NaN  NaN  NaN   NaN   NaN
# SCHN      NaN  ...    NaN   NaN NaN   NaN       NaN  NaN  NaN   NaN   NaN
# STLD      NaN  ...    NaN   NaN NaN   NaN       NaN  NaN  NaN   NaN   NaN
# TGLS      NaN  ...    NaN   NaN NaN   NaN       NaN  NaN  NaN   NaN   NaN
#
# Symbols  TGLS
# Symbols
# COP       NaN
# AVID      NaN
# QNST      NaN
# TTGT      NaN
# CTLT      NaN
# ...       ...
# FCX       NaN
# NUE       NaN
# SCHN      NaN
# STLD      NaN
# TGLS      NaN
#
# [82 rows x 82 columns]

# %%
fig, ax = plt.subplots(figsize=(16,10))
sns.heatmap(correlation, annot = True, ax = ax, cmap="YlGnBu")
# Out:
# <AxesSubplot:xlabel='Symbols', ylabel='Symbols'>

# %%
len(correlation)
# Out:
# 82

# %%
all_stocks = []
for each in correlation:
    all_stocks.append(each)

# %%
len(all_stocks)
# Out:
# 82

# %%
indexes = []
for i in range(len(final_df_aggressive)):
    each = final_df_aggressive.iloc[i]
    ticker = each["ticker"]
    if ticker in all_stocks:
        indexes.append(i)

# %%
final_aggressive_df = final_df_aggressive.iloc[indexes]
final_aggressive_df
# Out:
#     ticker                             name                  sector  \
# 52     COP                   ConocoPhillips                  Energy
# 259   AVID            Avid Technology, Inc.  Communication Services
# 767   QNST                 QuinStreet, Inc.  Communication Services
# 893   TTGT                 TechTarget, Inc.  Communication Services
# 56    CTLT                   Catalent, Inc.              Healthcare
# ..     ...                              ...                     ...
# 82     FCX           Freeport-McMoRan, Inc.         Basic Materials
# 157    NUE                Nucor Corporation         Basic Materials
# 809   SCHN  Schnitzer Steel Industries, Inc         Basic Materials
# 855   STLD             Steel Dynamics, Inc.         Basic Materials
# 878   TGLS                  Tecnoglass Inc.         Basic Materials
#
#     Earnings_expectation        irv_status  capm_status       esg_status  \
# 52              Increase  Above Fair Price  UnderValued  Not Sustainable
# 259             Increase  Above Fair Price  UnderValued          No Data
# 767             Increase  Below Fair Price  UnderValued          No Data
# 893             Increase  Below Fair Price   OverValued          No Data
# 56              Increase  Above Fair Price  UnderValued          No Data
# ..                   ...               ...          ...              ...
# 82              Increase  Below Fair Price  UnderValued  Not Sustainable
# 157             Increase  Below Fair Price  UnderValued  Not Sustainable
# 809             Increase  Above Fair Price  UnderValued          No Data
# 855             Increase  Below Fair Price  UnderValued  Not Sustainable
# 878             Increase  Above Fair Price  UnderValued          No Data
#
#      current_price  annu_return_10y    market_cap  ... eps_ttm  \
# 52           89.27         0.080856  1.177427e+11  ...   3.687
# 259          29.93         0.097825  1.347508e+09  ...   0.717
# 767          10.76        -0.002836  5.836483e+08  ...   0.223
# 893          73.20         0.263308  2.109602e+09  ...   0.694
# 56           97.61         0.171804  1.670966e+10  ...   3.177
# ..             ...              ...           ...  ...     ...
# 82           42.74         0.018945  6.276241e+10  ...   2.641
# 157         122.64         0.142526  3.505039e+10  ...  16.577
# 809          41.58         0.019844  1.156909e+09  ...   5.657
# 855          63.23         0.186302  1.254806e+10  ...  11.005
# 878          19.49         0.099058  9.291818e+08  ...   1.404
#
#      growth_estimate_5y  pe_forward  pe_trailing  irv_FairValue  ESG_risk  \
# 52              -0.0180   11.444871    24.212095      10.774530     34.87
# 259              0.1500   19.690790    41.743374      14.965000    999.00
# 767              0.2500   11.569893    48.251120      11.394409    999.00
# 893              0.3883   28.262548   105.475500     199.319788    999.00
# 56               0.1617   23.240477    30.723953      53.460086    999.00
# ..                  ...         ...          ...            ...       ...
# 82               0.2890   12.039437    16.183264      59.676070     34.50
# 157              0.3499    7.334929     7.398202     259.439419     36.58
# 809              0.1000    5.766991     7.350186      13.935037    999.00
# 855              0.3632    5.062450     5.745570     146.099525     34.29
# 878              0.0094   10.708791    13.881765       3.013498    999.00
#
#      capm_expected_return    AHV_5y  annu_return_5y  sharpe
# 52               0.216126  0.420681        0.148794   0.650
# 259              0.167502  0.613275        0.402675   0.946
# 767              0.107938  0.587975        0.269590   0.636
# 893              0.127388  0.455710        0.540216   1.136
# 56               0.182089  0.359504        0.285814   0.861
# ..                    ...       ...             ...     ...
# 82               0.270827  0.507643        0.234986   0.799
# 157              0.194245  0.360322        0.193174   0.741
# 809              0.203970  0.472387        0.156052   0.675
# 855              0.202754  0.411506        0.159118   0.689
# 878              0.230713  0.620494        0.151889   0.646
#
# [82 rows x 22 columns]

# %%
final_aggressive_df.to_csv("selected_stocks_aggressive_v3.csv")
